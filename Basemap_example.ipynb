# %% [markdown]
# <h1> Basemape tutorial </h1>

# %%
import matplotlib as mpl
from mpl_toolkits.basemap import Basemap
# %pylab inline
pylab.rcParams['figure.figsize'] = (14.0, 8.0) # set size of figures"
plt.rcParams.update({'font.size': 18})
from matplotlib.patches import Polygon
import sys
sys.path.append('/Users/attiladobi/basemap/examples')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <h1> nsper projection </h1>

# %%
m = Basemap(projection='nsper',lon_0=-105,lat_0=40, satellite_height=3e6\
            ,resolution='l')
m.drawcoastlines()
m.fillcontinents(color='magenta')
m.drawcountries()
m.drawstates()
#m.drawrivers()
plt.title('Basemap example')
plt.show()

# %%
m = Basemap(llcrnrlon=-100.,llcrnrlat=0.,urcrnrlon=-20.,urcrnrlat=57.,
            projection='lcc',lat_1=20.,lat_2=40.,lon_0=-60.,
            resolution ='l',area_thresh=1000.)
m.drawcoastlines()
m.drawcountries()
m.drawstates()
m.drawcounties()

#add marker for newyour
NYClat,NYClon = 40.7127, -74.0059
xpt, ypt = m(NYClon, NYClat)
m.plot(xpt,ypt,'*r', markersize=20)

plt.title('Basemap example')
plt.show()

# %% [markdown]
# <h1> lcc </h1>

# %%
# plot topography/bathymetry as an image.

# create the figure and axes instances.
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8])
m = Basemap(llcrnrlon=-145.5,llcrnrlat=1.,urcrnrlon=-2.566,urcrnrlat=46.352,\
            rsphere=(6378137.00,6356752.3142),\
            resolution='l',area_thresh=1000.,projection='lcc',\
            lat_1=50.,lon_0=-107.,ax=ax)

# draw coastlines and political boundaries.
m.drawcoastlines()
m.drawcountries()
m.drawstates()

# draw parallels and meridians.
# label on left and bottom of map.
parallels = np.arange(0.,80,20.)
m.drawparallels(parallels,labels=[1,0,0,1])
meridians = np.arange(10.,360.,30.)
m.drawmeridians(meridians,labels=[1,0,0,1])

#add topography 
m.etopo()

#add marker for newyour
NYClat,NYClon = 40.7127, -74.0059
xpt, ypt = m(NYClon, NYClat)
m.plot(xpt,ypt,'*r', markersize=20)

plt.show()

# %%
map = Basemap(llcrnrlon=-119,llcrnrlat=22,urcrnrlon=-64,urcrnrlat=49,
        projection='lcc',lat_1=33,lat_2=45,lon_0=-95)

# load the shapefile, use the name 'states'
map.readshapefile('st99_d00', name='states', drawbounds=True)

# collect the state names from the shapefile attributes so we can
# look up the shape obect for a state by it's name
state_names = []
for shape_dict in map.states_info:
    state_names.append(shape_dict['NAME'])

ax = plt.gca() # get current axes instance

# get Texas and draw the filled polygon
seg = map.states[state_names.index('Texas')]
poly = Polygon(seg, facecolor='red',edgecolor='red')
ax.add_patch(poly)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-38-c44d786a3d77> in <module>()
#       3
#       4 # load the shapefile, use the name 'states'
# ----> 5 map.readshapefile('st99_d00', name='states', drawbounds=True)
#       6
#       7 # collect the state names from the shapefile attributes so we can
#
# /Users/attiladobi/anaconda/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.pyc in readshapefile(self, shapefile, name, drawbounds, zorder, linewidth, color, antialiased, ax, default_encoding)
#    2122         shp.default_encoding = default_encoding
#    2123         if not os.path.exists('%s.shp'%shapefile):
# -> 2124             raise IOError('cannot locate %s.shp'%shapefile)
#    2125         if not os.path.exists('%s.shx'%shapefile):
#    2126             raise IOError('cannot locate %s.shx'%shapefile)
#
# IOError: cannot locate st99_d00.shp

# %%
cp=cmp?

# %%
c_map=cm

# %%
norm=mpl.colors.Normalize(vmin=min(X),vmax=max(X))
m = cm.ScalarMappable(norm=norm)
#mycolor=c_map.jet(X/max(X))

# %%
m.to_rgba(3)
# Out:
# (0.0, 0.83333333333333337, 1.0, 1.0)

# %%
mycolor=c_map.jet(X/max(X))

# %%
X=np.array([1,2,3,4,5,6,7])
for i,val in enumerate(X):
    plot(val,3,'o',color=m.to_rgba(val),markersize=10)
