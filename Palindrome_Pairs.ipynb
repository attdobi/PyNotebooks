# %%
class Answer(object):    
    def sum_str(self,string1, string2):
        return sum([ord(char1)-ord(char2) for char1,char2 in zip(string1,string2)])
        #if all equal zero at each element
    def is_pal(self, text):
        result=False
        middle_index=int(len(text)/2)
        
        if len(text)%2==0:
            #if self.sum_str(text[:middle_index])-self.sum_str(text[middle_index:])==0:
            if self.sum_str(text[:middle_index], text[middle_index:])==0:
                result=True
        else:
            #if self.sum_str(text[:middle_index])-self.sum_str(text[middle_index+1:])==0:
                result=True
            
        return result
        
    def palindromePairs(self, words):
        """
        :type words: List[str]
        :rtype: List[List[int]]
        """
        answers=[]
        for ii, word1 in enumerate(words):
            for jj, word2 in enumerate(words):
                if (ii!=jj) & (self.is_pal(word1+word2)):
                    answers.append([ii,jj])
        return answers

# %%
test=Answer()

# %%
test.palindromePairs(["aegdgcgcfcgafcbihci","gecbcdgbhjdhjjcjfbd","cdjbaffijd","dic","adggiigaagj","jfijedfbghhhfddbe","cjggaggffccbii","g","c","dehjgeehgda","fbjecadfadcejha","heeafjddadchi","idafi","dieahfgfiehgcedc","je","hihgeihcehjcf","ihgjej","bchggfbabadbjj","ecgehaagfgcibbgb","jgabecafba","hjaaacebhjcecbbfc","aecfe","hbfaeai","gaegif","geijeiaeccjcf","a","hhh","ehjjhiadjiacdibhjaf","cbegigbecaai","h","aajachagjdg","higaeb","cjeh","b","cjfdbeiejcecbcdbcajj","dihhchhbfegf","edjfhhjihdcgbaiai","icjeehhbfdaaebfa","afhabecahagjefi","hf","gjbiijjfjdf","gijcide","jbheae","cicdhbgghacgcgi","hegicjebfdjhebigci","dgbceaahii","gjgfbcigdgjcaieaecb","jjggaagaiiifbhhfe","gfdfgegjagjfjjaaabj","gidiedddbecjh","hdeegbf","cjc","feij","ccchegbbfggjfjjedf","dfggg","abcjhhdcghf","gfbdiggece","acgbbjiijecaefade","ejfjdegbab","ebbe","dcfajhfcfdbc","cjgedeibdfaffjbag","bbci","cj","jff","fjcjd","fjcjfgj","aegjhjjddhcjcajbejij","fdhhhdc","eecb","hihjhaccedadbiigbef","hcgeigicfdieifa","jfafgbib","fjffebjgciibaggggach","jiccfhfaddciiddeae","ahcafjjech","hiedhe","ijhejfciaehfebgj","ajcbcgdgajidgciacg","j","gfbdjehej","bajibaafj","acjd","ehhai","ghgddaiejecig","aidcjfhfdidiccaig","e","heddghede","fbfh","efchgfjgjbbicjb","ecjdjgjbi","eddehdcidccc","ghehgfgifdaacijcifj","fdjjj","ejhfadjadciceffij","hhejdj","jjcijeejabeijh","gifdheahjefeeddeed","hfgb","deeaabd","hfgifida","cjfbdaifeeij","ijbdj","ecdcgf","ebaaiddhghahdejib","eajjifajg","aideidjgfbgi","gjddhcefieeidi","dagdgehbifgecgj
#  [0, 52],
#  [0, 53],
#  [0, 56],
#  [0, 58],
#  [0, 59],
#  [0, 60],
#  [0, 62],
#  [0, 63],
#  [0, 67],
#  [0, 69],
#  [0, 72],
#  [0, 73],
#  [0, 74],
#  [0, 75],
#  [0, 76],
#  [0, 77],
#  [0, 78],
#  [0, 82],
#  [0, 88],
#  [0, 91],
#  [0, 95],
#  [0, 96],
#  [0, 97],
#  [0, 98],
#  [0, 100],
#  [0, 101],
#  [0, 103],
#  [0, 106],
#  [0, 107],
#  [0, 109],
#  [0, 110],
#  [0, 111],
#  [0, 112],
#  [0, 114],
#  [0, 115],
#  [0, 116],
#  [0, 121],
#  [0, 123],
#  [0, 124],
#  [0, 128],
#  [0, 129],
#  [0, 130],
#  [0, 131],
#  [0, 134],
#  [0, 135],
#  [0, 136],
#  [0, 138],
#  [0, 139],
#  [0, 141],
#  [0, 143],
#  [0, 148],
#  [0, 150],
#  [0, 152],
#  [0, 153],
#  [0, 154],
#  [0, 158],
#  [0, 159],
#  [0, 160],
#  [0, 161],
#  [0, 165],
#  [0, 166],
# ...

# %%
w=[100,20,300,700]
[[x for ii, x in enumerate(w) if ii!=index] for index in range(len(w))]
#[[ii for ii, x in enumerate(w) if ii!=index] for index in range(len(w))]
# Out:
# [[20, 300, 700], [100, 300, 700], [100, 20, 700], [100, 20, 300]]

# %%
a='restasdasd'
''.join([c for c in reversed(a)])
# Out:
# 'dsadsatser'

# %%
def check_pal(text):
    middle = int(len(text)/2)

# %%
def say_hello():
    print('Hello, World')

#for i in range(5):
#    say_hello()


# 
# Your previous Plain Text content is preserved below:
# 
# This is just a simple shared plaintext pad, with no execution capabilities.
# 
# When you know what language you'd like to use for your interview,
# simply choose it from the dropdown in the top bar.
# 
# You can also change the default language your pads are created with
# in your account settings: https://coderpad.io/profile
# 
# Enjoy your interview!
# 
# 
import numpy as np

def yo_kevin():
    print ('yo')


def nap_sack(a1,a2, weight_limit):
    result=[]
    
    ii=0
    for price, weight in zip(a1,a2):
        if weight <= weight_limit:
            result.append(ii)
            weight_limit=weight_limit-weight
        ii=ii+1
            
    return result
    
def zeroOneKnapsack(v, w, W):
    # c is the cost matrix
    c = []
    n = len(v)
    c = np.zeros([n,W+1])
    for i in range(0,n):
        #for ever possible weight
        for j in range(0,W+1):        
                    #can we add this item to this?
            if (w[i] > j):
                c[i][j] = c[i-1][j]
            else:
                c[i][j] = max(c[i-1][j],v[i] +c[i-1][j-w[i]])
    print(c)
    return [c[n-1][W]] #getUsedItems(w,c)
    
        
    #nap_sack2(p,w,limit)
    


S = {'item1':(50,100), 'item2':(100,50),'item4':(20,10) }
prices=[100,50,10]
weights=[100,50,20]

a= zeroOneKnapsack(prices,weights,10)
print(a)
