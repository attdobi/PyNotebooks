# %%
import aLib
import matplotlib as mlp
# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # set size of figures"
plt.rcParams.update({'font.size': 24})
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['rate']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
E_vect=np.linspace(0,100*1.01,100)
rate= rates.WIMP.WIMPdiffRate(E_vect, mW=50, sig=1e-36)

# %%
mWmps=[1.00 3.00 5.00 7.00 9.00 11.00 13.00 15.00 17.00 19.00 21.00 23.00 25.00 27.00 29.00 31.00 33.00 35.00 37.00 39.00 41.00 43.00 45.00 47.00 49.00 51.00 53.00 55.00 57.00 59.00 61.00 63.00 65.00 67.00 69.00 71.00 73.00 75.00 77.00 79.00 81.00 83.00 85.00 87.00 89.00 91.00 93.00 95.00 97.00 99.00]
# Out:
#   File "<ipython-input-19-ccb5e7226bdf>", line 1
#     mWmps=[1.00 3.00 5.00 7.00 9.00 11.00 13.00 15.00 17.00 19.00 21.00 23.00 25.00 27.00 29.00 31.00 33.00 35.00 37.00 39.00 41.00 43.00 45.00 47.00 49.00 51.00 53.00 55.00 57.00 59.00 61.00 63.00 65.00 67.00 69.00 71.00 73.00 75.00 77.00 79.00 81.00 83.00 85.00 87.00 89.00 91.00 93.00 95.00 97.00 99.00]
#                    ^
# SyntaxError: invalid syntax

# %%
plt.plot(E_vect,rate)
xlabel('Energy (KeVnr)')
ylabel('rate (sigma = 1e-36, 50 GeV WIMP)')
xlim([0,100])
# Out:
# (0, 100)

# %%
rates.WIMP.WIMPdiffRate?
