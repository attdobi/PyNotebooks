# %%
from __future__ import division
import numpy as np
import json
import re
import gzip
import pandas as pd
# %pylab inline
pylab.rcParams['figure.figsize'] = (12.0, 8.0) # set size of figures"
plt.rcParams.update({'font.size': 24})
import seaborn as sns
import datetime
import csv
import urllib
from area import area
from collections import defaultdict
from time import sleep
import pandas as pd

def load_dict_from_json(filepath):
    '''given file path to json mapping return a dict'''
    with open(filepath) as data_file:    
        return json.load(data_file)
    
def calc_centroid(coordinates):
    ''' Pass in geo_obj['coordinates'][0] '''
    N = len(coordinates)
    lat_sum, lon_sum = 0, 0
    for latlon in coordinates:
        lat_sum = lat_sum + latlon[1]
        lon_sum = lon_sum + latlon[0]
    return [lat_sum / N, lon_sum / N]
    
ET_woreda_geo = load_dict_from_json('/Users/attiladobi/Downloads/ethiopia-20170203.geojson')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <h1> Supporting functions </h1>

# %%
ELEVATION_BASE_URL = 'https://maps.googleapis.com/maps/api/elevation/json'
API_KEY = 'AIzaSyBVX3cxwT_4TenXjSjXUPnd4eL5NmabJmQ'

def lookup_elevation(lat, lon, try_max=3):
    if (float(lat) == 0.0) & (float(lon) == 0.0):
        return -1000
    else:
        url = '%s?locations=%s,%s&key=%s' % (ELEVATION_BASE_URL, lat, lon, API_KEY)
        trys = 0
        while trys < try_max:
            result = json.load(urllib.urlopen(url))
            if result['status'] == 'OK':
                return result['results'][0]['elevation']
            sleep(5)
            trys += 1
        return -1000
    
def process_woreda_elevation(df_woreda, geo_code):
    elevation_list = df_woreda.loc[geo_code]['Elevation_m']
    # remove anything less than -100 m
    elevations_cut = elevation_list[elevation_list > -100]
    if len(elevations_cut) > 0:
        elevation = elevations_cut.mean()
        elevation_min = elevations_cut.min()
        elevation_max = elevations_cut.max()
    else:
        elevation = -1000
        elevation_min = -1000
        elevation_max = -1000
    return elevation, elevation_min, elevation_max

def process_woreda_latlon(df_woreda, geo_code):
    # Using WoredaLat and Lon from the woreda_mapped.csv file (more complete than the geojson files)
    lat_list = df_woreda.loc[geo_code]['WoredaLat']
    lon_list = df_woreda.loc[geo_code]['WoredaLon']
    
    # remove anything with 0
    lat_list_cut = lat_list[lat_list != 0]
    lon_list_cut = lon_list[lon_list != 0]
    if len(lat_list_cut) > 0:
        lat = lat_list_cut.mean()
        lon = lon_list_cut.mean()
    else:
        lat = 0
        lon = 0
    return lat, lon

# %% [markdown]
# <h1> First loop through ET_woreda_geo file and build a dictionary lookup for area and centroid </h1>

# %%
geo_dict = dict()

for entry in ET_woreda_geo['features']:
    geoKey = entry['properties']['key']
    region, zone, woreda = geoKey.split('__')[:-1]
    geo_obj = entry['geometry']
    poly_area = area(geo_obj)/1e6
    latlons = geo_obj['coordinates'][0]
    # Sometimes the number of lists in the lists changes
    while len(np.shape(latlons)) > 2:
        latlons = latlons[0]
    centroid = calc_centroid(latlons)

    geo_dict[geoKey] ={'WoredaName': woreda, 'ZoneName': zone, 'RegionName': region, 'Area_km2': poly_area, \
                     'LatCenter': centroid[0], 'LonCenter': centroid[1]}

# %%
geo_dict.keys
# Out:
# {u'addis ababa______': {'Area_km2': 543.0859458141679,
#   'LatCenter': 8.96289341830333,
#   'LonCenter': 38.786080227245954,
#   'RegionName': u'addis ababa',
#   'WoredaName': u'',
#   'ZoneName': u''},
#  u'addis ababa__addis ababa____': {'Area_km2': 543.0859458141679,
#   'LatCenter': 8.96289341830333,
#   'LonCenter': 38.786080227245954,
#   'RegionName': u'addis ababa',
#   'WoredaName': u'',
#   'ZoneName': u'addis ababa'},
#  u'addis ababa__addis ababa__addis ketema__': {'Area_km2': 7.385986178443729,
#   'LatCenter': 9.036880802562553,
#   'LonCenter': 38.72702448706256,
#   'RegionName': u'addis ababa',
#   'WoredaName': u'addis ketema',
#   'ZoneName': u'addis ababa'},
#  u'addis ababa__addis ababa__akaki kality__': {'Area_km2': 128.2205870576507,
#   'LatCenter': 8.89748965884063,
#   'LonCenter': 38.80513133195656,
#   'RegionName': u'addis ababa',
#   'WoredaName': u'akaki kality',
#   'ZoneName': u'addis ababa'},
#  u'addis ababa__addis ababa__arada__': {'Area_km2': 9.261943452128762,
#   'LatCenter': 9.035817410764757,
#   'LonCenter': 38.75469862564711,
#   'RegionName': u'addis ababa',
#   'WoredaName': u'arada',
#   'ZoneName': u'addis ababa'},
#  u'addis ababa__addis ababa__bole__': {'Area_km2': 128.7884598346195,
#   'LatCenter': 8.976621100054592,
#   'LonCenter': 38.83427858463643,
#   'RegionName': u'addis ababa',
#   'WoredaName': u'bole',
#   'ZoneName': u'addis ababa'},
#  u'addis ababa__addis ababa__gulele__': {'Area_km2': 31.911316896684763,
#   'LatCenter': 9.070694488379356,
#   'LonCenter': 38.74856858613799,
#   'RegionName': u'addis ababa',
#   'WoredaName': u'gulele',
#   'ZoneName': u'addis ababa'},
#  u'addis ababa__addis ababa__kirkos__': {'Area_km2': 14.524461575510417,
#   'LatCenter': 9.002919641894792,
#   'LonCenter': 38.76018890421058,
#   'RegionName': u'addis ababa',
#   'WoredaName': u'kirkos',
#   'ZoneName': u'addis ababa'},
#  u'addis ababa__addis ababa__kolfe keraniyo__': {'Area_km2': 66.22398161664465,
#   'LatCenter': 9.014116720145884,
#   'LonCenter': 38.68809449285422,
#   'RegionName': u'addis ababa',
#   'WoredaName': u'kolfe keraniyo',
#   'ZoneName': u'addis ababa'},
#  u'addis ababa__addis ababa__lideta__': {'Area_km2': 11.041834021189796,
#   'LatCenter': 9.01144401805268,
#   'LonCenter': 38.73032014084217,
#   'RegionName': u'addis ababa',
#   'WoredaName': u'lideta',
#   'ZoneName': u'addis ababa'},
#  u'addis ababa__addis ababa__nefas silk lafto__': {'Area_km2': 58.70445494901413,
#   'LatCenter': 8.954212999630482,
#   'LonCenter': 38.73226571547831,
#   'RegionName': u'addis ababa',
#   'WoredaName': u'nefas silk lafto',
#   'ZoneName': u'addis ababa'},
#  u'addis ababa__addis ababa__yeka__': {'Area_km2': 87.02292023228165,
#   'LatCenter': 9.047489096133384,
#   'LonCenter': 38.822680844266735,
#   'RegionName': u'addis ababa',
#   'WoredaName': u'yeka',
#   'ZoneName': u'addis ababa'},
#  u'afar______': {'Area_km2': 95466.9058791291,
#   'LatCenter': 11.90627151151676,
#   'LonCenter': 40.19547889582188,
#   'RegionName': u'afar',
#   'WoredaName': u'',
#   'ZoneName': u''},
#  u'afar__zone 01 - awsi____': {'Area_km2': 34715.3201122545,
#   'LatCenter': 11.89921813098562,
#   'LonCenter': 41.07879218396159,
#   'RegionName': u'afar',
#   'WoredaName': u'',
#   'ZoneName': u'zone 01 - awsi'},
#  u'afar__zone 01 - awsi__adeare__': {'Area_km2': 1386.792006172886,
#   'LatCenter': 11.318437704604216,
#   'LonCenter': 40.397694667895884,
#   'RegionName': u'afar',
#   'WoredaName': u'adeare',
#   'ZoneName': u'zone 01 - awsi'},
#  u'afar__zone 01 - awsi__afambo__': {'Area_km2': 2052.0194771508995,
#   'LatCenter': 11.25828165874473,
#   'LonCenter': 41.62913701921281,
#   'RegionName': u'afar',
#   'WoredaName': u'afambo',
#   'ZoneName': u'zone 01 - awsi'},
#  u'afar__zone 01 - awsi__aysaita__': {'Area_km2': 1359.246512676065,
#   'LatCenter': 11.54252251850774,
#   'LonCenter': 41.521681827861606,
#   'RegionName': u'afar',
#   'WoredaName': u'aysaita',
#   'ZoneName': u'zone 01 - awsi'},
#  u'afar__zone 01 - awsi__bidu__': {'Area_km2': 4542.030909087015,
#   'LatCenter': 13.033594127837887,
#   'LonCenter': 41.48588360308112,
#   'RegionName': u'afar',
#   'WoredaName': u'bidu',
#   'ZoneName': u'zone 01 - awsi'},
#  u'afar__zone 01 - awsi__chifra__': {'Area_km2': 3298.942318552028,
#   'LatCenter': 11.58728471063296,
#   'LonCenter': 40.32792407375952,
#   'RegionName': u'afar',
#   'WoredaName': u'chifra',
#   'ZoneName': u'zone 01 - awsi'},
#  u'afar__zone 01 - awsi__dubti__': {'Area_km2': 6173.1831889467,
#   'LatCenter': 11.728044445635767,
#   'LonCenter': 41.08656358570006,
#   'RegionName': u'afar',
#   'WoredaName': u'dubti',
#   'ZoneName': u'zone 01 - awsi'},
#  u'afar__zone 01 - awsi__elidear__': {'Area_km2': 11897.472458699438,
#   'LatCenter': 12.296433792344585,
#   'LonCenter': 41.67033025373115,
#   'RegionName': u'afar',
#   'WoredaName': u'elidear',
#   'ZoneName': u'zone 01 - awsi'},
#  u'afar__zone 01 - awsi__kori__': {'Area_km2': 5142.534416502841,
#   'LatCenter': 12.409731852850046,
#   'LonCenter': 40.983493516270066,
#   'RegionName': u'afar',
#   'WoredaName': u'kori',
#   'ZoneName': u'zone 01 - awsi'},
#  u'afar__zone 01 - awsi__mille__': {'Area_km2': 3405.129733553402,
#   'LatCenter': 11.304775322258873,
#   'LonCenter': 40.9144839642824,
#   'RegionName': u'afar',
#   'WoredaName': u'mille',
#   'ZoneName': u'zone 01 - awsi'},
#  u'afar__zone 02 - kilbati____': {'Area_km2': 27833.713676489686,
#   'LatCenter': 13.638808802005098,
#   'LonCenter': 40.04789463822478,
#   'RegionName': u'afar',
#   'WoredaName': u'',
#   'ZoneName': u'zone 02 - kilbati'},
#  u'afar__zone 02 - kilbati__abeala__': {'Area_km2': 1221.663028753113,
#   'LatCenter': 13.333907197543258,
#   'LonCenter': 39.85210496193835,
#   'RegionName': u'afar',
#   'WoredaName': u'abeala',
#   'ZoneName': u'zone 02 - kilbati'},
#  u'afar__zone 02 - kilbati__afdera__': {'Area_km2': 7329.188554357893,
#   'LatCenter': 13.321982674256459,
#   'LonCenter': 40.83048320132057,
#   'RegionName': u'afar',
#   'WoredaName': u'afdera',
#   'ZoneName': u'zone 02 - kilbati'},
#  u'afar__zone 02 - kilbati__berhale__': {'Area_km2': 7138.593045741448,
#   'LatCenter': 13.744166642080405,
#   'LonCenter': 40.11259908485721,
#   'RegionName': u'afar',
#   'WoredaName': u'berhale',
#   'ZoneName': u'zone 02 - kilbati'},
#  u'afar__zone 02 - kilbati__dalole__': {'Area_km2': 3008.867097002233,
#   'LatCenter': 14.230059626138404,
#   'LonCenter': 39.9186544843271,
#   'RegionName': u'afar',
#   'WoredaName': u'dalole',
#   'ZoneName': u'zone 02 - kilbati'},
#  u'afar__zone 02 - kilbati__erbti__': {'Area_km2': 2472.1659751500897,
#   'LatCenter': 13.171784972214336,
#   'LonCenter': 40.433066323267894,
#   'RegionName': u'afar',
#   'WoredaName': u'erbti',
#   'ZoneName': u'zone 02 - kilbati'},
#  u'afar__zone 02 - kilbati__koneba__': {'Area_km2': 568.6363742539259,
#   'LatCenter': 13.891093282327914,
#   'LonCenter': 39.894802969868906,
#   'RegionName': u'afar',
#   'WoredaName': u'koneba',
#   'ZoneName': u'zone 02 - kilbati'},
#  u'afar__zone 02 - kilbati__megalle__': {'Area_km2': 1552.5686921437227,
#   'LatCenter': 13.02160779775286,
#   'LonCenter': 39.936264262191074,
#   'RegionName': u'afar',
#   'WoredaName': u'megalle',
#   'ZoneName': u'zone 02 - kilbati'},
#  u'afar__zone 03 - gabi____': {'Area_km2': 16676.57895033502,
#   'LatCenter': 9.848706597130336,
#   'LonCenter': 40.33351927759943,
#   'RegionName': u'afar',
#   'WoredaName': u'',
#   'ZoneName': u'zone 03 - gabi'},
#  u'afar__zone 03 - gabi__amibera__': {'Area_km2': 3941.472908632835,
#   'LatCenter': 9.503204494099341,
#   'LonCenter': 40.38501542609226,
#   'RegionName': u'afar',
#   'WoredaName': u'amibera',
#   'ZoneName': u'zone 03 - gabi'},
#  u'afar__zone 03 - gabi__argoba liyu__': {'Area_km2': 589.9615573992434,
#   'LatCenter': 9.519251186168585,
#   'LonCenter': 39.885074281236015,
#   'RegionName': u'afar',
#   'WoredaName': u'argoba liyu',
#   'ZoneName': u'zone 03 - gabi'},
#  u'afar__zone 03 - gabi__awash fentale__': {'Area_km2': 1064.4361838749164,
#   'LatCenter': 9.088914300289208,
#   'LonCenter': 39.99757668515669,
#   'RegionName': u'afar',
#   'WoredaName': u'awash fentale',
#   'ZoneName': u'zone 03 - gabi'},
#  u'afar__zone 03 - gabi__dulcha__': {'Area_km2': 1268.7357177135934,
#   'LatCenter': 9.501996962225855,
#   'LonCenter': 40.08171434868823,
#   'RegionName': u'afar',
#   'WoredaName': u'dulcha',
#   'ZoneName': u'zone 03 - gabi'},
#  u'afar__zone 03 - gabi__gelealu__': {'Area_km2': 1110.876645243829,
#   'LatCenter': 10.288274742904163,
#   'LonCenter': 40.464585021054845,
#   'RegionName': u'afar',
#   'WoredaName': u'gelealu',
#   'ZoneName': u'zone 03 - gabi'},
#  u'afar__zone 03 - gabi__gewane__': {'Area_km2': 8701.095937470553,
#   'LatCenter': 10.360149103467508,
#   'LonCenter': 40.716093452982285,
#   'RegionName': u'afar',
#   'WoredaName': u'gewane',
#   'ZoneName': u'zone 03 - gabi'},
#  u'afar__zone 04 - fenti____': {'Area_km2': 10805.499808010576,
#   'LatCenter': 12.326850477412844,
#   'LonCenter': 40.081797696837285,
#   'RegionName': u'afar',
#   'WoredaName': u'',
#   'ZoneName': u'zone 04 - fenti'},
#  u'afar__zone 04 - fenti__awora__': {'Area_km2': 3033.945156019608,
#   'LatCenter': 12.17416100438988,
#   'LonCenter': 40.434432959864466,
#   'RegionName': u'afar',
#   'WoredaName': u'awora',
#   'ZoneName': u'zone 04 - fenti'},
#  u'afar__zone 04 - fenti__ewa__': {'Area_km2': 1205.0528805171587,
#   'LatCenter': 11.896716139766712,
#   'LonCenter': 40.03413686683338,
#   'RegionName': u'afar',
#   'WoredaName': u'ewa',
#   'ZoneName': u'zone 04 - fenti'},
#  u'afar__zone 04 - fenti__golina__': {'Area_km2': 1157.5716935601074,
#   'LatCenter': 12.144779856828618,
#   'LonCenter': 39.94471086671434,
#   'RegionName': u'afar',
#   'WoredaName': u'golina',
#   'ZoneName': u'zone 04 - fenti'},
#  u'afar__zone 04 - fenti__teru__': {'Area_km2': 3680.496178977172,
#   'LatCenter': 12.62765244736848,
#   'LonCenter': 40.374434783175495,
#   'RegionName': u'afar',
#   'WoredaName': u'teru',
#   'ZoneName': u'zone 04 - fenti'},
#  u'afar__zone 04 - fenti__yallo__': {'Area_km2': 1728.4338989364392,
#   'LatCenter': 12.544536389467446,
#   'LonCenter': 39.949235651913106,
#   'RegionName': u'afar',
#   'WoredaName': u'yallo',
#   'ZoneName': u'zone 04 - fenti'},
#  u'afar__zone 05 - hari____': {'Area_km2': 5435.79333203982,
#   'LatCenter': 10.437976894224718,
#   'LonCenter': 40.21940218997804,
#   'RegionName': u'afar',
#   'WoredaName': u'',
#   'ZoneName': u'zone 05 - hari'},
#  u'afar__zone 05 - hari__dalifage__': {'Area_km2': 442.156115190771,
#   'LatCenter': 10.591904430152221,
#   'LonCenter': 40.25061745597832,
#   'RegionName': u'afar',
#   'WoredaName': u'dalifage',
#   'ZoneName': u'zone 05 - hari'},
#  u'afar__zone 05 - hari__dewe__': {'Area_km2': 1049.8339222853656,
#   'LatCenter': 10.79833386124055,
#   'LonCenter': 40.28602759451902,
#   'RegionName': u'afar',
#   'WoredaName': u'dewe',
#   'ZoneName': u'zone 05 - hari'},
#  u'afar__zone 05 - hari__hadlieala__': {'Area_km2': 1257.757353569025,
#   'LatCenter': 10.336481860243955,
#   'LonCenter': 40.28991465045128,
#   'RegionName': u'afar',
#   'WoredaName': u'hadlieala',
#   'ZoneName': u'zone 05 - hari'},
#  u'afar__zone 05 - hari__samurobi__': {'Area_km2': 1310.4039212510752,
#   'LatCenter': 9.922175703391808,
#   'LonCenter': 40.11575480493819,
#   'RegionName': u'afar',
#   'WoredaName': u'samurobi',
#   'ZoneName': u'zone 05 - hari'},
#  u'afar__zone 05 - hari__telalake__': {'Area_km2': 1375.6420197435684,
#   'LatCenter': 11.044000530701343,
#   'LonCenter': 40.32837170770136,
#   'RegionName': u'afar',
#   'WoredaName': u'telalake',
#   'ZoneName': u'zone 05 - hari'},
#  u'amhara______': {'Area_km2': 156602.50505051887,
#   'LatCenter': 11.25842978946545,
#   'LonCenter': 38.09221066689299,
#   'RegionName': u'amhara',
#   'WoredaName': u'',
#   'ZoneName': u''},
#  u'amhara__awi____': {'Area_km2': 9005.977419024983,
#   'LatCenter': 11.236298938494325,
#   'LonCenter': 36.56603701176552,
#   'RegionName': u'amhara',
#   'WoredaName': u'',
#   'ZoneName': u'awi'},
#  u'amhara__awi__ankesha guagusa__': {'Area_km2': 1065.1169005087809,
#   'LatCenter': 10.752874032789286,
#   'LonCenter': 36.77403357878929,
#   'RegionName': u'amhara',
#   'WoredaName': u'ankesha guagusa',
#   'ZoneName': u'awi'},
#  u'amhara__awi__banja shekudad__': {'Area_km2': 495.419948890655,
#   'LatCenter': 10.970239857116804,
#   'LonCenter': 36.89741491961425,
#   'RegionName': u'amhara',
#   'WoredaName': u'banja shekudad',
#   'ZoneName': u'awi'},
#  u'amhara__awi__dangla town__': {'Area_km2': 890.9403105867988,
#   'LatCenter': 11.227147819658592,
#   'LonCenter': 36.78969134197564,
#   'RegionName': u'amhara',
#   'WoredaName': u'dangla town',
#   'ZoneName': u'awi'},
#  u'amhara__awi__fagita lekoma__': {'Area_km2': 678.5230821651477,
#   'LatCenter': 11.080740584147588,
#   'LonCenter': 36.89640766455197,
#   'RegionName': u'amhara',
#   'WoredaName': u'fagita lekoma',
#   'ZoneName': u'awi'},
#  u'amhara__awi__guagusa shikuda__': {'Area_km2': 305.71415679465036,
#   'LatCenter': 10.817086513168046,
#   'LonCenter': 37.022521811208044,
#   'RegionName': u'amhara',
#   'WoredaName': u'guagusa shikuda',
#   'ZoneName': u'awi'},
#  u'amhara__awi__guangua__': {'Area_km2': 2345.22646835061,
#   'LatCenter': 10.785420712033794,
#   'LonCenter': 36.495478516809875,
#   'RegionName': u'amhara',
#   'WoredaName': u'guangua',
#   'ZoneName': u'awi'},
#  u'amhara__awi__jawi__': {'Area_km2': 3225.036551728308,
#   'LatCenter': 11.62324475995164,
#   'LonCenter': 36.4364835627053,
#   'RegionName': u'amhara',
#   'WoredaName': u'jawi',
#   'ZoneName': u'awi'},
#  u'amhara__east gojam____': {'Area_km2': 14343.61068200571,
#   'LatCenter': 10.537477865667928,
#   'LonCenter': 37.84184377851162,
#   'RegionName': u'amhara',
#   'WoredaName': u'',
#   'ZoneName': u'east gojam'},
#  u'amhara__east gojam__aneded__': {'Area_km2': 652.3113690993669,
#   'LatCenter': 10.164954961033217,
#   'LonCenter': 37.87920825540289,
#   'RegionName': u'amhara',
#   'WoredaName': u'aneded',
#   'ZoneName': u'east gojam'},
#  u'amhara__east gojam__awabel__': {'Area_km2': 827.4033446834728,
#   'LatCenter': 10.252971993875596,
#   'LonCenter': 37.98381398192893,
#   'RegionName': u'amhara',
#   'WoredaName': u'awabel',
#   'ZoneName': u'east gojam'},
#  u'amhara__east gojam__baso liben__': {'Area_km2': 1119.6684376753717,
#   'LatCenter': 10.025119109627706,
#   'LonCenter': 37.703781107776635,
#   'RegionName': u'amhara',
#   'WoredaName': u'baso liben',
#   'ZoneName': u'east gojam'},
#  u'amhara__east gojam__bibugn__': {'Area_km2': 399.0045974085691,
#   'LatCenter': 10.844756983735495,
#   'LonCenter': 37.746352932592636,
#   'RegionName': u'amhara',
#   'WoredaName': u'bibugn',
#   'ZoneName': u'east gojam'},
#  u'amhara__east gojam__debay tilatgin__': {'Area_km2': 633.1926700881039,
#   'LatCenter': 10.525342723269992,
#   'LonCenter': 37.99888895972398,
#   'RegionName': u'amhara',
#   'WoredaName': u'debay tilatgin',
#   'ZoneName': u'east gojam'},
#  u'amhara__east gojam__debre elias__': {'Area_km2': 1165.2086627331364,
#   'LatCenter': 10.233275403918698,
#   'LonCenter': 37.30644754526321,
#   'RegionName': u'amhara',
#   'WoredaName': u'debre elias',
#   'ZoneName': u'east gojam'},
#  u'amhara__east gojam__dejen__': {'Area_km2': 633.4662713127373,
#   'LatCenter': 10.204638552549065,
#   'LonCenter': 38.161620329294145,
#   'RegionName': u'amhara',
#   'WoredaName': u'dejen',
#   'ZoneName': u'east gojam'},
#  u'amhara__east gojam__enarj enawga__': {'Area_km2': 951.1670177072723,
#   'LatCenter': 10.678928314042818,
#   'LonCenter': 38.216364606042845,
#   'RegionName': u'amhara',
#   'WoredaName': u'enarj enawga',
#   'ZoneName': u'east gojam'},
#  u'amhara__east gojam__enebse sar midir__': {'Area_km2': 1080.3812143429516,
#   'LatCenter': 10.863907136058183,
#   'LonCenter': 38.39739699730818,
#   'RegionName': u'amhara',
#   'WoredaName': u'enebse sar midir',
#   'ZoneName': u'east gojam'},
#  u'amhara__east gojam__enemay__': {'Area_km2': 729.8196355077811,
#   'LatCenter': 10.501292267954826,
#   'LonCenter': 38.17086471847744,
#   'RegionName': u'amhara',
#   'WoredaName': u'enemay',
#   'ZoneName': u'east gojam'},
#  u'amhara__east gojam__goncha siso enese__': {'Area_km2': 1069.4654256252957,
#   'LatCenter': 10.962677141836785,
#   'LonCenter': 38.174883234352116,
#   'RegionName': u'amhara',
#   'WoredaName': u'goncha siso enese',
#   'ZoneName': u'east gojam'},
#  u'amhara__east gojam__gozamin__': {'Area_km2': 1030.0288108723473,
#   'LatCenter': 10.25007999028383,
#   'LonCenter': 37.607967146198256,
#   'RegionName': u'amhara',
#   'WoredaName': u'gozamin',
#   'ZoneName': u'east gojam'},
#  u'amhara__east gojam__hulet eju enese__': {'Area_km2': 1453.7999979403023,
#   'LatCenter': 10.986293621522869,
#   'LonCenter': 37.896097407107916,
#   'RegionName': u'amhara',
#   'WoredaName': u'hulet eju enese',
#   'ZoneName': u'east gojam'},
#  u'amhara__east gojam__machakel__': {'Area_km2': 670.2421326188444,
#   'LatCenter': 10.482997119948543,
#   'LonCenter': 37.52761030847645,
#   'RegionName': u'amhara',
#   'WoredaName': u'machakel',
#   'ZoneName': u'east gojam'},
#  u'amhara__east gojam__shebel berenta__': {'Area_km2': 906.6969957279941,
#   'LatCenter': 10.326183344577368,
#   'LonCenter': 38.36309132024231,
#   'RegionName': u'amhara',
#   'WoredaName': u'shebel berenta',
#   'ZoneName': u'east gojam'},
#  u'amhara__east gojam__sinan__': {'Area_km2': 780.2213218269088,
#   'LatCenter': 10.505842180524317,
#   'LonCenter': 37.75668557816024,
#   'RegionName': u'amhara',
#   'WoredaName': u'sinan',
#   'ZoneName': u'east gojam'},
#  u'amhara__north gondar____': {'Area_km2': 43466.23057118326,
#   'LatCenter': 12.711042020591405,
#   'LonCenter': 37.443146460465854,
#   'RegionName': u'amhara',
#   'WoredaName': u'',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__adi arkay__': {'Area_km2': 1322.5590357961942,
#   'LatCenter': 13.387728735140332,
#   'LonCenter': 37.96130638817273,
#   'RegionName': u'amhara',
#   'WoredaName': u'adi arkay',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__alefa__': {'Area_km2': 1903.4372987936135,
#   'LatCenter': 11.929703421357937,
#   'LonCenter': 36.723637394031634,
#   'RegionName': u'amhara',
#   'WoredaName': u'alefa',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__beyeda__': {'Area_km2': 1200.9147770335449,
#   'LatCenter': 13.237987543431581,
#   'LonCenter': 38.482026081340344,
#   'RegionName': u'amhara',
#   'WoredaName': u'beyeda',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__chilga__': {'Area_km2': 3235.076111634756,
#   'LatCenter': 12.582762655992617,
#   'LonCenter': 36.86040656682188,
#   'RegionName': u'amhara',
#   'WoredaName': u'chilga',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__dabat__': {'Area_km2': 1220.5226504276618,
#   'LatCenter': 13.0601366979587,
#   'LonCenter': 37.69476563588727,
#   'RegionName': u'amhara',
#   'WoredaName': u'dabat',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__debark town__': {'Area_km2': 1570.601359456358,
#   'LatCenter': 13.19280990409743,
#   'LonCenter': 37.86339458683423,
#   'RegionName': u'amhara',
#   'WoredaName': u'debark town',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__dembia__': {'Area_km2': 1308.56905840023,
#   'LatCenter': 12.397916758874002,
#   'LonCenter': 37.26279378826895,
#   'RegionName': u'amhara',
#   'WoredaName': u'dembia',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__gondar zuria__': {'Area_km2': 1436.3641798600743,
#   'LatCenter': 12.412830861185862,
#   'LonCenter': 37.57205628653719,
#   'RegionName': u'amhara',
#   'WoredaName': u'gondar zuria',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__janamora__': {'Area_km2': 1807.2806656283256,
#   'LatCenter': 13.014210301286258,
#   'LonCenter': 38.19546834042419,
#   'RegionName': u'amhara',
#   'WoredaName': u'janamora',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__lay armachiho__': {'Area_km2': 1051.0488895397789,
#   'LatCenter': 12.768637025143537,
#   'LonCenter': 37.36388918166092,
#   'RegionName': u'amhara',
#   'WoredaName': u'lay armachiho',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__metema__': {'Area_km2': 3894.3140443799043,
#   'LatCenter': 12.692505390669512,
#   'LonCenter': 36.44787742012975,
#   'RegionName': u'amhara',
#   'WoredaName': u'metema',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__mirab armachiho__': {'Area_km2': 2786.1487032537298,
#   'LatCenter': 13.200333416314807,
#   'LonCenter': 36.54198186029188,
#   'RegionName': u'amhara',
#   'WoredaName': u'mirab armachiho',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__mirab belesa__': {'Area_km2': 1157.145299753262,
#   'LatCenter': 12.467968255105315,
#   'LonCenter': 37.845974447122884,
#   'RegionName': u'amhara',
#   'WoredaName': u'mirab belesa',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__misrak belesa__': {'Area_km2': 1913.2118994093141,
#   'LatCenter': 12.51058719084762,
#   'LonCenter': 38.15649422172125,
#   'RegionName': u'amhara',
#   'WoredaName': u'misrak belesa',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__quara__': {'Area_km2': 8600.787501577157,
#   'LatCenter': 12.217444753620745,
#   'LonCenter': 36.124962466890864,
#   'RegionName': u'amhara',
#   'WoredaName': u'quara',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__tach armachiho__': {'Area_km2': 2633.903755529752,
#   'LatCenter': 13.036627858369195,
#   'LonCenter': 37.08293590968049,
#   'RegionName': u'amhara',
#   'WoredaName': u'tach armachiho',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__takusa__': {'Area_km2': 1897.0784023831393,
#   'LatCenter': 12.224294390214334,
#   'LonCenter': 36.76026088947966,
#   'RegionName': u'amhara',
#   'WoredaName': u'takusa',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__tegede__': {'Area_km2': 1962.2621453713703,
#   'LatCenter': 13.317522848432498,
#   'LonCenter': 37.006779347459506,
#   'RegionName': u'amhara',
#   'WoredaName': u'tegede',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__telemt__': {'Area_km2': 646.6928774229026,
#   'LatCenter': 13.460427534168366,
#   'LonCenter': 38.4399171930347,
#   'RegionName': u'amhara',
#   'WoredaName': u'telemt',
#   'ZoneName': u'north gondar'},
#  u'amhara__north gondar__wogera__': {'Area_km2': 1918.3119155316053,
#   'LatCenter': 12.781151447070329,
#   'LonCenter': 37.77750323043135,
#   'RegionName': u'amhara',
#   'WoredaName': u'wogera',
#   'ZoneName': u'north gondar'},
#  u'amhara__north shewa____': {'Area_km2': 16286.47937997835,
#   'LatCenter': 9.915844828120536,
#   'LonCenter': 39.40778823762208,
#   'RegionName': u'amhara',
#   'WoredaName': u'',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__angolela tera__': {'Area_km2': 840.5306160670536,
#   'LatCenter': 9.449057667349601,
#   'LonCenter': 39.450933212716876,
#   'RegionName': u'amhara',
#   'WoredaName': u'angolela tera',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__ankober__': {'Area_km2': 708.57339169806,
#   'LatCenter': 9.568626758965861,
#   'LonCenter': 39.76166865906841,
#   'RegionName': u'amhara',
#   'WoredaName': u'ankober',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__antsokya gemza__': {'Area_km2': 382.4745998802829,
#   'LatCenter': 10.589486130652233,
#   'LonCenter': 39.80935610913773,
#   'RegionName': u'amhara',
#   'WoredaName': u'antsokya gemza',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__asagirt__': {'Area_km2': 520.0662250871677,
#   'LatCenter': 9.329207495657577,
#   'LonCenter': 39.601489401048,
#   'RegionName': u'amhara',
#   'WoredaName': u'asagirt',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__basona werana__': {'Area_km2': 1360.968320201007,
#   'LatCenter': 9.727441649385469,
#   'LonCenter': 39.50005280159033,
#   'RegionName': u'amhara',
#   'WoredaName': u'basona werana',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__berehet__': {'Area_km2': 781.3340079309717,
#   'LatCenter': 9.183896905580928,
#   'LonCenter': 39.66508211620595,
#   'RegionName': u'amhara',
#   'WoredaName': u'berehet',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__efratana gidim__': {'Area_km2': 510.3461453014354,
#   'LatCenter': 10.300001014376512,
#   'LonCenter': 39.8933839891412,
#   'RegionName': u'amhara',
#   'WoredaName': u'efratana gidim',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__ensaro__': {'Area_km2': 401.1479391515232,
#   'LatCenter': 9.829039964737337,
#   'LonCenter': 38.900480414211906,
#   'RegionName': u'amhara',
#   'WoredaName': u'ensaro',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__gishe rabel__': {'Area_km2': 676.9285348979981,
#   'LatCenter': 10.58632647047776,
#   'LonCenter': 39.60121330370069,
#   'RegionName': u'amhara',
#   'WoredaName': u'gishe rabel',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__hagere mariam kesem__': {'Area_km2': 692.5482917585799,
#   'LatCenter': 9.188603456226945,
#   'LonCenter': 39.39396647903366,
#   'RegionName': u'amhara',
#   'WoredaName': u'hagere mariam kesem',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__kewot__': {'Area_km2': 740.6995480425852,
#   'LatCenter': 9.987724673986719,
#   'LonCenter': 39.8717462552534,
#   'RegionName': u'amhara',
#   'WoredaName': u'kewot',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__menz gera midir__': {'Area_km2': 1103.3613328479248,
#   'LatCenter': 10.354754179046346,
#   'LonCenter': 39.61873472354173,
#   'RegionName': u'amhara',
#   'WoredaName': u'menz gera midir',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__menz keya gebreal__': {'Area_km2': 548.9009417415285,
#   'LatCenter': 10.183433070248467,
#   'LonCenter': 39.374068814993684,
#   'RegionName': u'amhara',
#   'WoredaName': u'menz keya gebreal',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__menz lalo midir__': {'Area_km2': 378.02597514613564,
#   'LatCenter': 10.119401092964841,
#   'LonCenter': 39.50697619109866,
#   'RegionName': u'amhara',
#   'WoredaName': u'menz lalo midir',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__menz mama midir__': {'Area_km2': 645.3441459112021,
#   'LatCenter': 10.093347828393842,
#   'LonCenter': 39.61133412377205,
#   'RegionName': u'amhara',
#   'WoredaName': u'menz mama midir',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__merhabete__': {'Area_km2': 1029.3578555046627,
#   'LatCenter': 10.056123357019098,
#   'LonCenter': 38.97208343232385,
#   'RegionName': u'amhara',
#   'WoredaName': u'merhabete',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__mida woremo__': {'Area_km2': 852.0841538436079,
#   'LatCenter': 10.249584271284931,
#   'LonCenter': 39.01861427948262,
#   'RegionName': u'amhara',
#   'WoredaName': u'mida woremo',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__minjar shenkura__': {'Area_km2': 1708.3282637111045,
#   'LatCenter': 8.950712518260323,
#   'LonCenter': 39.49952735610278,
#   'RegionName': u'amhara',
#   'WoredaName': u'minjar shenkura',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__mojana wodera__': {'Area_km2': 625.2886013222509,
#   'LatCenter': 9.926590795113144,
#   'LonCenter': 39.536851907392915,
#   'RegionName': u'amhara',
#   'WoredaName': u'mojana wodera',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__moretna jiru__': {'Area_km2': 708.822595207377,
#   'LatCenter': 9.938803859689495,
#   'LonCenter': 39.144461646391335,
#   'RegionName': u'amhara',
#   'WoredaName': u'moretna jiru',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__siya deberna wayu__': {'Area_km2': 477.4645230517035,
#   'LatCenter': 9.781456678174198,
#   'LonCenter': 39.1865248901742,
#   'RegionName': u'amhara',
#   'WoredaName': u'siya deberna wayu',
#   'ZoneName': u'north shewa'},
#  u'amhara__north shewa__tarma ber__': {'Area_km2': 593.8833716742365,
#   'LatCenter': 9.890235277766351,
#   'LonCenter': 39.78883424403809,
#   'RegionName': u'amhara',
#   'WoredaName': u'tarma ber',
#   'ZoneName': u'north shewa'},
#  u'amhara__north wollo____': {'Area_km2': 12296.779487076357,
#   'LatCenter': 11.870194048296566,
#   'LonCenter': 39.14440443452499,
#   'RegionName': u'amhara',
#   'WoredaName': u'',
#   'ZoneName': u'north wollo'},
#  u'amhara__north wollo__bugna__': {'Area_km2': 1201.7470985083014,
#   'LatCenter': 12.165349389015674,
#   'LonCenter': 38.69999347680214,
#   'RegionName': u'amhara',
#   'WoredaName': u'bugna',
#   'ZoneName': u'north wollo'},
#  u'amhara__north wollo__dawunt__': {'Area_km2': 622.4868348319309,
#   'LatCenter': 11.476494389824369,
#   'LonCenter': 38.82973453860143,
#   'RegionName': u'amhara',
#   'WoredaName': u'dawunt',
#   'ZoneName': u'north wollo'},
#  u'amhara__north wollo__gidan__': {'Area_km2': 1238.1049159766378,
#   'LatCenter': 12.071030536291348,
#   'LonCenter': 39.32006220050876,
#   'RegionName': u'amhara',
#   'WoredaName': u'gidan',
#   'ZoneName': u'north wollo'},
#  u'amhara__north wollo__gubalafto__': {'Area_km2': 1016.033713580836,
#   'LatCenter': 11.794259225389705,
#   'LonCenter': 39.481165320427635,
#   'RegionName': u'amhara',
#   'WoredaName': u'gubalafto',
#   'ZoneName': u'north wollo'},
#  u'amhara__north wollo__habru__': {'Area_km2': 1359.7352089501062,
#   'LatCenter': 11.689251791336591,
#   'LonCenter': 39.742483108485644,
#   'RegionName': u'amhara',
#   'WoredaName': u'habru',
#   'ZoneName': u'north wollo'},
#  u'amhara__north wollo__kobo town__': {'Area_km2': 1956.1824583811406,
#   'LatCenter': 12.089013998854588,
#   'LonCenter': 39.61247749987278,
#   'RegionName': u'amhara',
#   'WoredaName': u'kobo town',
#   'ZoneName': u'north wollo'},
#  u'amhara__north wollo__lasta__': {'Area_km2': 1083.148073444236,
#   'LatCenter': 12.087000632682255,
#   'LonCenter': 39.00652659631786,
#   'RegionName': u'amhara',
#   'WoredaName': u'lasta',
#   'ZoneName': u'north wollo'},
#  u'amhara__north wollo__meket__': {'Area_km2': 1910.6746771403627,
#   'LatCenter': 11.810345408020185,
#   'LonCenter': 38.86078878055038,
#   'RegionName': u'amhara',
#   'WoredaName': u'meket',
#   'ZoneName': u'north wollo'},
#  u'amhara__north wollo__wadla__': {'Area_km2': 846.9166362221166,
#   'LatCenter': 11.667890303116556,
#   'LonCenter': 38.99926145085442,
#   'RegionName': u'amhara',
#   'WoredaName': u'wadla',
#   'ZoneName': u'north wollo'},
#  u'amhara__oromia special zone____': {'Area_km2': 3804.976211581669,
#   'LatCenter': 10.788774874083218,
#   'LonCenter': 39.947832659748535,
#   'RegionName': u'amhara',
#   'WoredaName': u'',
#   'ZoneName': u'oromia special zone'},
#  u'amhara__oromia special zone__artuma fursi__': {'Area_km2': 644.6657917128994,
#   'LatCenter': 10.533318984577827,
#   'LonCenter': 39.97067558406674,
#   'RegionName': u'amhara',
#   'WoredaName': u'artuma fursi',
#   'ZoneName': u'oromia special zone'},
#  u'amhara__oromia special zone__bati zuria__': {'Area_km2': 1150.5710721938822,
#   'LatCenter': 11.155016994976654,
#   'LonCenter': 40.03161981133338,
#   'RegionName': u'amhara',
#   'WoredaName': u'bati zuria',
#   'ZoneName': u'oromia special zone'},
#  u'amhara__oromia special zone__dawa chefa__': {'Area_km2': 666.7737216495999,
#   'LatCenter': 10.774671921989688,
#   'LonCenter': 39.83824718654927,
#   'RegionName': u'amhara',
#   'WoredaName': u'dawa chefa',
#   'ZoneName': u'oromia special zone'},
#  u'amhara__oromia special zone__dewe harewa__': {'Area_km2': 477.84763764115434,
#   'LatCenter': 10.767886784394276,
#   'LonCenter': 40.0401348587212,
#   'RegionName': u'amhara',
#   'WoredaName': u'dewe harewa',
#   'ZoneName': u'oromia special zone'},
#  u'amhara__oromia special zone__jile timuga__': {'Area_km2': 865.1179883841739,
#   'LatCenter': 10.277790405475853,
#   'LonCenter': 40.00610119430648,
#   'RegionName': u'amhara',
#   'WoredaName': u'jile timuga',
#   'ZoneName': u'oromia special zone'},
#  u'amhara__south gondar____': {'Area_km2': 14242.718655551735,
#   'LatCenter': 11.830919296373647,
#   'LonCenter': 38.08754660473351,
#   'RegionName': u'amhara',
#   'WoredaName': u'',
#   'ZoneName': u'south gondar'},
#  u'amhara__south gondar__andabet__': {'Area_km2': 928.9807723763975,
#   'LatCenter': 11.394986239027217,
#   'LonCenter': 37.93211719128267,
#   'RegionName': u'amhara',
#   'WoredaName': u'andabet',
#   'ZoneName': u'south gondar'},
#  u'amhara__south gondar__dera__': {'Area_km2': 1578.2457561443355,
#   'LatCenter': 11.619055777187972,
#   'LonCenter': 37.66069196987255,
#   'RegionName': u'amhara',
#   'WoredaName': u'dera',
#   'ZoneName': u'south gondar'},
#  u'amhara__south gondar__ebinat__': {'Area_km2': 2528.163219907491,
#   'LatCenter': 12.212809210539787,
#   'LonCenter': 38.221790738139156,
#   'RegionName': u'amhara',
#   'WoredaName': u'ebinat',
#   'ZoneName': u'south gondar'},
#  u'amhara__south gondar__este__': {'Area_km2': 1274.1038239174813,
#   'LatCenter': 11.494594773464547,
#   'LonCenter': 38.06781830760061,
#   'RegionName': u'amhara',
#   'WoredaName': u'este',
#   'ZoneName': u'south gondar'},
#  u'amhara__south gondar__farta__': {'Area_km2': 1220.4774297882952,
#   'LatCenter': 11.837870286078477,
#   'LonCenter': 38.0630895483922,
#   'RegionName': u'amhara',
#   'WoredaName': u'farta',
#   'ZoneName': u'south gondar'},
#  u'amhara__south gondar__fogera__': {'Area_km2': 1105.0745826617015,
#   'LatCenter': 11.878133255290644,
#   'LonCenter': 37.754044347188085,
#   'RegionName': u'amhara',
#   'WoredaName': u'fogera',
#   'ZoneName': u'south gondar'},
#  u'amhara__south gondar__lay gayint__': {'Area_km2': 1539.0034655553193,
#   'LatCenter': 11.822698417748143,
#   'LonCenter': 38.429693151316876,
#   'RegionName': u'amhara',
#   'WoredaName': u'lay gayint',
#   'ZoneName': u'south gondar'},
#  u'amhara__south gondar__libo kemkem__': {'Area_km2': 1022.4499982940433,
#   'LatCenter': 12.162243511572042,
#   'LonCenter': 37.76696395962004,
#   'RegionName': u'amhara',
#   'WoredaName': u'libo kemkem',
#   'ZoneName': u'south gondar'},
#  u'amhara__south gondar__simada__': {'Area_km2': 2243.026413975446,
#   'LatCenter': 11.329885520941655,
#   'LonCenter': 38.356421213865,
#   'RegionName': u'amhara',
#   'WoredaName': u'simada',
#   'ZoneName': u'south gondar'},
#  u'amhara__south gondar__tach gayint__': {'Area_km2': 803.1931929312689,
#   'LatCenter': 11.5703626637556,
#   'LonCenter': 38.5356945703667,
#   'RegionName': u'amhara',
#   'WoredaName': u'tach gayint',
#   'ZoneName': u'south gondar'},
#  u'amhara__south wollo____': {'Area_km2': 17332.807051097327,
#   'LatCenter': 10.954927042670429,
#   'LonCenter': 39.27096496119383,
#   'RegionName': u'amhara',
#   'WoredaName': u'',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__albuko__': {'Area_km2': 467.83933062148435,
#   'LatCenter': 10.823317042006382,
#   'LonCenter': 39.61762794509497,
#   'RegionName': u'amhara',
#   'WoredaName': u'albuko',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__ambassel__': {'Area_km2': 908.2929328492656,
#   'LatCenter': 11.49997623556481,
#   'LonCenter': 39.49885995716586,
#   'RegionName': u'amhara',
#   'WoredaName': u'ambassel',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__argoba__': {'Area_km2': 311.49114507343194,
#   'LatCenter': 10.927588766145346,
#   'LonCenter': 39.98265016688038,
#   'RegionName': u'amhara',
#   'WoredaName': u'argoba',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__borena__': {'Area_km2': 995.5133858321424,
#   'LatCenter': 10.73696823514922,
#   'LonCenter': 38.68149035578458,
#   'RegionName': u'amhara',
#   'WoredaName': u'borena',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__delanta__': {'Area_km2': 1061.749870040633,
#   'LatCenter': 11.615038058116875,
#   'LonCenter': 39.21210928576641,
#   'RegionName': u'amhara',
#   'WoredaName': u'delanta',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__dessie zuria__': {'Area_km2': 1222.6228572337554,
#   'LatCenter': 11.249652095700048,
#   'LonCenter': 39.60253557370005,
#   'RegionName': u'amhara',
#   'WoredaName': u'dessie zuria',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__jamma__': {'Area_km2': 1050.478027144225,
#   'LatCenter': 10.382138099748794,
#   'LonCenter': 39.24917737320608,
#   'RegionName': u'amhara',
#   'WoredaName': u'jamma',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__kallu__': {'Area_km2': 938.0447158267673,
#   'LatCenter': 11.06319004179841,
#   'LonCenter': 39.82675070473261,
#   'RegionName': u'amhara',
#   'WoredaName': u'kallu',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__kelala__': {'Area_km2': 1595.631298019033,
#   'LatCenter': 10.557710637424293,
#   'LonCenter': 38.9990198794416,
#   'RegionName': u'amhara',
#   'WoredaName': u'kelala',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__kutaber__': {'Area_km2': 743.8374473746348,
#   'LatCenter': 11.265679841994123,
#   'LonCenter': 39.46971094299415,
#   'RegionName': u'amhara',
#   'WoredaName': u'kutaber',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__legambo__': {'Area_km2': 995.8291638422311,
#   'LatCenter': 10.853936544951662,
#   'LonCenter': 39.17721328317345,
#   'RegionName': u'amhara',
#   'WoredaName': u'legambo',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__legehida__': {'Area_km2': 388.76300943497233,
#   'LatCenter': 10.699287037822483,
#   'LonCenter': 39.28602727626175,
#   'RegionName': u'amhara',
#   'WoredaName': u'legehida',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__mehal sayint__': {'Area_km2': 621.5027851066726,
#   'LatCenter': 10.924451378684253,
#   'LonCenter': 38.65211668184215,
#   'RegionName': u'amhara',
#   'WoredaName': u'mehal sayint',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__mekdela__': {'Area_km2': 1484.1653343399541,
#   'LatCenter': 11.245795488740477,
#   'LonCenter': 38.92554505330218,
#   'RegionName': u'amhara',
#   'WoredaName': u'mekdela',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__sayint__': {'Area_km2': 1482.542669835152,
#   'LatCenter': 11.048367365087357,
#   'LonCenter': 38.772830269008,
#   'RegionName': u'amhara',
#   'WoredaName': u'sayint',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__tehuledere__': {'Area_km2': 461.0123209450378,
#   'LatCenter': 11.31505391889318,
#   'LonCenter': 39.69481272170998,
#   'RegionName': u'amhara',
#   'WoredaName': u'tehuledere',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__tenta__': {'Area_km2': 1339.607669258192,
#   'LatCenter': 11.199658730566844,
#   'LonCenter': 39.223142936696426,
#   'RegionName': u'amhara',
#   'WoredaName': u'tenta',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__wogidi__': {'Area_km2': 1109.1741584859196,
#   'LatCenter': 10.561570238294731,
#   'LonCenter': 38.70527434198073,
#   'RegionName': u'amhara',
#   'WoredaName': u'wogidi',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__worebabo__': {'Area_km2': 757.9006300084733,
#   'LatCenter': 11.41767042219702,
#   'LonCenter': 39.875901057818254,
#   'RegionName': u'amhara',
#   'WoredaName': u'worebabo',
#   'ZoneName': u'south wollo'},
#  u'amhara__south wollo__woreilu__': {'Area_km2': 770.0493149394158,
#   'LatCenter': 10.668011219614089,
#   'LonCenter': 39.451286809671096,
#   'RegionName': u'amhara',
#   'WoredaName': u'woreilu',
#   'ZoneName': u'south wollo'},
#  u'amhara__wag himra____': {'Area_km2': 8995.164362161393,
#   'LatCenter': 12.704278917545667,
#   'LonCenter': 38.77433186234709,
#   'RegionName': u'amhara',
#   'WoredaName': u'',
#   'ZoneName': u'wag himra'},
#  u'amhara__wag himra__abergele__': {'Area_km2': 1517.5298586362687,
#   'LatCenter': 13.052327948043217,
#   'LonCenter': 38.89227162060799,
#   'RegionName': u'amhara',
#   'WoredaName': u'abergele',
#   'ZoneName': u'wag himra'},
#  u'amhara__wag himra__dehana__': {'Area_km2': 1699.5268128897203,
#   'LatCenter': 12.442937163900941,
#   'LonCenter': 38.668435448810875,
#   'RegionName': u'amhara',
#   'WoredaName': u'dehana',
#   'ZoneName': u'wag himra'},
#  u'amhara__wag himra__gazgibla__': {'Area_km2': 957.7747537751287,
#   'LatCenter': 12.31882840110665,
#   'LonCenter': 39.06066586289347,
#   'RegionName': u'amhara',
#   'WoredaName': u'gazgibla',
#   'ZoneName': u'wag himra'},
#  u'amhara__wag himra__sehala__': {'Area_km2': 1157.6574440362053,
#   'LatCenter': 12.946127425112056,
#   'LonCenter': 38.496083553472054,
#   'RegionName': u'amhara',
#   'WoredaName': u'sehala',
#   'ZoneName': u'wag himra'},
#  u'amhara__wag himra__sekota town__': {'Area_km2': 1956.4146110543666,
#   'LatCenter': 12.635296475430701,
#   'LonCenter': 39.07194709623731,
#   'RegionName': u'amhara',
#   'WoredaName': u'sekota town',
#   'ZoneName': u'wag himra'},
#  u'amhara__wag himra__ziquala__': {'Area_km2': 1706.2608817695525,
#   'LatCenter': 12.824861508692367,
#   'LonCenter': 38.70501360200337,
#   'RegionName': u'amhara',
#   'WoredaName': u'ziquala',
#   'ZoneName': u'wag himra'},
#  u'amhara__west gojam____': {'Area_km2': 13412.898880022321,
#   'LatCenter': 11.097569092133606,
#   'LonCenter': 37.17867258483669,
#   'RegionName': u'amhara',
#   'WoredaName': u'',
#   'ZoneName': u'west gojam'},
#  u'amhara__west gojam__bahir dar zuria__': {'Area_km2': 1547.54917626655,
#   'LatCenter': 11.81979893550006,
#   'LonCenter': 37.11649813950005,
#   'RegionName': u'amhara',
#   'WoredaName': u'bahir dar zuria',
#   'ZoneName': u'west gojam'},
#  u'amhara__west gojam__burie zuria__': {'Area_km2': 807.3337195102205,
#   'LatCenter': 10.565487562603293,
#   'LonCenter': 37.050810379611356,
#   'RegionName': u'amhara',
#   'WoredaName': u'burie zuria',
#   'ZoneName': u'west gojam'},
#  u'amhara__west gojam__debub achefer__': {'Area_km2': 1206.2663624804493,
#   'LatCenter': 11.463209741851612,
#   'LonCenter': 36.82668692302349,
#   'RegionName': u'amhara',
#   'WoredaName': u'debub achefer',
#   'ZoneName': u'west gojam'},
#  u'amhara__west gojam__dega damot__': {'Area_km2': 829.1535656035104,
#   'LatCenter': 10.855067133703017,
#   'LonCenter': 37.615644690886185,
#   'RegionName': u'amhara',
#   'WoredaName': u'dega damot',
#   'ZoneName': u'west gojam'},
#  u'amhara__west gojam__dembecha__': {'Area_km2': 969.6964447597974,
#   'LatCenter': 10.526047508845863,
#   'LonCenter': 37.36681281030841,
#   'RegionName': u'amhara',
#   'WoredaName': u'dembecha',
#   'ZoneName': u'west gojam'},
#  u'amhara__west gojam__jabi tehinan__': {'Area_km2': 1210.3303246929725,
#   'LatCenter': 10.690136213035201,
#   'LonCenter': 37.26567138275787,
#   'RegionName': u'amhara',
#   'WoredaName': u'jabi tehinan',
#   'ZoneName': u'west gojam'},
#  u'amhara__west gojam__mecha__': {'Area_km2': 1513.3436585141192,
#   'LatCenter': 11.332906166620877,
#   'LonCenter': 37.16823874182537,
#   'RegionName': u'amhara',
#   'WoredaName': u'mecha',
#   'ZoneName': u'west gojam'},
#  u'amhara__west gojam__quarit__': {'Area_km2': 619.0364992958687,
#   'LatCenter': 10.963344693366032,
#   'LonCenter': 37.4354081331083,
#   'RegionName': u'amhara',
#   'WoredaName': u'quarit',
#   'ZoneName': u'west gojam'},
#  u'amhara__west gojam__sekela__': {'Area_km2': 770.4826434825076,
#   'LatCenter': 10.989010859298215,
#   'LonCenter': 37.20450107757802,
#   'RegionName': u'amhara',
#   'WoredaName': u'sekela',
#   'ZoneName': u'west gojam'},
#  u'amhara__west gojam__semen achefer__': {'Area_km2': 1172.8186816699902,
#   'LatCenter': 11.513664860000063,
#   'LonCenter': 36.85482132140006,
#   'RegionName': u'amhara',
#   'WoredaName': u'semen achefer',
#   'ZoneName': u'west gojam'},
#  u'amhara__west gojam__womberma__': {'Area_km2': 1358.1323712981512,
#   'LatCenter': 10.50218042472419,
#   'LonCenter': 36.79144094481041,
#   'RegionName': u'amhara',
#   'WoredaName': u'womberma',
#   'ZoneName': u'west gojam'},
#  u'amhara__west gojam__yilmana densa__': {'Area_km2': 1408.7554324481496,
#   'LatCenter': 11.239057343859551,
#   'LonCenter': 37.550416681905,
#   'RegionName': u'amhara',
#   'WoredaName': u'yilmana densa',
#   'ZoneName': u'west gojam'},
#  u'benishangul-gumuz______': {'Area_km2': 50553.029134084056,
#   'LatCenter': 8.974620086000057,
#   'LonCenter': 36.21130021614291,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'',
#   'ZoneName': u''},
#  u'benishangul-gumuz__asosa____': {'Area_km2': 14523.922322270833,
#   'LatCenter': 9.99445158454416,
#   'LonCenter': 34.806808785485345,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'',
#   'ZoneName': u'asosa'},
#  u'benishangul-gumuz__asosa__asosa__': {'Area_km2': 3038.5724813620145,
#   'LatCenter': 10.00138635881255,
#   'LonCenter': 34.52636760425005,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'asosa',
#   'ZoneName': u'asosa'},
#  u'benishangul-gumuz__asosa__bambasi__': {'Area_km2': 1340.3493987304662,
#   'LatCenter': 9.819374353444497,
#   'LonCenter': 34.714330379888956,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'bambasi',
#   'ZoneName': u'asosa'},
#  u'benishangul-gumuz__asosa__homosha__': {'Area_km2': 628.3294496927484,
#   'LatCenter': 10.296907183578995,
#   'LonCenter': 34.560784735789525,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'homosha',
#   'ZoneName': u'asosa'},
#  u'benishangul-gumuz__asosa__kurmuk__': {'Area_km2': 1231.4824742579956,
#   'LatCenter': 10.558392344027077,
#   'LonCenter': 34.5100502642433,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'kurmuk',
#   'ZoneName': u'asosa'},
#  u'benishangul-gumuz__asosa__menge__': {'Area_km2': 1536.35430721073,
#   'LatCenter': 10.339406384607196,
#   'LonCenter': 34.844602430750065,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'menge',
#   'ZoneName': u'asosa'},
#  u'benishangul-gumuz__asosa__oda bildigilu__': {'Area_km2': 1606.2707980694001,
#   'LatCenter': 10.10969133327148,
#   'LonCenter': 35.10158527878576,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'oda bildigilu',
#   'ZoneName': u'asosa'},
#  u'benishangul-gumuz__asosa__sherkole__': {'Area_km2': 1980.468664829227,
#   'LatCenter': 10.642534992440726,
#   'LonCenter': 34.77884029632209,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'sherkole',
#   'ZoneName': u'asosa'},
#  u'benishangul-gumuz__kemashi____': {'Area_km2': 10184.327910006414,
#   'LatCenter': 8.974620086000057,
#   'LonCenter': 36.21130021614291,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'',
#   'ZoneName': u'kemashi'},
#  u'benishangul-gumuz__kemashi__agalo meti__': {'Area_km2': 1760.972044349362,
#   'LatCenter': 9.779700290089934,
#   'LonCenter': 35.623036881528144,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'agalo meti',
#   'ZoneName': u'kemashi'},
#  u'benishangul-gumuz__kemashi__belo jegenfoy__': {'Area_km2': 1673.3440582348776,
#   'LatCenter': 8.974620086000057,
#   'LonCenter': 36.21130021614291,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'belo jegenfoy',
#   'ZoneName': u'kemashi'},
#  u'benishangul-gumuz__kemashi__kamashi__': {'Area_km2': 1452.904753756699,
#   'LatCenter': 9.464685948168723,
#   'LonCenter': 35.91641035742173,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'kamashi',
#   'ZoneName': u'kemashi'},
#  u'benishangul-gumuz__kemashi__sedal__': {'Area_km2': 2687.5389157061404,
#   'LatCenter': 10.459959885816051,
#   'LonCenter': 35.22581654417604,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'sedal',
#   'ZoneName': u'kemashi'},
#  u'benishangul-gumuz__kemashi__yaso__': {'Area_km2': 2609.568137959319,
#   'LatCenter': 10.117826204308557,
#   'LonCenter': 36.27868547540433,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'yaso',
#   'ZoneName': u'kemashi'},
#  u'benishangul-gumuz__mao komo special woreda__mao komo special woreda__': {'Area_km2': 3162.094748118269,
#   'LatCenter': 9.412888947574514,
#   'LonCenter': 34.33565487204262,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'mao komo special woreda',
#   'ZoneName': u'mao komo special woreda'},
#  u'benishangul-gumuz__metekel____': {'Area_km2': 25844.77890180686,
#   'LatCenter': 11.139447040518034,
#   'LonCenter': 36.06527949814036,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'',
#   'ZoneName': u'metekel'},
#  u'benishangul-gumuz__metekel__bullen__': {'Area_km2': 3027.9459093597484,
#   'LatCenter': 10.512081169814003,
#   'LonCenter': 35.94857621574423,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'bullen',
#   'ZoneName': u'metekel'},
#  u'benishangul-gumuz__metekel__dangur__': {'Area_km2': 5042.808759012707,
#   'LatCenter': 11.457317691728447,
#   'LonCenter': 36.14684209675312,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'dangur',
#   'ZoneName': u'metekel'},
#  u'benishangul-gumuz__metekel__dibate__': {'Area_km2': 2246.5707730785025,
#   'LatCenter': 10.598286252805766,
#   'LonCenter': 36.27700140792005,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'dibate',
#   'ZoneName': u'metekel'},
#  u'benishangul-gumuz__metekel__guba__': {'Area_km2': 6959.32935467551,
#   'LatCenter': 11.62986097193234,
#   'LonCenter': 35.612730110807334,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'guba',
#   'ZoneName': u'metekel'},
#  u'benishangul-gumuz__metekel__mandura__': {'Area_km2': 1083.7322092412844,
#   'LatCenter': 11.043468719961288,
#   'LonCenter': 36.37859531729463,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'mandura',
#   'ZoneName': u'metekel'},
#  u'benishangul-gumuz__metekel__pawe__': {'Area_km2': 547.6722270383191,
#   'LatCenter': 11.306947761207846,
#   'LonCenter': 36.452236532194874,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'pawe',
#   'ZoneName': u'metekel'},
#  u'benishangul-gumuz__metekel__wombera__': {'Area_km2': 6936.719669400825,
#   'LatCenter': 10.555521725815176,
#   'LonCenter': 35.56279476630256,
#   'RegionName': u'benishangul-gumuz',
#   'WoredaName': u'wombera',
#   'ZoneName': u'metekel'},
# ...
#   'LatCenter': 7.462255962504722,
#   'LonCenter': 44.15791353081312,
#   'RegionName': u'somali',
#   'WoredaName': u'shaygosh',
#   'ZoneName': u'korahe'},
#  u'somali__korahe__shilabo__': {'Area_km2': 9037.038736012331,
#   'LatCenter': 6.378374982098813,
#   'LonCenter': 44.90862839312351,
#   'RegionName': u'somali',
#   'WoredaName': u'shilabo',
#   'ZoneName': u'korahe'},
#  u'somali__liben____': {'Area_km2': 36368.17274633436,
#   'LatCenter': 4.649669418911381,
#   'LonCenter': 40.801911011408876,
#   'RegionName': u'somali',
#   'WoredaName': u'',
#   'ZoneName': u'liben'},
#  u'somali__liben__dolo ado__': {'Area_km2': 9479.431510482564,
#   'LatCenter': 4.429568327321792,
#   'LonCenter': 41.39081671775658,
#   'RegionName': u'somali',
#   'WoredaName': u'dolo ado',
#   'ZoneName': u'liben'},
#  u'somali__liben__filtu__': {'Area_km2': 10529.323636371044,
#   'LatCenter': 5.07564296993225,
#   'LonCenter': 41.036432164601756,
#   'RegionName': u'somali',
#   'WoredaName': u'filtu',
#   'ZoneName': u'liben'},
#  u'somali__liben__hudhet__': {'Area_km2': 4040.3400122012245,
#   'LatCenter': 5.08540576890914,
#   'LonCenter': 40.110514464159145,
#   'RegionName': u'somali',
#   'WoredaName': u'hudhet',
#   'ZoneName': u'liben'},
#  u'somali__liben__moyale__': {'Area_km2': 12319.077587279482,
#   'LatCenter': 4.2307352762839985,
#   'LonCenter': 39.931794762888934,
#   'RegionName': u'somali',
#   'WoredaName': u'moyale',
#   'ZoneName': u'liben'},
#  u'somali__nogob____': {'Area_km2': 14281.946848179916,
#   'LatCenter': 7.631877007947967,
#   'LonCenter': 42.5988584245834,
#   'RegionName': u'somali',
#   'WoredaName': u'',
#   'ZoneName': u'nogob'},
#  u'somali__nogob__dhuhun__': {'Area_km2': 1934.101167687635,
#   'LatCenter': 7.229051845198066,
#   'LonCenter': 42.58582971708917,
#   'RegionName': u'somali',
#   'WoredaName': u'dhuhun',
#   'ZoneName': u'nogob'},
#  u'somali__nogob__fik__': {'Area_km2': 3822.8323016898685,
#   'LatCenter': 7.980541317906714,
#   'LonCenter': 42.393378003266726,
#   'RegionName': u'somali',
#   'WoredaName': u'fik',
#   'ZoneName': u'nogob'},
#  u'somali__nogob__garbo__': {'Area_km2': 994.4483503522566,
#   'LatCenter': 7.585506167644117,
#   'LonCenter': 42.996799693745835,
#   'RegionName': u'somali',
#   'WoredaName': u'garbo',
#   'ZoneName': u'nogob'},
#  u'somali__nogob__hamaro__': {'Area_km2': 3031.991967171614,
#   'LatCenter': 7.634765408166715,
#   'LonCenter': 42.395858388555595,
#   'RegionName': u'somali',
#   'WoredaName': u'hamaro',
#   'ZoneName': u'nogob'},
#  u'somali__nogob__lagahida__': {'Area_km2': 697.2646757820264,
#   'LatCenter': 8.018637008400047,
#   'LonCenter': 41.99999114014291,
#   'RegionName': u'somali',
#   'WoredaName': u'lagahida',
#   'ZoneName': u'nogob'},
#  u'somali__nogob__mayumuluko__': {'Area_km2': 1217.0275001848624,
#   'LatCenter': 8.468839386500047,
#   'LonCenter': 42.25105741672733,
#   'RegionName': u'somali',
#   'WoredaName': u'mayumuluko',
#   'ZoneName': u'nogob'},
#  u'somali__nogob__sagag__': {'Area_km2': 1717.661654889387,
#   'LatCenter': 7.473783273080695,
#   'LonCenter': 42.62815367961296,
#   'RegionName': u'somali',
#   'WoredaName': u'sagag',
#   'ZoneName': u'nogob'},
#  u'somali__nogob__salahad__': {'Area_km2': 866.6192304222858,
#   'LatCenter': 7.505256528057191,
#   'LonCenter': 42.026241147057185,
#   'RegionName': u'somali',
#   'WoredaName': u'salahad',
#   'ZoneName': u'nogob'},
#  u'somali__shebele____': {'Area_km2': 33032.933920648306,
#   'LatCenter': 6.306131446669718,
#   'LonCenter': 43.40923604691296,
#   'RegionName': u'somali',
#   'WoredaName': u'',
#   'ZoneName': u'shebele'},
#  u'somali__shebele__adadle__': {'Area_km2': 3204.6600353746217,
#   'LatCenter': 5.822953592129458,
#   'LonCenter': 43.317660970282404,
#   'RegionName': u'somali',
#   'WoredaName': u'adadle',
#   'ZoneName': u'shebele'},
#  u'somali__shebele__danan__': {'Area_km2': 5919.911384760318,
#   'LatCenter': 6.853675291731536,
#   'LonCenter': 43.302339833731516,
#   'RegionName': u'somali',
#   'WoredaName': u'danan',
#   'ZoneName': u'shebele'},
#  u'somali__shebele__east imey__': {'Area_km2': 9604.104774441981,
#   'LatCenter': 6.7015387761148,
#   'LonCenter': 42.538113124918105,
#   'RegionName': u'somali',
#   'WoredaName': u'east imey',
#   'ZoneName': u'shebele'},
#  u'somali__shebele__ferfer__': {'Area_km2': 3432.99347669551,
#   'LatCenter': 5.464940666800051,
#   'LonCenter': 45.05830731560006,
#   'RegionName': u'somali',
#   'WoredaName': u'ferfer',
#   'ZoneName': u'shebele'},
#  u'somali__shebele__gode woreda__': {'Area_km2': 4002.7639694046784,
#   'LatCenter': 6.0054961204091395,
#   'LonCenter': 43.5734563192046,
#   'RegionName': u'somali',
#   'WoredaName': u'gode woreda',
#   'ZoneName': u'shebele'},
#  u'somali__shebele__kalafo__': {'Area_km2': 2878.296371735029,
#   'LatCenter': 5.762910401088658,
#   'LonCenter': 44.133412975076,
#   'RegionName': u'somali',
#   'WoredaName': u'kalafo',
#   'ZoneName': u'shebele'},
#  u'somali__shebele__mustahil__': {'Area_km2': 3990.203908236238,
#   'LatCenter': 5.435084703610437,
#   'LonCenter': 44.79910714333771,
#   'RegionName': u'somali',
#   'WoredaName': u'mustahil',
#   'ZoneName': u'shebele'},
#  u'somali__sitti____': {'Area_km2': 30533.370769790876,
#   'LatCenter': 10.021733409292544,
#   'LonCenter': 41.66594104913839,
#   'RegionName': u'somali',
#   'WoredaName': u'',
#   'ZoneName': u'sitti'},
#  u'somali__sitti__afdem__': {'Area_km2': 4416.73980126424,
#   'LatCenter': 10.16050562154435,
#   'LonCenter': 41.17352894262031,
#   'RegionName': u'somali',
#   'WoredaName': u'afdem',
#   'ZoneName': u'sitti'},
#  u'somali__sitti__aysha__': {'Area_km2': 7725.634300663349,
#   'LatCenter': 10.610796059811813,
#   'LonCenter': 42.38342173482359,
#   'RegionName': u'somali',
#   'WoredaName': u'aysha',
#   'ZoneName': u'sitti'},
#  u'somali__sitti__dembel__': {'Area_km2': 2472.922561470291,
#   'LatCenter': 9.901228611457675,
#   'LonCenter': 42.46692709483057,
#   'RegionName': u'somali',
#   'WoredaName': u'dembel',
#   'ZoneName': u'sitti'},
#  u'somali__sitti__erer__': {'Area_km2': 4097.426332598224,
#   'LatCenter': 10.18660399325719,
#   'LonCenter': 41.618460415585766,
#   'RegionName': u'somali',
#   'WoredaName': u'erer',
#   'ZoneName': u'sitti'},
#  u'somali__sitti__meiso__': {'Area_km2': 3115.213359313818,
#   'LatCenter': 9.579544997241433,
#   'LonCenter': 40.982750633919586,
#   'RegionName': u'somali',
#   'WoredaName': u'meiso',
#   'ZoneName': u'sitti'},
#  u'somali__sitti__shinle__': {'Area_km2': 8705.434414480926,
#   'LatCenter': 10.108667963413087,
#   'LonCenter': 41.959449020293526,
#   'RegionName': u'somali',
#   'WoredaName': u'shinle',
#   'ZoneName': u'sitti'},
#  u'tigray______': {'Area_km2': 52943.43907101953,
#   'LatCenter': 13.757666621961892,
#   'LonCenter': 38.5860775885668,
#   'RegionName': u'tigray',
#   'WoredaName': u'',
#   'ZoneName': u''},
#  u'tigray__central tigray____': {'Area_km2': 9425.578316007935,
#   'LatCenter': 13.94238926226306,
#   'LonCenter': 38.8875047199882,
#   'RegionName': u'tigray',
#   'WoredaName': u'',
#   'ZoneName': u'central tigray'},
#  u'tigray__central tigray__adwa zuria__': {'Area_km2': 669.7639467495383,
#   'LatCenter': 14.18615362164372,
#   'LonCenter': 38.92274846585061,
#   'RegionName': u'tigray',
#   'WoredaName': u'adwa zuria',
#   'ZoneName': u'central tigray'},
#  u'tigray__central tigray__ahferom__': {'Area_km2': 1306.9440971289662,
#   'LatCenter': 14.359074733199224,
#   'LonCenter': 39.126898980813046,
#   'RegionName': u'tigray',
#   'WoredaName': u'ahferom',
#   'ZoneName': u'central tigray'},
#  u'tigray__central tigray__laelay maychew__': {'Area_km2': 560.2899890468917,
#   'LatCenter': 14.084723191563581,
#   'LonCenter': 38.76900555331499,
#   'RegionName': u'tigray',
#   'WoredaName': u'laelay maychew',
#   'ZoneName': u'central tigray'},
#  u'tigray__central tigray__mereb leke__': {'Area_km2': 1257.4251912994403,
#   'LatCenter': 14.355544418744806,
#   'LonCenter': 38.734691535790255,
#   'RegionName': u'tigray',
#   'WoredaName': u'mereb leke',
#   'ZoneName': u'central tigray'},
#  u'tigray__central tigray__naeder adiet__': {'Area_km2': 943.9589948677154,
#   'LatCenter': 13.859317256805882,
#   'LonCenter': 38.69305362433016,
#   'RegionName': u'tigray',
#   'WoredaName': u'naeder adiet',
#   'ZoneName': u'central tigray'},
#  u'tigray__central tigray__qola tenbien__': {'Area_km2': 1387.0863164400928,
#   'LatCenter': 13.704445938725916,
#   'LonCenter': 38.92621682187651,
#   'RegionName': u'tigray',
#   'WoredaName': u'qola tenbien',
#   'ZoneName': u'central tigray'},
#  u'tigray__central tigray__tahtay maychew__': {'Area_km2': 572.9499650776013,
#   'LatCenter': 14.121149371539264,
#   'LonCenter': 38.587682281818694,
#   'RegionName': u'tigray',
#   'WoredaName': u'tahtay maychew',
#   'ZoneName': u'central tigray'},
#  u'tigray__central tigray__tanqua abergele__': {'Area_km2': 1459.7251962151822,
#   'LatCenter': 13.428524851496215,
#   'LonCenter': 38.893135240569265,
#   'RegionName': u'tigray',
#   'WoredaName': u'tanqua abergele',
#   'ZoneName': u'central tigray'},
#  u'tigray__central tigray__werei leke__': {'Area_km2': 1267.4346191824006,
#   'LatCenter': 13.983099539391002,
#   'LonCenter': 39.072307333979474,
#   'RegionName': u'tigray',
#   'WoredaName': u'werei leke',
#   'ZoneName': u'central tigray'},
#  u'tigray__east tigray____': {'Area_km2': 6274.746457372598,
#   'LatCenter': 14.120173613662784,
#   'LonCenter': 39.57405238479264,
#   'RegionName': u'tigray',
#   'WoredaName': u'',
#   'ZoneName': u'east tigray'},
#  u'tigray__east tigray__atsibi wenberta__': {'Area_km2': 1147.478275963273,
#   'LatCenter': 13.822687523206232,
#   'LonCenter': 39.75909710202583,
#   'RegionName': u'tigray',
#   'WoredaName': u'atsibi wenberta',
#   'ZoneName': u'east tigray'},
#  u'tigray__east tigray__erob__': {'Area_km2': 936.0107855787744,
#   'LatCenter': 14.483118832695038,
#   'LonCenter': 39.70763684841506,
#   'RegionName': u'tigray',
#   'WoredaName': u'erob',
#   'ZoneName': u'east tigray'},
#  u'tigray__east tigray__ganta afeshum__': {'Area_km2': 553.4789062022464,
#   'LatCenter': 14.244276487625749,
#   'LonCenter': 39.379942936379926,
#   'RegionName': u'tigray',
#   'WoredaName': u'ganta afeshum',
#   'ZoneName': u'east tigray'},
#  u'tigray__east tigray__gulo mekeda__': {'Area_km2': 596.0122692325652,
#   'LatCenter': 14.406693673731894,
#   'LonCenter': 39.401900922703945,
#   'RegionName': u'tigray',
#   'WoredaName': u'gulo mekeda',
#   'ZoneName': u'east tigray'},
#  u'tigray__east tigray__hawzien__': {'Area_km2': 856.4787426173777,
#   'LatCenter': 13.96892762961841,
#   'LonCenter': 39.39469644808701,
#   'RegionName': u'tigray',
#   'WoredaName': u'hawzien',
#   'ZoneName': u'east tigray'},
#  u'tigray__east tigray__klite awlalo__': {'Area_km2': 1019.7693493276965,
#   'LatCenter': 13.755175853965264,
#   'LonCenter': 39.51515943610006,
#   'RegionName': u'tigray',
#   'WoredaName': u'klite awlalo',
#   'ZoneName': u'east tigray'},
#  u'tigray__east tigray__saesit tsaeda emba__': {'Area_km2': 1165.5181284507937,
#   'LatCenter': 14.131859146309068,
#   'LonCenter': 39.62821108159729,
#   'RegionName': u'tigray',
#   'WoredaName': u'saesit tsaeda emba',
#   'ZoneName': u'east tigray'},
#  u'tigray__north west tigray____': {'Area_km2': 12636.53530072873,
#   'LatCenter': 13.434762537193597,
#   'LonCenter': 38.67640257922586,
#   'RegionName': u'tigray',
#   'WoredaName': u'',
#   'ZoneName': u'north west tigray'},
#  u'tigray__north west tigray__asgede tsimbla__': {'Area_km2': 2415.1804881791377,
#   'LatCenter': 13.975038525927163,
#   'LonCenter': 37.97534373167642,
#   'RegionName': u'tigray',
#   'WoredaName': u'asgede tsimbla',
#   'ZoneName': u'north west tigray'},
#  u'tigray__north west tigray__laelay adiabo__': {'Area_km2': 1782.705866760645,
#   'LatCenter': 14.359478401423598,
#   'LonCenter': 38.18707255803828,
#   'RegionName': u'tigray',
#   'WoredaName': u'laelay adiabo',
#   'ZoneName': u'north west tigray'},
#  u'tigray__north west tigray__medebay zana__': {'Area_km2': 1062.3702972231802,
#   'LatCenter': 14.037255277817621,
#   'LonCenter': 38.44771445321965,
#   'RegionName': u'tigray',
#   'WoredaName': u'medebay zana',
#   'ZoneName': u'north west tigray'},
#  u'tigray__north west tigray__tahtay adiabo__': {'Area_km2': 3928.9208963651436,
#   'LatCenter': 14.384910657244754,
#   'LonCenter': 37.798246363713055,
#   'RegionName': u'tigray',
#   'WoredaName': u'tahtay adiabo',
#   'ZoneName': u'north west tigray'},
#  u'tigray__north west tigray__tahtay koraro__': {'Area_km2': 674.5687774879531,
#   'LatCenter': 14.096876260474232,
#   'LonCenter': 38.27543861824417,
#   'RegionName': u'tigray',
#   'WoredaName': u'tahtay koraro',
#   'ZoneName': u'north west tigray'},
#  u'tigray__north west tigray__tselemti__': {'Area_km2': 2772.788974713065,
#   'LatCenter': 13.636161320354544,
#   'LonCenter': 38.21148938225931,
#   'RegionName': u'tigray',
#   'WoredaName': u'tselemti',
#   'ZoneName': u'north west tigray'},
#  u'tigray__south east tigray____': {'Area_km2': 6196.220034307325,
#   'LatCenter': 13.329560258070028,
#   'LonCenter': 39.40002164727626,
#   'RegionName': u'tigray',
#   'WoredaName': u'',
#   'ZoneName': u'south east tigray'},
#  u'tigray__south east tigray__degua tembien__': {'Area_km2': 1039.238752369716,
#   'LatCenter': 13.625237100763876,
#   'LonCenter': 39.22034365029654,
#   'RegionName': u'tigray',
#   'WoredaName': u'degua tembien',
#   'ZoneName': u'south east tigray'},
#  u'tigray__south east tigray__enderta__': {'Area_km2': 1481.6587409841145,
#   'LatCenter': 13.423654354068772,
#   'LonCenter': 39.54494254843991,
#   'RegionName': u'tigray',
#   'WoredaName': u'enderta',
#   'ZoneName': u'south east tigray'},
#  u'tigray__south east tigray__hintalo wajirat__': {'Area_km2': 1945.7661912089252,
#   'LatCenter': 13.170326997233696,
#   'LonCenter': 39.53941589325862,
#   'RegionName': u'tigray',
#   'WoredaName': u'hintalo wajirat',
#   'ZoneName': u'south east tigray'},
#  u'tigray__south east tigray__seharti samre__': {'Area_km2': 1729.5563497446244,
#   'LatCenter': 13.237941233687312,
#   'LonCenter': 39.18724918030507,
#   'RegionName': u'tigray',
#   'WoredaName': u'seharti samre',
#   'ZoneName': u'south east tigray'},
#  u'tigray__south tigray____': {'Area_km2': 5051.815685052256,
#   'LatCenter': 12.706605276739664,
#   'LonCenter': 39.529655285415565,
#   'RegionName': u'tigray',
#   'WoredaName': u'',
#   'ZoneName': u'south tigray'},
#  u'tigray__south tigray__alemata town__': {'Area_km2': 730.5398348790518,
#   'LatCenter': 12.400627182390958,
#   'LonCenter': 39.51870415105005,
#   'RegionName': u'tigray',
#   'WoredaName': u'alemata town',
#   'ZoneName': u'south tigray'},
#  u'tigray__south tigray__emba alaje__': {'Area_km2': 779.204844628288,
#   'LatCenter': 12.941684268958623,
#   'LonCenter': 39.44056336920124,
#   'RegionName': u'tigray',
#   'WoredaName': u'emba alaje',
#   'ZoneName': u'south tigray'},
#  u'tigray__south tigray__enda mekoni__': {'Area_km2': 638.971362506588,
#   'LatCenter': 12.751447924184978,
#   'LonCenter': 39.46415871525348,
#   'RegionName': u'tigray',
#   'WoredaName': u'enda mekoni',
#   'ZoneName': u'south tigray'},
#  u'tigray__south tigray__ofla__': {'Area_km2': 1108.8638171539674,
#   'LatCenter': 12.544108285064715,
#   'LonCenter': 39.39674133599011,
#   'RegionName': u'tigray',
#   'WoredaName': u'ofla',
#   'ZoneName': u'south tigray'},
#  u'tigray__south tigray__raya azebo__': {'Area_km2': 1794.235825884357,
#   'LatCenter': 12.6688106576946,
#   'LonCenter': 39.71490372151641,
#   'RegionName': u'tigray',
#   'WoredaName': u'raya azebo',
#   'ZoneName': u'south tigray'},
#  u'tigray__west tigray____': {'Area_km2': 13358.54327754995,
#   'LatCenter': 13.809750080584225,
#   'LonCenter': 37.17819366368861,
#   'RegionName': u'tigray',
#   'WoredaName': u'',
#   'ZoneName': u'west tigray'},
#  u'tigray__west tigray__kafta humera__': {'Area_km2': 6272.626795197225,
#   'LatCenter': 14.060701402705261,
#   'LonCenter': 37.07126024711569,
#   'RegionName': u'tigray',
#   'WoredaName': u'kafta humera',
#   'ZoneName': u'west tigray'},
#  u'tigray__west tigray__tsegede__': {'Area_km2': 3252.813269833513,
#   'LatCenter': 13.499231687931086,
#   'LonCenter': 37.08514178928605,
#   'RegionName': u'tigray',
#   'WoredaName': u'tsegede',
#   'ZoneName': u'west tigray'},
#  u'tigray__west tigray__welkayit__': {'Area_km2': 3833.103212519078,
#   'LatCenter': 13.77300436729403,
#   'LonCenter': 37.364958139226914,
#   'RegionName': u'tigray',
#   'WoredaName': u'welkayit',
#   'ZoneName': u'west tigray'}}

# %% [markdown]
# <h1> Test creating GeoKey </h1>

# %%
# Generate the geo_key given an arbitary number of available columns
name_columns = [column for column in mapped_dataframe.columns if 'Name' in column]
extra_dash = '__' * (4 - len(name_columns))
mapped_dataframe[name_columns].apply(lambda x: '%s%s' % ('__'.join(x).lower(), extra_dash), axis=1)
# Out:
# 0                       addis ababa__addis ababa__
# 1                           afar__zone 01 - awsi__
# 2                        afar__zone 02 - kilbati__
# 3                           afar__zone 03 - gabi__
# 4                          afar__zone 04 - fenti__
# 5                           afar__zone 05 - hari__
# 6                                    amhara__awi__
# 7                         amhara__bahir dar town__
# 8                            amhara__dessie town__
# 9                             amhara__east gojam__
# 10                           amhara__gondar town__
# 11                          amhara__north gondar__
# 12                           amhara__north shewa__
# 13                           amhara__north wollo__
# 14                   amhara__oromia special zone__
# 15                          amhara__south gondar__
# 16                           amhara__south wollo__
# 17                             amhara__wag himra__
# 18                            amhara__west gojam__
# 19                      benishangul-gumuz__asosa__
# 20                 benishangul-gumuz__asosa town__
# 21                    benishangul-gumuz__kemashi__
# 22    benishangul-gumuz__mao komo special woreda__
# 23                    benishangul-gumuz__metekel__
# 24                          dire dawa__dire dawa__
# 25                             gambella__angewak__
# 26                       gambella__gambella town__
# 27                               gambella__itang__
# 28                            gambella__mejenger__
# 29                               gambella__nuwer__
#                           ...
# 70                                 snnpr__gurage__
# 71                                 snnpr__hadiya__
# 72                  snnpr__halaba special woreda__
# 73                                snnpr__hawassa__
# 74                                  snnpr__kaffa__
# 75                        snnpr__kembata tembaro__
# 76                                  snnpr__konta__
# 77                                  snnpr__segen__
# 78                                  snnpr__sheka__
# 79                                 snnpr__sidama__
# 80                                  snnpr__silte__
# 81                              snnpr__south omo__
# 82                                snnpr__wolayta__
# 83                                    snnpr__yem__
# 84                                 somali__afder__
# 85                                 somali__dollo__
# 86                                somali__faafan__
# 87                                 somali__jarar__
# 88                                somali__korahe__
# 89                                 somali__liben__
# 90                                 somali__nogob__
# 91                               somali__shebele__
# 92                                 somali__sitti__
# 93                        tigray__central tigray__
# 94                           tigray__east tigray__
# 95                                tigray__mekele__
# 96                     tigray__north west tigray__
# 97                     tigray__south east tigray__
# 98                          tigray__south tigray__
# 99                           tigray__west tigray__
# dtype: object

# %%
fpath = '/Users/attiladobi/zenysis/pipeline/auto/ethiopia/bin/shared/data/zone_mapped.csv'
mapped_dataframe = pd.read_csv(fpath, dtype=str)
good_columns = [column for column in mapped_dataframe.columns if 'match' not in column]
mapped_dataframe = mapped_dataframe[good_columns]
#for row in mapped_dataframe.iterrows():
#    print row[1].keys()

# %%
mapped_dataframe
# Out:
#       RegionName           ZoneName                WoredaName  \
# 0    Addis Ababa        Addis Ababa              Addis Ketema
# 1    Addis Ababa        Addis Ababa              Akaki Kality
# 2    Addis Ababa        Addis Ababa                     Arada
# 3    Addis Ababa        Addis Ababa                      Bole
# 4    Addis Ababa        Addis Ababa                    Gulele
# 5    Addis Ababa        Addis Ababa                    Kirkos
# 6    Addis Ababa        Addis Ababa            Kolfe Keraniyo
# 7    Addis Ababa        Addis Ababa                    Lideta
# 8    Addis Ababa        Addis Ababa          Nefas Silk Lafto
# 9    Addis Ababa        Addis Ababa                      Yeka
# 10          Afar     Zone 01 - Awsi                    Adeare
# 11          Afar     Zone 01 - Awsi                    Afambo
# 12          Afar     Zone 01 - Awsi                   Aysaita
# 13          Afar     Zone 01 - Awsi                      Bidu
# 14          Afar     Zone 01 - Awsi                    Chifra
# 15          Afar     Zone 01 - Awsi                     Dubti
# 16          Afar     Zone 01 - Awsi                   Elidear
# 17          Afar     Zone 01 - Awsi                      Kori
# 18          Afar     Zone 01 - Awsi                     Mille
# 19          Afar     Zone 01 - Awsi         Samara Logia City
# 20          Afar  Zone 02 - Kilbati                    Abeala
# 21          Afar  Zone 02 - Kilbati                    Afdera
# 22          Afar  Zone 02 - Kilbati                   Berhale
# 23          Afar  Zone 02 - Kilbati                    Dalole
# 24          Afar  Zone 02 - Kilbati                     Erbti
# 25          Afar  Zone 02 - Kilbati                    Koneba
# 26          Afar  Zone 02 - Kilbati                   Megalle
# 27          Afar     Zone 03 - Gabi                   Amibera
# 28          Afar     Zone 03 - Gabi               Argoba Liyu
# 29          Afar     Zone 03 - Gabi                Awash City
# ..           ...                ...                       ...
# 813       Tigray             Mekele                    Ayeder
# 814       Tigray             Mekele                   Hadinet
# 815       Tigray             Mekele                   Hawelti
# 816       Tigray             Mekele             Qdemay Woyane
# 817       Tigray             Mekele                     Quiha
# 818       Tigray             Mekele                    Semean
# 819       Tigray  North West Tigray            Asgede Tsimbla
# 820       Tigray  North West Tigray             Laelay Adiabo
# 821       Tigray  North West Tigray              Medebay Zana
# 822       Tigray  North West Tigray              Sheraro Town
# 823       Tigray  North West Tigray  Shire Endassilassie Town
# 824       Tigray  North West Tigray             Tahtay Adiabo
# 825       Tigray  North West Tigray             Tahtay Koraro
# 826       Tigray  North West Tigray                  Tselemti
# 827       Tigray  South East Tigray             Degua Tembien
# 828       Tigray  South East Tigray                   Enderta
# 829       Tigray  South East Tigray           Hintalo Wajirat
# 830       Tigray  South East Tigray             Seharti Samre
# 831       Tigray       South Tigray              Alemata Town
# 832       Tigray       South Tigray                Emba Alaje
# 833       Tigray       South Tigray               Enda Mekoni
# 834       Tigray       South Tigray                Korem Town
# 835       Tigray       South Tigray              Maychew Town
# 836       Tigray       South Tigray                      Ofla
# 837       Tigray       South Tigray              Raya Alamata
# 838       Tigray       South Tigray                Raya Azebo
# 839       Tigray        West Tigray              Kafta Humera
# 840       Tigray        West Tigray              Setit Humera
# 841       Tigray        West Tigray                   Tsegede
# 842       Tigray        West Tigray                  Welkayit
#
#               WoredaLat           WoredaLon
# 0     9.034698212854872  38.726558114195036
# 1      8.89728556566618     38.803769890705
# 2     9.035681311338866    38.7546835191774
# 3      8.98003533307717   38.83908245092445
# 4     9.071479416494498  38.744859937113176
# 5     9.001003803530361   38.75843721783356
# 6     9.010224654632118   38.68719697668988
# 7     9.011481143879871  38.729876963602074
# 8     8.952101351535061   38.72884748276097
# 9     9.048984481088622  38.827313748592175
# 10   11.315658431000134   40.44370333513461
# 11   11.238992735080531    41.6467541186634
# 12    11.54663602146654   41.51189823666065
# 13   13.004548707390803  41.506296574338776
# 14    11.65049837034306  40.341676169268894
# 15   11.683414156583575   41.10288860787214
# 16   12.312935457725892   41.73687826970957
# 17   12.537055763298358   40.93120378953305
# 18   11.291285027875187   40.92598700665982
# 19                  0.0                 0.0
# 20   13.339392314314548  39.959672559559884
# 21   13.387168967367312   40.92963753974413
# 22   13.839480500786149  40.430073860926576
# 23   14.233859270014118  40.078209873283164
# 24   13.160895302004231   40.40322440506571
# 25   13.902929512569884   39.94401380689703
# 26   13.022924834152601    40.0180348985992
# 27    9.525947896093713   40.40392144812952
# 28    9.504935707421911   39.89072151860723
# 29                  0.0                 0.0
# ..                  ...                 ...
# 813           13.515811           39.464358
# 814            13.57705            36.77238
# 815                 0.0                 0.0
# 816                 0.0                 0.0
# 817                 0.0                 0.0
# 818                 0.0                 0.0
# 819  13.957487251598225  37.994397389377056
# 820  14.366996748316682   38.19827495707353
# 821  14.008605920829073   38.44539294133599
# 822           14.396877           37.772841
# 823           14.104443           38.286924
# 824  14.426690660018924   37.78966992852489
# 825   14.09622859372155   38.28582857859055
# 826   13.62902673359616   38.16004836739632
# 827   13.62169171966358   39.22525773525199
# 828  13.437366000063378   39.55513449313203
# 829  13.134439001045806   39.57958622229621
# 830  13.203694767985848  39.173767180811225
# 831  12.385982323571435   39.51276901667983
# 832  12.945032917248357  39.421817010170024
# 833  12.753128109064955   39.45099425682594
# 834           12.509256           39.519882
# 835           12.784327           39.542735
# 836  12.539613889190688   39.38117294748163
# 837                 0.0                 0.0
# 838  12.663163138225144   39.74354327021197
# 839  14.047562538306977  36.934700383571666
# 840           14.280020           36.615071
# 841  13.490462585860064  37.056434865232454
# 842  13.756371601067402    37.3954474200696
#
# [843 rows x 5 columns]

# %% [markdown]
# <h1> Build dict with lat, lon, elevation. Google API call for elevation </h1>

# %%
fpath = '/Users/attiladobi/zenysis/pipeline/auto/ethiopia/bin/shared/data/woreda_mapped.csv'

headers = ['RegionName', 'ZoneName', 'WoredaName', 'GeoKey', 'WoredaLat', 'WoredaLon', \
           'Elevation_m', 'Area_km2', 'LatCenter', 'LonCenter']

with open('woreda_info.csv', 'wb') as f:
    writer = csv.writer(f)
    writer.writerow(headers)
    
    with open(fpath, 'rb') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        # skip one row
        spamreader.next()
        for N, row in enumerate(spamreader):
            region, zone, woreda = row[:3]
            geo_code = ('%s__%s__%s__' % (region, zone, woreda)).lower()
            geo_data = geo_dict.get(geo_code, {})
            
            geo_area = geo_data.get('Area_km2', 0)
            center_lat = geo_data.get('LatCenter', 0)
            center_lon = geo_data.get('LonCenter', 0)
            lat, lon = row[3], row[4]
            # If 0 then maybe use the lat,lon centroid
            if (float(lat) == 0.0) & (float(lon) == 0.0):
                elevation = lookup_elevation(center_lat, center_lon)
            else:
                elevation = lookup_elevation(lat, lon)
            # print failure
            if elevation == 'fail':
                print N, lat, lon
                
            writer.writerow([region, zone, woreda, geo_code, lat, lon, elevation,\
                             geo_area, center_lat, center_lon])

# %% [markdown]
# <h1> Load in as DF. Only need this to get the average elevation information.</h1>

# %%
DF_woreda = pd.read_csv('woreda_info.csv')
DF_woreda['ZoneKey'] = [('%s__%s____' % (region, zone)).lower() for region,zone in DF_woreda[['RegionName', 'ZoneName']].values]
DF_woreda['RegionKey'] = [('%s______' % region).lower() for region in DF_woreda['RegionName'] ]

# May not be needed next time, but we have to cut out the negative values
DF_woreda['Elevation_m'] = [float(val) if val != 'fail' else 0 for val in DF_woreda['Elevation_m']]

# %% [markdown]
# <h1> Loop through zone mapped file </h1>

# %%
fpath = '/Users/attiladobi/zenysis/pipeline/auto/ethiopia/bin/shared/data/zone_mapped.csv'

headers = ['RegionName', 'ZoneName', 'GeoKey', 'ZoneLat', 'ZoneLon', \
           'Elevation_m', 'minElevation_m', 'maxElevation_m', 'Area_km2', 'LatCenter', 'LonCenter']

with open('zone_info.csv', 'wb') as f:
    writer = csv.writer(f)
    writer.writerow(headers)
    
    with open(fpath, 'rb') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        # skip one row
        spamreader.next()
        for N, row in enumerate(spamreader):
            region, zone = row[:2]
            geo_code = ('%s__%s____' % (region, zone)).lower()
            # Look up geo_dict with area and lat lon center info
            geo_data = geo_dict.get(geo_code, {})
            
            geo_area = geo_data.get('Area_km2', 0)
            center_lat = geo_data.get('LatCenter', 0)
            center_lon = geo_data.get('LonCenter', 0)
            lat, lon = row[2], row[3]
            
            # If center lat,lon are missing take the centroid of all woredas in the zone
            if (center_lat == 0) & (center_lon == 0):
                center_lat, center_lon = process_woreda_latlon(DF_woreda.set_index('ZoneKey'), geo_code)

            # Calculate average elevation info from the woredas in the zones 
            elevation, elevation_min, elevation_max = \
                process_woreda_elevation(DF_woreda.set_index('ZoneKey'), geo_code)
                
            writer.writerow([region, zone, geo_code, lat, lon, elevation, elevation_min, elevation_max,\
                             geo_area, center_lat, center_lon])

# %% [markdown]
# <h1> Loop through region mapped file </h1>

# %%
fpath = '/Users/attiladobi/zenysis/pipeline/auto/ethiopia/bin/shared/data/region_mapped.csv'

headers = ['RegionName', 'GeoKey', 'ZoneLat', 'ZoneLon', \
           'Elevation_m', 'minElevation_m', 'maxElevation_m', 'Area_km2', 'LatCenter', 'LonCenter']

with open('region_info.csv', 'wb') as f:
    writer = csv.writer(f)
    writer.writerow(headers)
    
    with open(fpath, 'rb') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        # skip one row
        spamreader.next()
        for N, row in enumerate(spamreader):
            region = row[0]
            geo_code = ('%s______' % region).lower()
            # Look up geo_dict with area and lat lon center info
            geo_data = geo_dict.get(geo_code, {})
            
            geo_area = geo_data.get('Area_km2', 0)
            center_lat = geo_data.get('LatCenter', 0)
            center_lon = geo_data.get('LonCenter', 0)
            lat, lon = row[1], row[2]
            
            # If center lat,lon are missing take the centroid of all woredas in the region
            if (center_lat == 0) & (center_lon == 0):
                center_lat, center_lon = process_woreda_latlon(DF_woreda.set_index('RegionKey'), geo_code)

            # Look up the woredas in the region and calculate average elevation info
            elevation, elevation_min, elevation_max = \
                process_woreda_elevation(DF_woreda.set_index('RegionKey'), geo_code)
                
            writer.writerow([region, geo_code, lat, lon, elevation, elevation_min, elevation_max,\
                             geo_area, center_lat, center_lon])
