# %% [markdown]
# <h1> RMCH</h1>

# %%
from __future__ import division
import numpy as np
import json
import re
import gzip
import pandas as pd
# %pylab inline
pylab.rcParams['figure.figsize'] = (12.0, 8.0) # set size of figures"
plt.rcParams.update({'font.size': 24})
import seaborn as sns
import datetime

from IPython.html.widgets import *
from nvd3 import pieChart
import nvd3
nvd3.ipynb.initialize_javascript(use_remote=True)

from ethiopian_date import ethiopian_date

pd.set_option('display.max_rows', 50)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['f', 'Text', 'Widget', 'Button', 'interactive']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# <link media="all" href="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.css" type="text/css"
#                         rel="stylesheet"/>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.js"></script>

# %% [markdown]
# <h1> Load in the indicator names and make an indicator ID mapping </h1>

# %%
import sys
sys.path.append('/Users/attiladobi/zenysis')
import config.et.indicators

# %%
useful_groups = config.indicators.HMIS_GROUPS + [config.indicators.CALCULATED_INDICATOR_GROUP]

# %%
IDlookup = {val['id']:val for cluster in useful_groups for val in cluster['indicators']}
len(IDlookup)
# Out:
# 1051

# %%
config.indicators.CALCULATED_INDICATOR_GROUP
# Out:
# {'groupId': 'zenysis-calculated-indicators',
#  'groupText': 'Calculated Indicators',
#  'groupTextShort': 'Calculated Indicators',
#  'indicators': [{'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_1_1',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Maternal Health'],
#    'text': 'Contraceptive acceptance rate'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_1_2',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Maternal Health'],
#    'text': 'Antenatal care coverage - First visit'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_1_3',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Maternal Health'],
#    'text': 'Antenatal care coverage - four visits'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_1_4',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Maternal Health'],
#    'text': 'Percentage of pregnant women attending antenatal care clinics tested for syphilis'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_1_5',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Maternal Health'],
#    'text': 'Proportion of births attended by skilled health personnel'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_1_6',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Maternal Health'],
#    'text': 'Proportion of births attended by health extension workers at Health Post'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_1_7',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Maternal Health'],
#    'text': 'Early postnatal care coverage'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_1_8',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Maternal Health'],
#    'text': 'Caesarean section rate'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_1_9',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Maternal Health'],
#    'text': 'Number of women receiving comprehensive abortion care services'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_1_1_10',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Maternal Health'],
#    'text': 'Proportion of maternal deaths related to pregnancy or its management in a health facility'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_1_1_11',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Maternal Health'],
#    'text': 'Number of maternal deaths in the community'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_1_1_12',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Maternal Health'],
#    'text': 'Stillbirth rate'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_1_13',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Maternal Health'],
#    'text': 'Proportion of kebeles declared "home delivery free"'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_2_1',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'PMTCT'],
#    'text': 'Percentage of pregnant and lactating women who were tested for HIV and who know their results'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_2_2',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'PMTCT'],
#    'text': 'Number of HIV positive pregnant and lactating women who received ART at ANC+L&D+PNC for the first time based on option B+'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_2_3',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'PMTCT'],
#    'text': 'Number of HIV-positive women who get pregnant while on ART and linked to ANC'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_2_4',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'PMTCT'],
#    'text': 'Percentage of infants born to HIV infected women receiving a virological test for HIV within 12 months of birth'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_2_5',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'PMTCT'],
#    'text': 'Percentage of infants born to HIV-infected women who were started on co-trimoxazole prophylaxis within two months of birth'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_2_6',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'PMTCT'],
#    'text': 'Percentage of infants born to HIV-infected women receiving antiretroviral (ARV) prophylaxis for prevention of mother-to-child transmission (PMTCT)'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_2_7',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'PMTCT'],
#    'text': 'Percentage of HIV exposed infants receiving HIV confirmatory (antibody test) test by 18 months'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_3_1',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Child Health'],
#    'text': 'DPT1-HepB1-Hib1 (pentavalent First dose) immunization coverage (< 1 year)'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_3_2',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Child Health'],
#    'text': 'DPT3-HepB3-Hib3 (Pentavalent third dose) immunization coverage (< 1 year)'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_3_3',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Child Health'],
#    'text': 'Pneumococcal conjugated vaccine first dose (PCV1) immunization coverage (< 1 year)'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_3_4',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Child Health'],
#    'text': 'Pneumococcal conjugated vaccine (PCV3) immunization coverage (< 1 year)'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_3_5',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Child Health'],
#    'text': 'Rotavirus vaccine first dose (Rota1) immunization coverage (< 1 year)'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_3_6',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Child Health'],
#    'text': 'Rotavirus vaccine 2nd dose (Rota2) immunization coverage (< 1 year)'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_3_7',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Child Health'],
#    'text': 'Measles immunization coverage (< 1 year)'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_3_8',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Child Health'],
#    'text': 'Full immunization coverage (< 1 year)'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_3_9',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Child Health'],
#    'text': 'Proportion of infants protected at birth against neonatal tetanus'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_1_3_11',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Child Health'],
#    'text': 'Early institutional neonatal death rate'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_1_3_12',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Child Health'],
#    'text': 'Early Neonatal death rate at community'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_3_13',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Child Health'],
#    'text': 'Proportion of children treated for pneumonia'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_3_14',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Child Health'],
#    'text': 'Proportion of neonates treated for sepsis'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_1_3_15',
#    'programAreas': ['Improve Access to Health Services',
#     'Maternal and Child Health',
#     'Child Health'],
#    'text': 'Proportion of neonates treated for asphyxia at health facility'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_2_1',
#    'programAreas': ['Improve Access to Health Services', 'Nutrition'],
#    'text': 'Percentage of low birth weight (LBW) newborns'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_2_2',
#    'programAreas': ['Improve Access to Health Services', 'Nutrition'],
#    'text': 'Percentage of underweight Children aged <5 years'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_2_3',
#    'programAreas': ['Improve Access to Health Services', 'Nutrition'],
#    'text': 'Proportion of children 6-59 months with severe acute malnutrition'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_2_5',
#    'programAreas': ['Improve Access to Health Services', 'Nutrition'],
#    'text': 'Proportion of children aged 6-59 months who received vitamin A supplementation'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_2_6',
#    'programAreas': ['Improve Access to Health Services', 'Nutrition'],
#    'text': 'Proportion of children aged 2-5 years de-wormed'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_3_1',
#    'programAreas': ['Improve Access to Health Services',
#     'Hygiene and Environmental'],
#    'text': "Proportion of households' access to latrine facilities"},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_3_2',
#    'programAreas': ['Improve Access to Health Services',
#     'Hygiene and Environmental'],
#    'text': 'Proportion of HHs using latrine'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_3_3',
#    'programAreas': ['Improve Access to Health Services',
#     'Hygiene and Environmental'],
#    'text': 'Proportion of kebeles declared "Open Defecation Free"'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_1_3',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'All Diseases'],
#    'text': 'Inpatient mortality rate'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_1_1',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'HIV/AIDS'],
#    'text': 'Number of individuals tested and counseled for HIV and who received their test results'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_1_2',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'HIV/AIDS'],
#    'text': 'Number of PLHIV newly enrolled in pre-ART care'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_1_3',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'HIV/AIDS'],
#    'text': 'HIV positive persons receiving co-trimoxazole prophylaxis'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_1_4',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'HIV/AIDS'],
#    'text': 'Number of PLHIV ever started on ART'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_1_5',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'HIV/AIDS'],
#    'text': 'Number of adults and children receiving Anti-Retroviral Therapy (ART) (CURRENT)'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_1_6',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'HIV/AIDS'],
#    'text': 'Number of adults and children with HIV infection newly started on ART'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_1_7',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'HIV/AIDS'],
#    'text': 'Survival on ART'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_1_8',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'HIV/AIDS'],
#    'text': 'Percentage of ART patients with an undetectable viral load at 12 month after initiation of ART'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_1_9',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'HIV/AIDS'],
#    'text': 'Proportion of clinically undernourished People Living with HIV (PLHIV) who received therapeutic or supplementary food'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_1_10',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'HIV/AIDS'],
#    'text': 'Number of HIV-positive adults and children currently receiving clinical care'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_1_11',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'HIV/AIDS'],
#    'text': 'Number of HIV-positive adults and children newly enrolled in clinical care'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_1_12',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'HIV/AIDS'],
#    'text': 'Number of persons provided with Post-exposure prophylaxis (PEP)'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_2_1_13',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'HIV/AIDS'],
#    'text': 'Health Facilities Providing ART that Experienced Stock-Outs of at least one required ARV'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_2_2_1',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Tuberculosis'],
#    'text': 'Tuberculosis case detection rate (all forms)'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_2_2_2',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Tuberculosis'],
#    'text': 'Tuberculosis re-treatment rate'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_2_3',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Tuberculosis'],
#    'text': 'Cure rate for bacteriologically confirmed new PTB cases (CR)'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_2_4',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Tuberculosis'],
#    'text': 'Treatment Success Rate (TSR) among bacteriologically confirmed NEW PTB cases'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_2_5',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Tuberculosis'],
#    'text': 'Treatment success rate among clinically diagnosed new TB cases'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_2_2_6',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Tuberculosis'],
#    'text': 'Death rate among all forms of TB cases'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_2_2_7',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Tuberculosis'],
#    'text': 'Lost to follow up rate among all forms of TB cases'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_2_8',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Tuberculosis'],
#    'text': 'TB case detection through community TB care'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_2_9',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Tuberculosis'],
#    'text': 'Proportion of TB cases (all forms) provided treatment observation (DOT) by community among all TB cases'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_2_10',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Tuberculosis'],
#    'text': 'Proportion of AFB Microscopy centers (HF) with adequate EQA performance'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_2_2_11',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Tuberculosis'],
#    'text': 'Proportion of TB cases (all forms) contributed by private sector'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_2_2_12',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Tuberculosis'],
#    'text': 'Proportion of presumptive MDR TB cases with result for drug susceptibility testing (DST)'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_2_2_13',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Tuberculosis'],
#    'text': 'Number of MDR TB cases detected'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_2_2_14',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Tuberculosis'],
#    'text': 'MDR-TB cases enrolled on Second Line Drugs (SLDs)'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_2_2_15',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Tuberculosis'],
#    'text': 'MDR TB Treatment six month interim result'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_2_3_1',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Leprosy'],
#    'text': 'Leprosy case notification'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_2_3_2',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Leprosy'],
#    'text': 'Grade II disability rate among new cases of leprosy'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_3_3',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Leprosy'],
#    'text': 'Leprosy treatment completion rate'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_4_1',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'TB/HIV'],
#    'text': 'HIV screening for TB patients'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_4_2',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'TB/HIV'],
#    'text': 'TB Screening for HIV positive Clients'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_4_3',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'TB/HIV'],
#    'text': 'Anti-Retroviral Therapy (ART) for HIV positive TB patients'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_4_4',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'TB/HIV'],
#    'text': ' INH Preventive therapy (IPT) for HIV positive clients'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_4_5',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'TB/HIV'],
#    'text': 'Co-trimoxazole preventive therapy during TB treatment for PLHIV'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_2_5_1',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Malaria'],
#    'text': 'Morbidity attributed to malaria'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_2_5_2',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Malaria'],
#    'text': 'Facility-based malaria deaths'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_2_5_3',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Malaria'],
#    'text': 'Malaria positivity rate'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_5_4',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Malaria'],
#    'text': 'Proportion of targeted HH covered with LLIN in the last 12 months'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_2_5_5',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Malaria'],
#    'text': 'Proportion of unit structures covered by indoor residual spraying (IRS)'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_2_6_2',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Communicable Diseases',
#     'Neglected Tropical Diseases'],
#    'text': 'Number of lymph edema cases treated'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_3_1',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Non Communicable Diseases'],
#    'text': 'Morbidity attributed to hypertension'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_3_2',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Non Communicable Diseases'],
#    'text': 'Morbidity attributed to diabetes mellitus'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_c_1_4_3_3',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Non Communicable Diseases'],
#    'text': 'Morbidity attributed to asthma'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_3_4',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Non Communicable Diseases'],
#    'text': 'Cervical cancer screening in women age 30 - 49 using VIA/PAP smear'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_1_4_3_5',
#    'programAreas': ['Improve Access to Health Services',
#     'Prevention and Control of Diseases',
#     'Non Communicable Diseases'],
#    'text': 'Cataract surgical rate'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_2_1',
#    'programAreas': ['Community Ownership'],
#    'text': 'Proportion of Model households graduated / Households Currently Model'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_c_2_2',
#    'programAreas': ['Community Ownership'],
#    'text': 'Proportion of functional 1 to 5 networks'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_f_1_1',
#    'programAreas': ['Resource Mobilization and Utilization'],
#    'text': 'General Government expenditure on health'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_f_1_2',
#    'programAreas': ['Resource Mobilization and Utilization'],
#    'text': 'Health budget utilization'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_f_1_3',
#    'programAreas': ['Resource Mobilization and Utilization'],
#    'text': 'Share of internal revenue generated'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_f_1_4',
#    'programAreas': ['Resource Mobilization and Utilization'],
#    'text': 'Proportion of reimbursed amount out of total patient fees waived'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_p_1_1',
#    'programAreas': ['Quality of Health Services'],
#    'text': 'Outpatient attendance per capita'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_p_1_2',
#    'programAreas': ['Quality of Health Services'],
#    'text': 'Admission rate'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_p_1_4',
#    'programAreas': ['Quality of Health Services'],
#    'text': 'Average length of stay'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_p_1_5',
#    'programAreas': ['Quality of Health Services'],
#    'text': 'Proportion of blood units utilized from blood bank service'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_p_1_6',
#    'programAreas': ['Quality of Health Services'],
#    'text': 'Series adverse transfusion incidents or reactions'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_p_3_1',
#    'programAreas': ['Pharmaceutical Supply and Services'],
#    'text': 'Essential drugs availability'},
#   {'decreaseIsGood': True,
#    'id': 'hmis_p_5_1',
#    'programAreas': ['Evidence Based Decision Making'],
#    'text': 'Integrated Supportive supervision'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_p_5_2',
#    'programAreas': ['Evidence Based Decision Making'],
#    'text': 'Reporting completeness'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_p_5_3',
#    'programAreas': ['Evidence Based Decision Making'],
#    'text': 'Reporting timeliness'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_cb_1_1',
#    'programAreas': ['Health Infrastructure'],
#    'text': 'Functional facility to population ratio'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_cb_1_2',
#    'programAreas': ['Health Infrastructure'],
#    'text': 'Health institutions newly constructed and upgraded'},
#   {'decreaseIsGood': False,
#    'id': 'hmis_cb_2_1',
#    'programAreas': ['Human Capital and Leaders'],
#    'text': 'Health staff to population ratio by category'}]}

# %%
IDlookup['hmis_indicator_3633']
# Out:
# {'id': 'hmis_indicator_3633',
#  'program_area': 'Communicable Diseases',
#  'sub_area': 'HIV/AIDS',
#  'text': 'Clients testing positive for HIV 25-49 years: Males'}

# %% [markdown]
# <h1> Load the data </h1>

# %%
with open('/Users/attiladobi/Downloads/car.json', 'rb') as f:
    data = f.readlines()
# remove the trailing "\n" from each line
data = map(lambda x: x.rstrip(), data)
data_json_str = "[" + ','.join(data) + "]"

# now, load it into pandas
DF2 = pd.read_json(data_json_str)

# %%
'_c_' in val
# Out:
# True

# %%
df_list = []
for region in DF2['byGeo'][0].keys():
    region_name = region.split('_')[0]
    meta_data = pd.DataFrame(DF2['byGeo'][0][region]['data']['month'])
    formatted_data = pd.DataFrame(meta_data[1:].stack()).reset_index(level=0)
    formatted_data.index = [pd.to_datetime(val) for val in formatted_data.index]
    formatted_data.columns = ['Indicator_id', 'val']
    formatted_data.index.name = 'Real_Date'
    formatted_data['Region'] = region_name
    df_list.append(formatted_data)
DF_ind=pd.concat(df_list)
DF_ind['Indicator'] = [IDlookup[val]['text'] for val in DF_ind['Indicator_id']]
if '_c_' not in val:
    DF_ind['program_area'] = [IDlookup[val]['program_area'] for val in DF_ind['Indicator_id']]
    DF_ind['sub_area'] = [IDlookup[val]['sub_area'] for val in DF_ind['Indicator_id']]

# %%
DF_ind.groupby('Indicator').val.sum().reset_index()
# Out:
#                        Indicator        val
# 0  Contraceptive acceptance rate  12.432422

# %%
DF_ind = DF_ind.replace(0,nan).dropna()
DF_ind['E_Date'] = [ethiopian_date.EthiopianDateConverter.date_to_ethiopian(date) for date in DF_ind.index]
DF_ind['E_Date'] =DF_ind['E_Date'].astype(datetime64)
DF_ind['E_year'] = [val.year for val in DF_ind['E_Date']]
DF_ind['E_month'] = [val.month for val in DF_ind['E_Date']]

# %%
DF_ind
# Out:
#               Indicator_id       val    Region                      Indicator  \
# Real_Date
# 2014-07-08  hmis_c_1_1_1_1  0.027017   harreri  Contraceptive acceptance rate
# 2014-08-07  hmis_c_1_1_1_1  0.040617   harreri  Contraceptive acceptance rate
# 2014-09-11  hmis_c_1_1_1_1  0.033247   harreri  Contraceptive acceptance rate
# 2014-10-11  hmis_c_1_1_1_1  0.037448   harreri  Contraceptive acceptance rate
# 2014-11-10  hmis_c_1_1_1_1  0.032233   harreri  Contraceptive acceptance rate
# 2014-12-10  hmis_c_1_1_1_1  0.044238   harreri  Contraceptive acceptance rate
# 2015-01-09  hmis_c_1_1_1_1  0.030675   harreri  Contraceptive acceptance rate
# 2015-02-08  hmis_c_1_1_1_1  0.035293   harreri  Contraceptive acceptance rate
# 2015-03-10  hmis_c_1_1_1_1  0.034713   harreri  Contraceptive acceptance rate
# 2015-04-09  hmis_c_1_1_1_1  0.050649   harreri  Contraceptive acceptance rate
# 2015-05-09  hmis_c_1_1_1_1  0.038154   harreri  Contraceptive acceptance rate
# 2015-06-08  hmis_c_1_1_1_1  0.129745   harreri  Contraceptive acceptance rate
# 2015-07-08  hmis_c_1_1_1_1  0.051463   harreri  Contraceptive acceptance rate
# 2015-08-07  hmis_c_1_1_1_1  0.037230   harreri  Contraceptive acceptance rate
# 2015-09-12  hmis_c_1_1_1_1  0.040291   harreri  Contraceptive acceptance rate
def pd_proper_dateformat(series):
    '''Given a pandas time series return x, y with the time formatted to plot in matplotlib'''
    return series.index.astype(datetime.datetime), series.values

def frac_err(num, sig_num, den, sig_den):
    return sqrt( (sig_num / den) ** 2 + ((sig_den * num) / (den**2)) ** 2)

# %%
def pd_proper_dateformat(series):
    '''Given a pandas time series return x, y with the time formatted to plot in matplotlib'''
    return series.index.astype(datetime.datetime), series.values

def plot_date_indicator(dataframe, indicator, ind2=None):
    to_plot = DF_ind.loc[DF_ind['Indicator'] == indicator].reset_index().groupby(['Region', 'E_Date']).val.sum()
    ylab_text = indicator    
    #If not none use indicator 2 as the denominator
    if ind2:
        to_plot /= DF_ind.loc[DF_ind['Indicator'] == ind2].reset_index().groupby(['Region', 'E_Date']).val.sum()
        ylab_text = '%s per \n %s' % (indicator, ind2)
        
    start,stop=0,1
    number_of_colors= len(to_plot.index.levels[0])
    cm_subsection = linspace(start, stop, number_of_colors) 
    colors = [ cm.jet(x) for x in cm_subsection ]

    fig=figure()
    fig.set_size_inches(13, 9)
    sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

    for level,color in zip(to_plot.index.levels[0],colors):
        x, y = pd_proper_dateformat(to_plot[level])
        plt.plot_date(x, y, '.-', color=color, markersize=20, label=level,)
    ylabel(ylab_text)
    xlabel('Date')
    legend(loc='upper right', numpoints=1,fontsize=12)
    ax = gca()
    ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter('%b\n%Y'))
    #ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter('%b'))
    #yscale('log')
    
    return to_plot

def plot_date_indicator_nation(dataframe, indicator, ind2=None, plt_err=False, plt_mean=False, plt_mean_std=False):
    to_plot = DF_ind.loc[DF_ind['Indicator'] == indicator].reset_index().groupby(['E_Date']).val.sum()
    yn = to_plot.values
    sqrtNn = sqrt(yn)
    y_err = sqrtNn
    ylab_text = indicator
    #If not none use indicator 2 as the denominator
    if ind2:
        to_plot_d = DF_ind.loc[DF_ind['Indicator'] == ind2].reset_index().groupby(['E_Date']).val.sum()
        to_plot /= to_plot_d
        yt = to_plot_d.values
        sqrtNt = sqrt(yt)
        y_err = frac_err(yn, sqrtNn, yt, sqrtNt)
        #use binomial error
        p = to_plot.values
        y_err = sqrt( p*(1-p) / yt )
        ylab_text = '%s per \n %s' % (indicator, ind2)
    
    to_plot = to_plot[4:-1]
    
    fig=figure()
    fig.set_size_inches(13, 9)
    sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
    x, y = pd_proper_dateformat(to_plot)
    y_mean = ones_like(y)*mean(y)
    y_mean_err = std(y) / sqrt(len(y))
    plt.plot_date(x, y, '.-', color='b', markersize=20, label='Nation',)
    
    if plt_err:
        plt.fill_between(x, y-y_err, y+y_err,
            alpha=0.2, edgecolor='#1B2ACC', facecolor='#089FFF',
            linewidth=4, linestyle='dashdot', antialiased=True, label=r'1 $\sigma$')
        
    if plt_mean:
        plt.plot_date(x, y_mean, '-', color='k', markersize=20, label='Mean',)
    if plt_mean_std:    
        plt.fill_between(x, y_mean-y_mean_err, y_mean+y_mean_err,
        alpha=0.2, edgecolor='black', facecolor='grey',
        linewidth=4, linestyle='dashdot', antialiased=True)
    
    #x has to be in int to fit the data
    x_fit = to_plot.index.astype(int)
    fit = np.poly1d(np.polyfit(x_fit, y, 1))
    y_lin = fit(x_fit)
    plt.plot_date(x, y_lin,'-', color='r', label='Liner Fit',)
    
    ylabel(ylab_text)
    xlabel('Date')
    legend(loc='upper right', numpoints=1,fontsize=12)
    ax = gca()
    ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter('%b\n%Y'))
    
    return to_plot

# %%
indicator = 'Contraceptive acceptance rate'
series_d = plot_date_indicator(DF_ind, indicator)
series_d = plot_date_indicator_nation(DF_ind, indicator, plt_mean=False)

# %%
series_d.index[0][1]
# Out:
# Timestamp('2014-07-08 00:00:00')

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
series_d_diff = (series_d[4:-1] - series_d[4:-1].shift())[1:]
series_d_diff
# Out:
# Region       Real_Date
# addis ababa  2014-12-10    0.008485
#              2015-01-09   -0.007251
#              2015-02-08    0.010409
#              2015-03-10    0.017822
#              2015-04-09   -0.022501
#              2015-05-09    0.002248
#              2015-06-08    0.007672
#              2015-07-08   -0.000823
#              2015-08-07    0.000574
#              2015-09-12    0.001339
#              2015-10-12   -0.006161
#              2015-11-11   -0.002067
#              2015-12-11    0.000277
#              2016-01-10   -0.000057
#              2016-02-09    0.002260
#              2016-03-10    0.001872
#              2016-04-09   -0.004405
#              2016-05-09   -0.003993
#              2016-06-08    0.001755
#              2016-07-08    0.003241
#              2016-08-07   -0.000747
#              2016-09-11    0.002529
#              2016-10-11   -0.001769
# afar         2014-04-09   -0.029683
#              2014-07-08    0.018690
#                              ...
# tigray       2014-09-11    0.006076
#              2014-10-11   -0.012998
#              2014-11-10   -0.002643
#              2014-12-10    0.007525
#              2015-01-09   -0.000742
#              2015-02-08   -0.001387
#              2015-03-10   -0.000870
#              2015-04-09    0.000114
#              2015-05-09    0.003378
#              2015-06-08   -0.000359
#              2015-07-08    0.007223
#              2015-08-07   -0.001607
#              2015-09-12    0.006153
#              2015-10-12   -0.011678
#              2015-11-11   -0.004960
#              2015-12-11    0.004011
#              2016-01-10   -0.000239
#              2016-02-09   -0.001507
#              2016-03-10   -0.000340
#              2016-04-09   -0.001437
#              2016-05-09   -0.001651
#              2016-06-08    0.005937
#              2016-07-08    0.003751
#              2016-08-07    0.001477
#              2016-09-11    0.007345
# Name: val, dtype: float64

# %%
model = ARIMA(series_d[2:-1], order=(0, 1, 2)) 
results_MA = model.fit(disp=-1) 
plt.plot(series_d_diff)
plt.plot(results_MA.fittedvalues, color='red')

# %%
model = ARIMA(series_d[2:-1], order=(0, 1, 2))  
results_MA = model.fit(disp=-1)  
plt.plot(series_d_diff)
plt.plot(results_MA.fittedvalues, color='red')

# %% [markdown]
# <h1> Combined model </h1>

# %%
series_d_diff = series_d[3:-1]-series_d[3:-1].shift()
series_d.dropna(inplace=True)

# %%
model = ARIMA(series_d[3:-1], order=(2,1,2))  
results_ARIMA = model.fit(disp=-1)  
plt.plot(series_d_diff)
plt.plot(results_ARIMA.fittedvalues, color='red')

# %% [markdown]
# <h1> original scale </h1>

# %%
rng = pd.date_range('09/07/2014', periods=40, freq='M')
rng

#results_ARIMA.predict(start = 1, end = 100)
# Out:
# DatetimeIndex(['2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31',
#                '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30',
#                '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31',
#                '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31',
#                '2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30',
#                '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31',
#                '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31',
#                '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30',
#                '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31',
#                '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
predictions_ARIMA_diff = pd.Series(results_ARIMA.predict(end = 40), copy=True)
#print predictions_ARIMA_diff.head()

predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
#print predictions_ARIMA_diff_cumsum.head()
predictions_ARIMA_diff_cumsum.index = rng
predictions_ARIMA_diff_cumsum
# Out:
# 2014-09-30    0.003138
# 2014-10-31    0.016355
# 2014-11-30    0.037193
# 2014-12-31    0.007031
# 2015-01-31    0.017044
# 2015-02-28    0.047523
# 2015-03-31    0.014588
# 2015-04-30   -0.002853
# 2015-05-31    0.053962
# 2015-06-30    0.041715
# 2015-07-31    0.005872
# 2015-08-31    0.065790
# 2015-09-30    0.054701
# 2015-10-31    0.024370
# 2015-11-30    0.062285
# 2015-12-31    0.072095
# 2016-01-31    0.034592
# 2016-02-29    0.070423
# 2016-03-31    0.083253
# 2016-04-30    0.041773
# 2016-05-31    0.070703
# 2016-06-30    0.097041
# 2016-07-31    0.054909
# 2016-08-31    0.073259
# 2016-09-30    0.108593
# 2016-10-31    0.069339
# 2016-11-30    0.076298
# 2016-12-31    0.118407
# 2017-01-31    0.084760
# 2017-02-28    0.080228
# 2017-03-31    0.126478
# 2017-04-30    0.100767
# 2017-05-31    0.085396
# 2017-06-30    0.132919
# 2017-07-31    0.116922
# 2017-08-31    0.092064
# 2017-09-30    0.137943
# 2017-10-31    0.132782
# 2017-11-30    0.100390
# 2017-12-31    0.141858
# Freq: M, dtype: float64

# %%
predictions_ARIMA_log = pd.Series(series_d.ix[2], index=rng) #
predictions_ARIMA_log
predictions_ARIMA_diff_cumsum
# Out:
# 2014-09-30    0.003138
# 2014-10-31    0.016355
# 2014-11-30    0.037193
# 2014-12-31    0.007031
# 2015-01-31    0.017044
# 2015-02-28    0.047523
# 2015-03-31    0.014588
# 2015-04-30   -0.002853
# 2015-05-31    0.053962
# 2015-06-30    0.041715
# 2015-07-31    0.005872
# 2015-08-31    0.065790
# 2015-09-30    0.054701
# 2015-10-31    0.024370
# 2015-11-30    0.062285
# 2015-12-31    0.072095
# 2016-01-31    0.034592
# 2016-02-29    0.070423
# 2016-03-31    0.083253
# 2016-04-30    0.041773
# 2016-05-31    0.070703
# 2016-06-30    0.097041
# 2016-07-31    0.054909
# 2016-08-31    0.073259
# 2016-09-30    0.108593
# 2016-10-31    0.069339
# 2016-11-30    0.076298
# 2016-12-31    0.118407
# 2017-01-31    0.084760
# 2017-02-28    0.080228
# 2017-03-31    0.126478
# 2017-04-30    0.100767
# 2017-05-31    0.085396
# 2017-06-30    0.132919
# 2017-07-31    0.116922
# 2017-08-31    0.092064
# 2017-09-30    0.137943
# 2017-10-31    0.132782
# 2017-11-30    0.100390
# 2017-12-31    0.141858
# Freq: M, dtype: float64

# %%
predictions_ARIMA_log = pd.Series(series_d.ix[2], index=rng) #series_d[3:-1].index
predictions_ARIMA_log = predictions_ARIMA_log.add(1*predictions_ARIMA_diff_cumsum,fill_value=0)

# %%
plt.plot(series_d[3:-1])
plt.plot(predictions_ARIMA_log[20:40])

# %% [markdown]
# <h1> LSTM </h1>

# %%
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# Out:
# Using TensorFlow backend.
