# %% [markdown]
# <h1> Initial NACOSA M&E study </h1>

# %%
from __future__ import division
import psycopg2
import numpy as np
import json
import re
from ast import literal_eval
import pandas as pd
# %pylab inline
pylab.rcParams['figure.figsize'] = (12.0, 8.0) # set size of figures"
plt.rcParams.update({'font.size': 24})
import seaborn as sns

from nvd3 import multiBarChart
import nvd3
nvd3.ipynb.initialize_javascript(use_remote=True)

from IPython.html.widgets import *
# Out:
# Populating the interactive namespace from numpy and matplotlib
# loaded nvd3 IPython extension
# run nvd3.ipynb.initialize_javascript() to set up the notebook
# help(nvd3.ipynb.initialize_javascript) for options
# <link media="all" href="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.css" type="text/css"
#                         rel="stylesheet"/>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.js"></script>
# /Users/attiladobi/anaconda2/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
def quarter_map(year,month):
    val=0
    if ((year==2016) & (month>=4) & (month<=6)):
        val=1
    elif ((year==2016) & (month>=7) & (month<=9)):
        val=2
    elif ((year==2016) & (month>=10) & (month<=12)):
        val=3
    else:
        val=0
    return val

# %%
# read the entire file into a python array
with open('/Users/attiladobi/Downloads/za_integration.json', 'rb') as f:
    data = f.readlines()

# remove the trailing "\n" from each line
data = map(lambda x: x.rstrip(), data)

# each element of 'data' is an individual JSON object.
# i want to convert it into an *array* of JSON objects
# which, in and of itself, is one large JSON object
# basically... add square brackets to the beginning
# and end, and have all the individual business JSON objects
# separated by a comma
data_json_str = "[" + ','.join(data) + "]"

# now, load it into pandas
DF = pd.read_json(data_json_str)

#convert date:
DF['Date']=pd.to_datetime(DF['Real_Date'])
DF['day'] = DF['Date'].dt.day
DF['month'] = DF['Date'].dt.month
DF['year'] = DF['Date'].dt.year

#ADD Quarter grouping to the data
DF['Quarter']=[quarter_map(year,month) for year,month in DF[['year','month']].values]

DF['subrecipient']=DF['subrecipient'].replace('nqobile women','nqobile')

#standardize names
DF['field']=DF['field'].replace('red_umbrella_male_condom_lube','f_1_male_condoms_number_given')

# %%
DF.groupby(['subrecipient','province']).count()
# Out:
#                             Real_Date  beneficiary  budget_line  \
# subrecipient province
# cpc          gauteng            98618        98406            0
#              limpopo            48990        48942            0
#              north west         68032        67918            0
# grip         mpumalanga         60869        60869            0
# htt          limpopo              719          719            0
#              mpumalanga         19483        19483            0
# humana       gauteng               98            0            0
# ll           free state           384          384            0
#              kwazulu-natal        712          712            0
#              northern cape        308          308            0
# lljbh        gauteng               98            0            0
# llpc         free state           910          910            0
# nqobile      gauteng            14184        14070            0
# oasis        gauteng            17991        17877            0
# phru         gauteng              114            0            0
# psh          northern cape        223          223            0
#              western cape         288          288            0
# qac          free state          7429         7429            0
# qlac         free state           114            0            0
# sweat        eastern cape        9039         8933            0
#              north west         51599        51599            0
#              western cape       36199        36048            0
# whri         gauteng             1377         1377            0
# wrhi         gauteng              721          721            0
#
#                             budget_line_full  cost_category  description  \
# subrecipient province
# cpc          gauteng                       0              0            0
#              limpopo                       0              0            0
#              north west                    0              0            0
# grip         mpumalanga                    0              0            0
# htt          limpopo                       0              0            0
#              mpumalanga                    0              0            0
# humana       gauteng                       0              0            0
# ll           free state                    0              0            0
#              kwazulu-natal                 0              0            0
#              northern cape                 0              0            0
# lljbh        gauteng                       0              0            0
# llpc         free state                    0              0            0
# nqobile      gauteng                       0              0            0
# oasis        gauteng                       0              0            0
# phru         gauteng                       0              0            0
# psh          northern cape                 0              0            0
#              western cape                  0              0            0
# qac          free state                    0              0            0
# qlac         free state                    0              0            0
# sweat        eastern cape                  0              0            0
#              north west                    0              0            0
#              western cape                  0              0            0
# whri         gauteng                       0              0            0
# wrhi         gauteng                       0              0            0
#
#                             field  invoice_receipt_number  peer_motivator  \
# subrecipient province
# cpc          gauteng        98618                       0           97154
#              limpopo        48990                       0           47221
#              north west     68032                       0           67063
# grip         mpumalanga     60869                       0           58925
# htt          limpopo          719                       0               0
#              mpumalanga     19483                       0           18950
# humana       gauteng           98                       0               0
# ll           free state       384                       0               0
#              kwazulu-natal    712                       0               0
#              northern cape    308                       0               0
# lljbh        gauteng           98                       0               0
# llpc         free state       910                       0               0
# nqobile      gauteng        14184                       0           13361
# oasis        gauteng        17991                       0           17098
# phru         gauteng          114                       0               0
# psh          northern cape    223                       0               0
#              western cape     288                       0               0
# qac          free state      7429                       0            7429
# qlac         free state       114                       0               0
# sweat        eastern cape    9039                       0            8911
#              north west     51599                       0           50864
#              western cape   36199                       0           35382
# whri         gauteng         1377                       0               0
# wrhi         gauteng          721                       0               0
#
#                             province_lat   ...     site_lng  suburb  \
# subrecipient province                      ...
# cpc          gauteng               98618   ...        98618   98406
#              limpopo               48990   ...        48990   48942
#              north west            68032   ...        68032   67918
# grip         mpumalanga            60869   ...        60869   60869
# htt          limpopo                 719   ...          719     719
#              mpumalanga            19483   ...        19483   19483
# humana       gauteng                  98   ...           98       0
# ll           free state              384   ...          384     384
#              kwazulu-natal           712   ...          712     712
#              northern cape           308   ...          308     308
# lljbh        gauteng                  98   ...           98       0
# llpc         free state              910   ...          910     910
# nqobile      gauteng               14184   ...        14184   14070
# oasis        gauteng               17991   ...        17991   17877
# phru         gauteng                 114   ...          114       0
# psh          northern cape           223   ...          223     223
#              western cape            288   ...          288     288
# qac          free state             7429   ...         7429    7429
# qlac         free state              114   ...          114       0
# sweat        eastern cape           9039   ...         9039    8933
#              north west            51599   ...        51599   51599
#              western cape          36199   ...        36199   36048
# whri         gauteng                1377   ...         1377    1377
# wrhi         gauteng                 721   ...          721     721
#
#                             supplier_employee_name  transaction_reference  \
# subrecipient province
# cpc          gauteng                             0                      0
#              limpopo                             0                      0
#              north west                          0                      0
# grip         mpumalanga                          0                      0
# htt          limpopo                             0                      0
#              mpumalanga                          0                      0
# humana       gauteng                             0                      0
# ll           free state                          0                      0
#              kwazulu-natal                       0                      0
#              northern cape                       0                      0
# lljbh        gauteng                             0                      0
# llpc         free state                          0                      0
# nqobile      gauteng                             0                      0
# oasis        gauteng                             0                      0
# phru         gauteng                             0                      0
# psh          northern cape                       0                      0
#              western cape                        0                      0
# qac          free state                          0                      0
# qlac         free state                          0                      0
# sweat        eastern cape                        0                      0
#              north west                          0                      0
#              western cape                        0                      0
# whri         gauteng                             0                      0
# wrhi         gauteng                             0                      0
#
#                               val   Date    day  month   year  Quarter
# subrecipient province
# cpc          gauteng        98618  98618  98618  98618  98618    98618
#              limpopo        48990  48990  48990  48990  48990    48990
#              north west     68032  68032  68032  68032  68032    68032
# grip         mpumalanga     60869  60869  60869  60869  60869    60869
# htt          limpopo          719    719    719    719    719      719
#              mpumalanga     19483  19483  19483  19483  19483    19483
# humana       gauteng           98     98     98     98     98       98
# ll           free state       384    384    384    384    384      384
#              kwazulu-natal    712    712    712    712    712      712
#              northern cape    308    308    308    308    308      308
# lljbh        gauteng           98     98     98     98     98       98
# llpc         free state       910    910    910    910    910      910
# nqobile      gauteng        14184  14184  14184  14184  14184    14184
# oasis        gauteng        17991  17991  17991  17991  17991    17991
# phru         gauteng          114    114    114    114    114      114
# psh          northern cape    223    223    223    223    223      223
#              western cape     288    288    288    288    288      288
# qac          free state      7429   7429   7429   7429   7429     7429
# qlac         free state       114    114    114    114    114      114
# sweat        eastern cape    9039   9039   9039   9039   9039     9039
#              north west     51599  51599  51599  51599  51599    51599
#              western cape   36199  36199  36199  36199  36199    36199
# whri         gauteng         1377   1377   1377   1377   1377     1377
# wrhi         gauteng          721    721    721    721    721      721
#
# [24 rows x 23 columns]

# %%
DF.groupby('field').count()
# Out:
#                                                     Real_Date  beneficiary  \
# field
# amount_allocated_to_global_fund                          3647            0
# amount_excluding_vat                                     3650            0
# amount_including_vat                                     3653            0
# amount_paid                                              3638            0
# b2_sw_tested_hiv_negative                                 747          747
# b4_a_referred_for_art1_referred                           507          507
# b6_sws_who_refused_hiv_test                               273          273
# b_1_received_hts_and_know_results                        1263         1263
# b_3_newly_diagnosed_hiv_positive_sw                       396          396
# b_4b_initiated_on_art1_initiated                           36           36
# b_5_known_hiv_positive_status                            4119         4119
# b_7_hiv_negative_sws_receiving_prep                        82           82
# b_8_b_succesful_referal_to_treatment_adherence_...         27           27
# b_8a_referred_to_treatment_adherence_clubs               2727         2727
# behavioural_safety_intervention_e_g_substance_a...      13363        13363
# budget                                                  16253            0
# c1_sws_screened_for_sexually_transmitted_infect...       8000         8000
# c2_sti_referral_1_referred                                359          359
# c2b_successful_sti_referal                                 54           54
# counter_1_first_outreach_for_quarter                   113968       113968
# d1_number_of_sws_screened_for_tb                         7633         7633
# d2a_tb_referal_to_health_facility1_referred               369          369
# d2b_succesful_tb_referal                                   24           24
# did_client_face_any_human_rights_violation                643          643
# difference                                               3657            0
# e4_support_group_workshops                                105          105
# f3_lube                                                  6505         6505
# f_1_male_condoms_number_given                           54162        54162
# female_condom                                           10533        10533
# goody_bags                                               2496         2496
# hct_screening                                           14858        14858
# health_and_sexual_reproductive_health_services          24349        24349
# hiv_negative_sws_referred_for_prep                        338          338
# iec                                                      9796         9796
# number_of_services_received_in_quarter                 114463       114463
# other_condoms_e_g_doh                                   25565        25565
# paralegal_human_rights_education_health_other_s...      14681        14681
# referral_to_human_rights_organisations1_referred          263          263
# risk_reduction_workshop                                  4512         4512
# spend                                                   16253            0
# target_a1_number_of_sex_workers_reached_with_hi...        139            0
# target_a2_number_of_sex_workers_who_received_on...        139            0
# target_b1_number_of_sex_workers_that_have_recei...        128            0
# target_e1_number_of_creative_space_workshops              139            0
# target_e2_number_of_sws_attending_creative_spac...        139            0
# target_e3_number_of_small_group_workshops                  99            0
# target_e4_number_of_sws_attending_small_group_w...         99            0
# target_f1_number_of_male_condoms_distributed              139            0
# target_f2_number_of_female_condoms_distributed            139            0
# target_f3_number_of_lube_distributed                      139            0
# variance                                                16253            0
#
#                                                     budget_line  \
# field
# amount_allocated_to_global_fund                            3644
# amount_excluding_vat                                       3647
# amount_including_vat                                       3650
# amount_paid                                                3635
# b2_sw_tested_hiv_negative                                     0
# b4_a_referred_for_art1_referred                               0
# b6_sws_who_refused_hiv_test                                   0
# b_1_received_hts_and_know_results                             0
# b_3_newly_diagnosed_hiv_positive_sw                           0
# b_4b_initiated_on_art1_initiated                              0
# b_5_known_hiv_positive_status                                 0
# b_7_hiv_negative_sws_receiving_prep                           0
# b_8_b_succesful_referal_to_treatment_adherence_...            0
# b_8a_referred_to_treatment_adherence_clubs                    0
# behavioural_safety_intervention_e_g_substance_a...            0
# budget                                                    16253
# c1_sws_screened_for_sexually_transmitted_infect...            0
# c2_sti_referral_1_referred                                    0
# c2b_successful_sti_referal                                    0
# counter_1_first_outreach_for_quarter                          0
# d1_number_of_sws_screened_for_tb                              0
# d2a_tb_referal_to_health_facility1_referred                   0
# d2b_succesful_tb_referal                                      0
# did_client_face_any_human_rights_violation                    0
# difference                                                 3654
# e4_support_group_workshops                                    0
# f3_lube                                                       0
# f_1_male_condoms_number_given                                 0
# female_condom                                                 0
# goody_bags                                                    0
# hct_screening                                                 0
# health_and_sexual_reproductive_health_services                0
# hiv_negative_sws_referred_for_prep                            0
# iec                                                           0
# number_of_services_received_in_quarter                        0
# other_condoms_e_g_doh                                         0
# paralegal_human_rights_education_health_other_s...            0
# referral_to_human_rights_organisations1_referred              0
# risk_reduction_workshop                                       0
# spend                                                     16253
# target_a1_number_of_sex_workers_reached_with_hi...            0
# target_a2_number_of_sex_workers_who_received_on...            0
# target_b1_number_of_sex_workers_that_have_recei...            0
# target_e1_number_of_creative_space_workshops                  0
# target_e2_number_of_sws_attending_creative_spac...            0
# target_e3_number_of_small_group_workshops                     0
# target_e4_number_of_sws_attending_small_group_w...            0
# target_f1_number_of_male_condoms_distributed                  0
# target_f2_number_of_female_condoms_distributed                0
# target_f3_number_of_lube_distributed                          0
# variance                                                  16253
#
#                                                     budget_line_full  \
# field
# amount_allocated_to_global_fund                                 3644
# amount_excluding_vat                                            3647
# amount_including_vat                                            3650
# amount_paid                                                     3635
# b2_sw_tested_hiv_negative                                          0
# b4_a_referred_for_art1_referred                                    0
# b6_sws_who_refused_hiv_test                                        0
# b_1_received_hts_and_know_results                                  0
# b_3_newly_diagnosed_hiv_positive_sw                                0
# b_4b_initiated_on_art1_initiated                                   0
# b_5_known_hiv_positive_status                                      0
# b_7_hiv_negative_sws_receiving_prep                                0
# b_8_b_succesful_referal_to_treatment_adherence_...                 0
# b_8a_referred_to_treatment_adherence_clubs                         0
# behavioural_safety_intervention_e_g_substance_a...                 0
# budget                                                         16253
# c1_sws_screened_for_sexually_transmitted_infect...                 0
# c2_sti_referral_1_referred                                         0
# c2b_successful_sti_referal                                         0
# counter_1_first_outreach_for_quarter                               0
# d1_number_of_sws_screened_for_tb                                   0
# d2a_tb_referal_to_health_facility1_referred                        0
# d2b_succesful_tb_referal                                           0
# did_client_face_any_human_rights_violation                         0
# difference                                                      3654
# e4_support_group_workshops                                         0
# f3_lube                                                            0
# f_1_male_condoms_number_given                                      0
# female_condom                                                      0
# goody_bags                                                         0
# hct_screening                                                      0
# health_and_sexual_reproductive_health_services                     0
# hiv_negative_sws_referred_for_prep                                 0
# iec                                                                0
# number_of_services_received_in_quarter                             0
# other_condoms_e_g_doh                                              0
# paralegal_human_rights_education_health_other_s...                 0
# referral_to_human_rights_organisations1_referred                   0
# risk_reduction_workshop                                            0
# spend                                                          16253
# target_a1_number_of_sex_workers_reached_with_hi...                 0
# target_a2_number_of_sex_workers_who_received_on...                 0
# target_b1_number_of_sex_workers_that_have_recei...                 0
# target_e1_number_of_creative_space_workshops                       0
# target_e2_number_of_sws_attending_creative_spac...                 0
# target_e3_number_of_small_group_workshops                          0
# target_e4_number_of_sws_attending_small_group_w...                 0
# target_f1_number_of_male_condoms_distributed                       0
# target_f2_number_of_female_condoms_distributed                     0
# target_f3_number_of_lube_distributed                               0
# variance                                                       16253
#
#                                                     cost_category  \
# field
# amount_allocated_to_global_fund                              3643
# amount_excluding_vat                                         3646
# amount_including_vat                                         3649
# amount_paid                                                  3634
# b2_sw_tested_hiv_negative                                       0
# b4_a_referred_for_art1_referred                                 0
# b6_sws_who_refused_hiv_test                                     0
# b_1_received_hts_and_know_results                               0
# b_3_newly_diagnosed_hiv_positive_sw                             0
# b_4b_initiated_on_art1_initiated                                0
# b_5_known_hiv_positive_status                                   0
# b_7_hiv_negative_sws_receiving_prep                             0
# b_8_b_succesful_referal_to_treatment_adherence_...              0
# b_8a_referred_to_treatment_adherence_clubs                      0
# behavioural_safety_intervention_e_g_substance_a...              0
# budget                                                      16253
# c1_sws_screened_for_sexually_transmitted_infect...              0
# c2_sti_referral_1_referred                                      0
# c2b_successful_sti_referal                                      0
# counter_1_first_outreach_for_quarter                            0
# d1_number_of_sws_screened_for_tb                                0
# d2a_tb_referal_to_health_facility1_referred                     0
# d2b_succesful_tb_referal                                        0
# did_client_face_any_human_rights_violation                      0
# difference                                                   3653
# e4_support_group_workshops                                      0
# f3_lube                                                         0
# f_1_male_condoms_number_given                                   0
# female_condom                                                   0
# goody_bags                                                      0
# hct_screening                                                   0
# health_and_sexual_reproductive_health_services                  0
# hiv_negative_sws_referred_for_prep                              0
# iec                                                             0
# number_of_services_received_in_quarter                          0
# other_condoms_e_g_doh                                           0
# paralegal_human_rights_education_health_other_s...              0
# referral_to_human_rights_organisations1_referred                0
# risk_reduction_workshop                                         0
# spend                                                       16253
# target_a1_number_of_sex_workers_reached_with_hi...              0
# target_a2_number_of_sex_workers_who_received_on...              0
# target_b1_number_of_sex_workers_that_have_recei...              0
# target_e1_number_of_creative_space_workshops                    0
# target_e2_number_of_sws_attending_creative_spac...              0
# target_e3_number_of_small_group_workshops                       0
# target_e4_number_of_sws_attending_small_group_w...              0
# target_f1_number_of_male_condoms_distributed                    0
# target_f2_number_of_female_condoms_distributed                  0
# target_f3_number_of_lube_distributed                            0
# variance                                                    16253
#
#                                                     description  \
# field
# amount_allocated_to_global_fund                               0
# amount_excluding_vat                                          0
# amount_including_vat                                          0
# amount_paid                                                   0
# b2_sw_tested_hiv_negative                                     0
# b4_a_referred_for_art1_referred                               0
# b6_sws_who_refused_hiv_test                                   0
# b_1_received_hts_and_know_results                             0
# b_3_newly_diagnosed_hiv_positive_sw                           0
# b_4b_initiated_on_art1_initiated                              0
# b_5_known_hiv_positive_status                                 0
# b_7_hiv_negative_sws_receiving_prep                           0
# b_8_b_succesful_referal_to_treatment_adherence_...            0
# b_8a_referred_to_treatment_adherence_clubs                    0
# behavioural_safety_intervention_e_g_substance_a...            0
# budget                                                    16253
# c1_sws_screened_for_sexually_transmitted_infect...            0
# c2_sti_referral_1_referred                                    0
# c2b_successful_sti_referal                                    0
# counter_1_first_outreach_for_quarter                          0
# d1_number_of_sws_screened_for_tb                              0
# d2a_tb_referal_to_health_facility1_referred                   0
# d2b_succesful_tb_referal                                      0
# did_client_face_any_human_rights_violation                    0
# difference                                                    0
# e4_support_group_workshops                                    0
# f3_lube                                                       0
# f_1_male_condoms_number_given                                 0
# female_condom                                                 0
# goody_bags                                                    0
# hct_screening                                                 0
# health_and_sexual_reproductive_health_services                0
# hiv_negative_sws_referred_for_prep                            0
# iec                                                           0
# number_of_services_received_in_quarter                        0
# other_condoms_e_g_doh                                         0
# paralegal_human_rights_education_health_other_s...            0
# referral_to_human_rights_organisations1_referred              0
# risk_reduction_workshop                                       0
# spend                                                     16253
# target_a1_number_of_sex_workers_reached_with_hi...            0
# target_a2_number_of_sex_workers_who_received_on...            0
# target_b1_number_of_sex_workers_that_have_recei...            0
# target_e1_number_of_creative_space_workshops                  0
# target_e2_number_of_sws_attending_creative_spac...            0
# target_e3_number_of_small_group_workshops                     0
# target_e4_number_of_sws_attending_small_group_w...            0
# target_f1_number_of_male_condoms_distributed                  0
# target_f2_number_of_female_condoms_distributed                0
# target_f3_number_of_lube_distributed                          0
# variance                                                  16253
#
#                                                     invoice_receipt_number  \
# field
# amount_allocated_to_global_fund                                       3627
# amount_excluding_vat                                                  3637
# amount_including_vat                                                  3633
# amount_paid                                                           3625
# b2_sw_tested_hiv_negative                                                0
# b4_a_referred_for_art1_referred                                          0
# b6_sws_who_refused_hiv_test                                              0
# b_1_received_hts_and_know_results                                        0
# b_3_newly_diagnosed_hiv_positive_sw                                      0
# b_4b_initiated_on_art1_initiated                                         0
# b_5_known_hiv_positive_status                                            0
# b_7_hiv_negative_sws_receiving_prep                                      0
# b_8_b_succesful_referal_to_treatment_adherence_...                       0
# b_8a_referred_to_treatment_adherence_clubs                               0
# behavioural_safety_intervention_e_g_substance_a...                       0
# budget                                                                   0
# c1_sws_screened_for_sexually_transmitted_infect...                       0
# c2_sti_referral_1_referred                                               0
# c2b_successful_sti_referal                                               0
# counter_1_first_outreach_for_quarter                                     0
# d1_number_of_sws_screened_for_tb                                         0
# d2a_tb_referal_to_health_facility1_referred                              0
# d2b_succesful_tb_referal                                                 0
# did_client_face_any_human_rights_violation                               0
# difference                                                            3637
# e4_support_group_workshops                                               0
# f3_lube                                                                  0
# f_1_male_condoms_number_given                                            0
# female_condom                                                            0
# goody_bags                                                               0
# hct_screening                                                            0
# health_and_sexual_reproductive_health_services                           0
# hiv_negative_sws_referred_for_prep                                       0
# iec                                                                      0
# number_of_services_received_in_quarter                                   0
# other_condoms_e_g_doh                                                    0
# paralegal_human_rights_education_health_other_s...                       0
# referral_to_human_rights_organisations1_referred                         0
# risk_reduction_workshop                                                  0
# spend                                                                    0
# target_a1_number_of_sex_workers_reached_with_hi...                       0
# target_a2_number_of_sex_workers_who_received_on...                       0
# target_b1_number_of_sex_workers_that_have_recei...                       0
# target_e1_number_of_creative_space_workshops                             0
# target_e2_number_of_sws_attending_creative_spac...                       0
# target_e3_number_of_small_group_workshops                                0
# target_e4_number_of_sws_attending_small_group_w...                       0
# target_f1_number_of_male_condoms_distributed                             0
# target_f2_number_of_female_condoms_distributed                           0
# target_f3_number_of_lube_distributed                                     0
# variance                                                                 0
#
#                                                     peer_motivator  province  \
# field
# amount_allocated_to_global_fund                                  0         0
# amount_excluding_vat                                             0         0
# amount_including_vat                                             0         0
# amount_paid                                                      0         0
# b2_sw_tested_hiv_negative                                      747       747
# b4_a_referred_for_art1_referred                                507       507
# b6_sws_who_refused_hiv_test                                    273       273
# b_1_received_hts_and_know_results                             1263      1263
# b_3_newly_diagnosed_hiv_positive_sw                            396       396
# b_4b_initiated_on_art1_initiated                                36        36
# b_5_known_hiv_positive_status                                 4119      4119
# b_7_hiv_negative_sws_receiving_prep                             82        82
# b_8_b_succesful_referal_to_treatment_adherence_...              27        27
# b_8a_referred_to_treatment_adherence_clubs                    2727      2727
# behavioural_safety_intervention_e_g_substance_a...           13363     13363
# budget                                                           0         0
# c1_sws_screened_for_sexually_transmitted_infect...            8000      8000
# c2_sti_referral_1_referred                                     359       359
# c2b_successful_sti_referal                                      54        54
# counter_1_first_outreach_for_quarter                        113968    113968
# d1_number_of_sws_screened_for_tb                              7633      7633
# d2a_tb_referal_to_health_facility1_referred                    369       369
# d2b_succesful_tb_referal                                        24        24
# did_client_face_any_human_rights_violation                     643       643
# difference                                                       0         0
# e4_support_group_workshops                                     105       105
# f3_lube                                                       6505      6505
# f_1_male_condoms_number_given                                54162     54162
# female_condom                                                10533     10533
# goody_bags                                                    2496      2496
# hct_screening                                                    0     14858
# health_and_sexual_reproductive_health_services               24349     24349
# hiv_negative_sws_referred_for_prep                             338       338
# iec                                                           9796      9796
# number_of_services_received_in_quarter                      114463    114463
# other_condoms_e_g_doh                                        25565     25565
# paralegal_human_rights_education_health_other_s...           14681     14681
# referral_to_human_rights_organisations1_referred               263       263
# risk_reduction_workshop                                       4512      4512
# spend                                                            0         0
# target_a1_number_of_sex_workers_reached_with_hi...               0       137
# target_a2_number_of_sex_workers_who_received_on...               0       137
# target_b1_number_of_sex_workers_that_have_recei...               0       126
# target_e1_number_of_creative_space_workshops                     0       137
# target_e2_number_of_sws_attending_creative_spac...               0       137
# target_e3_number_of_small_group_workshops                        0        99
# target_e4_number_of_sws_attending_small_group_w...               0        99
# target_f1_number_of_male_condoms_distributed                     0       137
# target_f2_number_of_female_condoms_distributed                   0       137
# target_f3_number_of_lube_distributed                             0       137
# variance                                                         0         0
#
#                                                     province_lat   ...     \
# field                                                              ...
# amount_allocated_to_global_fund                                0   ...
# amount_excluding_vat                                           0   ...
# amount_including_vat                                           0   ...
# amount_paid                                                    0   ...
# b2_sw_tested_hiv_negative                                    747   ...
# b4_a_referred_for_art1_referred                              507   ...
# b6_sws_who_refused_hiv_test                                  273   ...
# b_1_received_hts_and_know_results                           1263   ...
# b_3_newly_diagnosed_hiv_positive_sw                          396   ...
# b_4b_initiated_on_art1_initiated                              36   ...
# b_5_known_hiv_positive_status                               4119   ...
# b_7_hiv_negative_sws_receiving_prep                           82   ...
# b_8_b_succesful_referal_to_treatment_adherence_...            27   ...
# b_8a_referred_to_treatment_adherence_clubs                  2727   ...
# behavioural_safety_intervention_e_g_substance_a...         13363   ...
# budget                                                         0   ...
# c1_sws_screened_for_sexually_transmitted_infect...          8000   ...
# c2_sti_referral_1_referred                                   359   ...
# c2b_successful_sti_referal                                    54   ...
# counter_1_first_outreach_for_quarter                      113968   ...
# d1_number_of_sws_screened_for_tb                            7633   ...
# d2a_tb_referal_to_health_facility1_referred                  369   ...
# d2b_succesful_tb_referal                                      24   ...
# did_client_face_any_human_rights_violation                   643   ...
# difference                                                     0   ...
# e4_support_group_workshops                                   105   ...
# f3_lube                                                     6505   ...
# f_1_male_condoms_number_given                              54162   ...
# female_condom                                              10533   ...
# goody_bags                                                  2496   ...
# hct_screening                                              14858   ...
# health_and_sexual_reproductive_health_services             24349   ...
# hiv_negative_sws_referred_for_prep                           338   ...
# iec                                                         9796   ...
# number_of_services_received_in_quarter                    114463   ...
# other_condoms_e_g_doh                                      25565   ...
# paralegal_human_rights_education_health_other_s...         14681   ...
# referral_to_human_rights_organisations1_referred             263   ...
# risk_reduction_workshop                                     4512   ...
# spend                                                          0   ...
# target_a1_number_of_sex_workers_reached_with_hi...           137   ...
# target_a2_number_of_sex_workers_who_received_on...           137   ...
# target_b1_number_of_sex_workers_that_have_recei...           126   ...
# target_e1_number_of_creative_space_workshops                 137   ...
# target_e2_number_of_sws_attending_creative_spac...           137   ...
# target_e3_number_of_small_group_workshops                     99   ...
# target_e4_number_of_sws_attending_small_group_w...            99   ...
# target_f1_number_of_male_condoms_distributed                 137   ...
# target_f2_number_of_female_condoms_distributed               137   ...
# target_f3_number_of_lube_distributed                         137   ...
# variance                                                       0   ...
#
#                                                     subrecipient  suburb  \
# field
# amount_allocated_to_global_fund                             3647       0
# amount_excluding_vat                                        3650       0
# amount_including_vat                                        3653       0
# amount_paid                                                 3638       0
# b2_sw_tested_hiv_negative                                    747     747
# b4_a_referred_for_art1_referred                              507     507
# b6_sws_who_refused_hiv_test                                  273     273
# b_1_received_hts_and_know_results                           1263    1263
# b_3_newly_diagnosed_hiv_positive_sw                          396     396
# b_4b_initiated_on_art1_initiated                              36      36
# b_5_known_hiv_positive_status                               4119    4119
# b_7_hiv_negative_sws_receiving_prep                           82      82
# b_8_b_succesful_referal_to_treatment_adherence_...            27      27
# b_8a_referred_to_treatment_adherence_clubs                  2727    2727
# behavioural_safety_intervention_e_g_substance_a...         13363   13363
# budget                                                     16253       0
# c1_sws_screened_for_sexually_transmitted_infect...          8000    8000
# c2_sti_referral_1_referred                                   359     359
# c2b_successful_sti_referal                                    54      54
# counter_1_first_outreach_for_quarter                      113968  113968
# d1_number_of_sws_screened_for_tb                            7633    7633
# d2a_tb_referal_to_health_facility1_referred                  369     369
# d2b_succesful_tb_referal                                      24      24
# did_client_face_any_human_rights_violation                   643     643
# difference                                                  3657       0
# e4_support_group_workshops                                   105     105
# f3_lube                                                     6505    6505
# f_1_male_condoms_number_given                              54162   54162
# female_condom                                              10533   10533
# goody_bags                                                  2496    2496
# hct_screening                                              14858   14858
# health_and_sexual_reproductive_health_services             24349   24349
# hiv_negative_sws_referred_for_prep                           338     338
# iec                                                         9796    9796
# number_of_services_received_in_quarter                    114463  114463
# other_condoms_e_g_doh                                      25565   25565
# paralegal_human_rights_education_health_other_s...         14681   14681
# referral_to_human_rights_organisations1_referred             263     263
# risk_reduction_workshop                                     4512    4512
# spend                                                      16253       0
# target_a1_number_of_sex_workers_reached_with_hi...           139       0
# target_a2_number_of_sex_workers_who_received_on...           139       0
# target_b1_number_of_sex_workers_that_have_recei...           128       0
# target_e1_number_of_creative_space_workshops                 139       0
# target_e2_number_of_sws_attending_creative_spac...           139       0
# target_e3_number_of_small_group_workshops                     99       0
# target_e4_number_of_sws_attending_small_group_w...            99       0
# target_f1_number_of_male_condoms_distributed                 139       0
# target_f2_number_of_female_condoms_distributed               139       0
# target_f3_number_of_lube_distributed                         139       0
# variance                                                   16253       0
#
#                                                     supplier_employee_name  \
# field
# amount_allocated_to_global_fund                                       3646
# amount_excluding_vat                                                  3649
# amount_including_vat                                                  3652
# amount_paid                                                           3637
# b2_sw_tested_hiv_negative                                                0
# b4_a_referred_for_art1_referred                                          0
# b6_sws_who_refused_hiv_test                                              0
# b_1_received_hts_and_know_results                                        0
# b_3_newly_diagnosed_hiv_positive_sw                                      0
# b_4b_initiated_on_art1_initiated                                         0
# b_5_known_hiv_positive_status                                            0
# b_7_hiv_negative_sws_receiving_prep                                      0
# b_8_b_succesful_referal_to_treatment_adherence_...                       0
# b_8a_referred_to_treatment_adherence_clubs                               0
# behavioural_safety_intervention_e_g_substance_a...                       0
# budget                                                                   0
# c1_sws_screened_for_sexually_transmitted_infect...                       0
# c2_sti_referral_1_referred                                               0
# c2b_successful_sti_referal                                               0
# counter_1_first_outreach_for_quarter                                     0
# d1_number_of_sws_screened_for_tb                                         0
# d2a_tb_referal_to_health_facility1_referred                              0
# d2b_succesful_tb_referal                                                 0
# did_client_face_any_human_rights_violation                               0
# difference                                                            3656
# e4_support_group_workshops                                               0
# f3_lube                                                                  0
# f_1_male_condoms_number_given                                            0
# female_condom                                                            0
# goody_bags                                                               0
# hct_screening                                                            0
# health_and_sexual_reproductive_health_services                           0
# hiv_negative_sws_referred_for_prep                                       0
# iec                                                                      0
# number_of_services_received_in_quarter                                   0
# other_condoms_e_g_doh                                                    0
# paralegal_human_rights_education_health_other_s...                       0
# referral_to_human_rights_organisations1_referred                         0
# risk_reduction_workshop                                                  0
# spend                                                                    0
# target_a1_number_of_sex_workers_reached_with_hi...                       0
# target_a2_number_of_sex_workers_who_received_on...                       0
# target_b1_number_of_sex_workers_that_have_recei...                       0
# target_e1_number_of_creative_space_workshops                             0
# target_e2_number_of_sws_attending_creative_spac...                       0
# target_e3_number_of_small_group_workshops                                0
# target_e4_number_of_sws_attending_small_group_w...                       0
# target_f1_number_of_male_condoms_distributed                             0
# target_f2_number_of_female_condoms_distributed                           0
# target_f3_number_of_lube_distributed                                     0
# variance                                                                 0
#
#                                                     transaction_reference  \
# field
# amount_allocated_to_global_fund                                      3647
# amount_excluding_vat                                                 3650
# amount_including_vat                                                 3653
# amount_paid                                                          3638
# b2_sw_tested_hiv_negative                                               0
# b4_a_referred_for_art1_referred                                         0
# b6_sws_who_refused_hiv_test                                             0
# b_1_received_hts_and_know_results                                       0
# b_3_newly_diagnosed_hiv_positive_sw                                     0
# b_4b_initiated_on_art1_initiated                                        0
# b_5_known_hiv_positive_status                                           0
# b_7_hiv_negative_sws_receiving_prep                                     0
# b_8_b_succesful_referal_to_treatment_adherence_...                      0
# b_8a_referred_to_treatment_adherence_clubs                              0
# behavioural_safety_intervention_e_g_substance_a...                      0
# budget                                                                  0
# c1_sws_screened_for_sexually_transmitted_infect...                      0
# c2_sti_referral_1_referred                                              0
# c2b_successful_sti_referal                                              0
# counter_1_first_outreach_for_quarter                                    0
# d1_number_of_sws_screened_for_tb                                        0
# d2a_tb_referal_to_health_facility1_referred                             0
# d2b_succesful_tb_referal                                                0
# did_client_face_any_human_rights_violation                              0
# difference                                                           3657
# e4_support_group_workshops                                              0
# f3_lube                                                                 0
# f_1_male_condoms_number_given                                           0
# female_condom                                                           0
# goody_bags                                                              0
# hct_screening                                                           0
# health_and_sexual_reproductive_health_services                          0
# hiv_negative_sws_referred_for_prep                                      0
# iec                                                                     0
# number_of_services_received_in_quarter                                  0
# other_condoms_e_g_doh                                                   0
# paralegal_human_rights_education_health_other_s...                      0
# referral_to_human_rights_organisations1_referred                        0
# risk_reduction_workshop                                                 0
# spend                                                                   0
# target_a1_number_of_sex_workers_reached_with_hi...                      0
# target_a2_number_of_sex_workers_who_received_on...                      0
# target_b1_number_of_sex_workers_that_have_recei...                      0
# target_e1_number_of_creative_space_workshops                            0
# target_e2_number_of_sws_attending_creative_spac...                      0
# target_e3_number_of_small_group_workshops                               0
# target_e4_number_of_sws_attending_small_group_w...                      0
# target_f1_number_of_male_condoms_distributed                            0
# target_f2_number_of_female_condoms_distributed                          0
# target_f3_number_of_lube_distributed                                    0
# variance                                                                0
#
#                                                        val    Date     day  \
# field
# amount_allocated_to_global_fund                       3647    3647    3647
# amount_excluding_vat                                  3650    3650    3650
# amount_including_vat                                  3653    3653    3653
# amount_paid                                           3638    3638    3638
# b2_sw_tested_hiv_negative                              747     747     747
# b4_a_referred_for_art1_referred                        507     507     507
# b6_sws_who_refused_hiv_test                            273     273     273
# b_1_received_hts_and_know_results                     1263    1263    1263
# b_3_newly_diagnosed_hiv_positive_sw                    396     396     396
# b_4b_initiated_on_art1_initiated                        36      36      36
# b_5_known_hiv_positive_status                         4119    4119    4119
# b_7_hiv_negative_sws_receiving_prep                     82      82      82
# b_8_b_succesful_referal_to_treatment_adherence_...      27      27      27
# b_8a_referred_to_treatment_adherence_clubs            2727    2727    2727
# behavioural_safety_intervention_e_g_substance_a...   13363   13363   13363
# budget                                               16253   16253   16253
# c1_sws_screened_for_sexually_transmitted_infect...    8000    8000    8000
# c2_sti_referral_1_referred                             359     359     359
# c2b_successful_sti_referal                              54      54      54
# counter_1_first_outreach_for_quarter                113968  113968  113968
# d1_number_of_sws_screened_for_tb                      7633    7633    7633
# d2a_tb_referal_to_health_facility1_referred            369     369     369
# d2b_succesful_tb_referal                                24      24      24
# did_client_face_any_human_rights_violation             643     643     643
# difference                                            3657    3657    3657
# e4_support_group_workshops                             105     105     105
# f3_lube                                               6505    6505    6505
# f_1_male_condoms_number_given                        54162   54162   54162
# female_condom                                        10533   10533   10533
# goody_bags                                            2496    2496    2496
# hct_screening                                        14858   14858   14858
# health_and_sexual_reproductive_health_services       24349   24349   24349
# hiv_negative_sws_referred_for_prep                     338     338     338
# iec                                                   9796    9796    9796
# number_of_services_received_in_quarter              114463  114463  114463
# other_condoms_e_g_doh                                25565   25565   25565
# paralegal_human_rights_education_health_other_s...   14681   14681   14681
# referral_to_human_rights_organisations1_referred       263     263     263
# risk_reduction_workshop                               4512    4512    4512
# spend                                                16253   16253   16253
# target_a1_number_of_sex_workers_reached_with_hi...     139     139     139
# target_a2_number_of_sex_workers_who_received_on...     139     139     139
# target_b1_number_of_sex_workers_that_have_recei...     128     128     128
# target_e1_number_of_creative_space_workshops           139     139     139
# target_e2_number_of_sws_attending_creative_spac...     139     139     139
# target_e3_number_of_small_group_workshops               99      99      99
# target_e4_number_of_sws_attending_small_group_w...      99      99      99
# target_f1_number_of_male_condoms_distributed           139     139     139
# target_f2_number_of_female_condoms_distributed         139     139     139
# target_f3_number_of_lube_distributed                   139     139     139
# variance                                             16253   16253   16253
#
#                                                      month    year  Quarter
# field
# amount_allocated_to_global_fund                       3647    3647     3647
# amount_excluding_vat                                  3650    3650     3650
# amount_including_vat                                  3653    3653     3653
# amount_paid                                           3638    3638     3638
# b2_sw_tested_hiv_negative                              747     747      747
# b4_a_referred_for_art1_referred                        507     507      507
# b6_sws_who_refused_hiv_test                            273     273      273
# b_1_received_hts_and_know_results                     1263    1263     1263
# b_3_newly_diagnosed_hiv_positive_sw                    396     396      396
# b_4b_initiated_on_art1_initiated                        36      36       36
# b_5_known_hiv_positive_status                         4119    4119     4119
# b_7_hiv_negative_sws_receiving_prep                     82      82       82
# b_8_b_succesful_referal_to_treatment_adherence_...      27      27       27
# b_8a_referred_to_treatment_adherence_clubs            2727    2727     2727
# behavioural_safety_intervention_e_g_substance_a...   13363   13363    13363
# budget                                               16253   16253    16253
# c1_sws_screened_for_sexually_transmitted_infect...    8000    8000     8000
# c2_sti_referral_1_referred                             359     359      359
# c2b_successful_sti_referal                              54      54       54
# counter_1_first_outreach_for_quarter                113968  113968   113968
# d1_number_of_sws_screened_for_tb                      7633    7633     7633
# d2a_tb_referal_to_health_facility1_referred            369     369      369
# d2b_succesful_tb_referal                                24      24       24
# did_client_face_any_human_rights_violation             643     643      643
# difference                                            3657    3657     3657
# e4_support_group_workshops                             105     105      105
# f3_lube                                               6505    6505     6505
# f_1_male_condoms_number_given                        54162   54162    54162
# female_condom                                        10533   10533    10533
# goody_bags                                            2496    2496     2496
# hct_screening                                        14858   14858    14858
# health_and_sexual_reproductive_health_services       24349   24349    24349
# hiv_negative_sws_referred_for_prep                     338     338      338
# iec                                                   9796    9796     9796
# number_of_services_received_in_quarter              114463  114463   114463
# other_condoms_e_g_doh                                25565   25565    25565
# paralegal_human_rights_education_health_other_s...   14681   14681    14681
# referral_to_human_rights_organisations1_referred       263     263      263
# risk_reduction_workshop                               4512    4512     4512
# spend                                                16253   16253    16253
# target_a1_number_of_sex_workers_reached_with_hi...     139     139      139
# target_a2_number_of_sex_workers_who_received_on...     139     139      139
# target_b1_number_of_sex_workers_that_have_recei...     128     128      128
# target_e1_number_of_creative_space_workshops           139     139      139
# target_e2_number_of_sws_attending_creative_spac...     139     139      139
# target_e3_number_of_small_group_workshops               99      99       99
# target_e4_number_of_sws_attending_small_group_w...      99      99       99
# target_f1_number_of_male_condoms_distributed           139     139      139
# target_f2_number_of_female_condoms_distributed         139     139      139
# target_f3_number_of_lube_distributed                   139     139      139
# variance                                             16253   16253    16253
#
# [51 rows x 24 columns]

# %% [markdown]
# <h3> Clean names nqobile women -> nqobile </h3>

# %%
DF['subrecipient']=DF['subrecipient'].replace('nqobile women','nqobile')

#standardize names
DF['field']=DF['field'].replace('red_umbrella_male_condom_lube','f_1_male_condoms_number_given')

# %%
DF_cut=(DF['year']>=2016) & (DF['year']<2017)

# %%
DF

# %% [markdown]
# <h1> M&E which have 4 or more SRs reporting</h1>

# %%
#number of SRs that are reporting for each field
SRs_in_field=DF.loc[DF_cut].groupby(['field','subrecipient']).count().groupby(level=0).count()
SRs_in_field.loc[(SRs_in_field['Date']>=4) & ~( SRs_in_field.index.str.contains('target'))\
                & ~( SRs_in_field.index.str.contains('amount')) ]
# Out:
#                                                     Real_Date  beneficiary  \
# field
# b2_sw_tested_hiv_negative                                   4            4
# b4_a_referred_for_art1_referred                             4            4
# b_1_received_hts_and_know_results                           5            5
# b_5_known_hiv_positive_status                               4            4
# budget                                                     15           15
# c1_sws_screened_for_sexually_transmitted_infect...          4            4
# c2_sti_referral_1_referred                                  4            4
# counter_1_first_outreach_for_quarter                        7            7
# d1_number_of_sws_screened_for_tb                            4            4
# difference                                                  7            7
# f_1_male_condoms_number_given                               6            6
# hct_screening                                              11           11
# number_of_services_received_in_quarter                      7            7
# other_condoms_e_g_doh                                       4            4
# risk_reduction_workshop                                     6            6
# spend                                                      15           15
# variance                                                   15           15
#
#                                                     budget_line  \
# field
# b2_sw_tested_hiv_negative                                     4
# b4_a_referred_for_art1_referred                               4
# b_1_received_hts_and_know_results                             5
# b_5_known_hiv_positive_status                                 4
# budget                                                       15
# c1_sws_screened_for_sexually_transmitted_infect...            4
# c2_sti_referral_1_referred                                    4
# counter_1_first_outreach_for_quarter                          7
# d1_number_of_sws_screened_for_tb                              4
# difference                                                    7
# f_1_male_condoms_number_given                                 6
# hct_screening                                                11
# number_of_services_received_in_quarter                        7
# other_condoms_e_g_doh                                         4
# risk_reduction_workshop                                       6
# spend                                                        15
# variance                                                     15
#
#                                                     budget_line_full  \
# field
# b2_sw_tested_hiv_negative                                          4
# b4_a_referred_for_art1_referred                                    4
# b_1_received_hts_and_know_results                                  5
# b_5_known_hiv_positive_status                                      4
# budget                                                            15
# c1_sws_screened_for_sexually_transmitted_infect...                 4
# c2_sti_referral_1_referred                                         4
# counter_1_first_outreach_for_quarter                               7
# d1_number_of_sws_screened_for_tb                                   4
# difference                                                         7
# f_1_male_condoms_number_given                                      6
# hct_screening                                                     11
# number_of_services_received_in_quarter                             7
# other_condoms_e_g_doh                                              4
# risk_reduction_workshop                                            6
# spend                                                             15
# variance                                                          15
#
#                                                     cost_category  \
# field
# b2_sw_tested_hiv_negative                                       4
# b4_a_referred_for_art1_referred                                 4
# b_1_received_hts_and_know_results                               5
# b_5_known_hiv_positive_status                                   4
# budget                                                         15
# c1_sws_screened_for_sexually_transmitted_infect...              4
# c2_sti_referral_1_referred                                      4
# counter_1_first_outreach_for_quarter                            7
# d1_number_of_sws_screened_for_tb                                4
# difference                                                      7
# f_1_male_condoms_number_given                                   6
# hct_screening                                                  11
# number_of_services_received_in_quarter                          7
# other_condoms_e_g_doh                                           4
# risk_reduction_workshop                                         6
# spend                                                          15
# variance                                                       15
#
#                                                     description  \
# field
# b2_sw_tested_hiv_negative                                     4
# b4_a_referred_for_art1_referred                               4
# b_1_received_hts_and_know_results                             5
# b_5_known_hiv_positive_status                                 4
# budget                                                       15
# c1_sws_screened_for_sexually_transmitted_infect...            4
# c2_sti_referral_1_referred                                    4
# counter_1_first_outreach_for_quarter                          7
# d1_number_of_sws_screened_for_tb                              4
# difference                                                    7
# f_1_male_condoms_number_given                                 6
# hct_screening                                                11
# number_of_services_received_in_quarter                        7
# other_condoms_e_g_doh                                         4
# risk_reduction_workshop                                       6
# spend                                                        15
# variance                                                     15
#
#                                                     invoice_receipt_number  \
# field
# b2_sw_tested_hiv_negative                                                4
# b4_a_referred_for_art1_referred                                          4
# b_1_received_hts_and_know_results                                        5
# b_5_known_hiv_positive_status                                            4
# budget                                                                  15
# c1_sws_screened_for_sexually_transmitted_infect...                       4
# c2_sti_referral_1_referred                                               4
# counter_1_first_outreach_for_quarter                                     7
# d1_number_of_sws_screened_for_tb                                         4
# difference                                                               7
# f_1_male_condoms_number_given                                            6
# hct_screening                                                           11
# number_of_services_received_in_quarter                                   7
# other_condoms_e_g_doh                                                    4
# risk_reduction_workshop                                                  6
# spend                                                                   15
# variance                                                                15
#
#                                                     peer_motivator  province  \
# field
# b2_sw_tested_hiv_negative                                        4         4
# b4_a_referred_for_art1_referred                                  4         4
# b_1_received_hts_and_know_results                                5         5
# b_5_known_hiv_positive_status                                    4         4
# budget                                                          15        15
# c1_sws_screened_for_sexually_transmitted_infect...               4         4
# c2_sti_referral_1_referred                                       4         4
# counter_1_first_outreach_for_quarter                             7         7
# d1_number_of_sws_screened_for_tb                                 4         4
# difference                                                       7         7
# f_1_male_condoms_number_given                                    6         6
# hct_screening                                                   11        11
# number_of_services_received_in_quarter                           7         7
# other_condoms_e_g_doh                                            4         4
# risk_reduction_workshop                                          6         6
# spend                                                           15        15
# variance                                                        15        15
#
#                                                     province_lat   ...     \
# field                                                              ...
# b2_sw_tested_hiv_negative                                      4   ...
# b4_a_referred_for_art1_referred                                4   ...
# b_1_received_hts_and_know_results                              5   ...
# b_5_known_hiv_positive_status                                  4   ...
# budget                                                        15   ...
# c1_sws_screened_for_sexually_transmitted_infect...             4   ...
# c2_sti_referral_1_referred                                     4   ...
# counter_1_first_outreach_for_quarter                           7   ...
# d1_number_of_sws_screened_for_tb                               4   ...
# difference                                                     7   ...
# f_1_male_condoms_number_given                                  6   ...
# hct_screening                                                 11   ...
# number_of_services_received_in_quarter                         7   ...
# other_condoms_e_g_doh                                          4   ...
# risk_reduction_workshop                                        6   ...
# spend                                                         15   ...
# variance                                                      15   ...
#
#                                                     site_lng  suburb  \
# field
# b2_sw_tested_hiv_negative                                  4       4
# b4_a_referred_for_art1_referred                            4       4
# b_1_received_hts_and_know_results                          5       5
# b_5_known_hiv_positive_status                              4       4
# budget                                                    15      15
# c1_sws_screened_for_sexually_transmitted_infect...         4       4
# c2_sti_referral_1_referred                                 4       4
# counter_1_first_outreach_for_quarter                       7       7
# d1_number_of_sws_screened_for_tb                           4       4
# difference                                                 7       7
# f_1_male_condoms_number_given                              6       6
# hct_screening                                             11      11
# number_of_services_received_in_quarter                     7       7
# other_condoms_e_g_doh                                      4       4
# risk_reduction_workshop                                    6       6
# spend                                                     15      15
# variance                                                  15      15
#
#                                                     supplier_employee_name  \
# field
# b2_sw_tested_hiv_negative                                                4
# b4_a_referred_for_art1_referred                                          4
# b_1_received_hts_and_know_results                                        5
# b_5_known_hiv_positive_status                                            4
# budget                                                                  15
# c1_sws_screened_for_sexually_transmitted_infect...                       4
# c2_sti_referral_1_referred                                               4
# counter_1_first_outreach_for_quarter                                     7
# d1_number_of_sws_screened_for_tb                                         4
# difference                                                               7
# f_1_male_condoms_number_given                                            6
# hct_screening                                                           11
# number_of_services_received_in_quarter                                   7
# other_condoms_e_g_doh                                                    4
# risk_reduction_workshop                                                  6
# spend                                                                   15
# variance                                                                15
#
#                                                     transaction_reference  \
# field
# b2_sw_tested_hiv_negative                                               4
# b4_a_referred_for_art1_referred                                         4
# b_1_received_hts_and_know_results                                       5
# b_5_known_hiv_positive_status                                           4
# budget                                                                 15
# c1_sws_screened_for_sexually_transmitted_infect...                      4
# c2_sti_referral_1_referred                                              4
# counter_1_first_outreach_for_quarter                                    7
# d1_number_of_sws_screened_for_tb                                        4
# difference                                                              7
# f_1_male_condoms_number_given                                           6
# hct_screening                                                          11
# number_of_services_received_in_quarter                                  7
# other_condoms_e_g_doh                                                   4
# risk_reduction_workshop                                                 6
# spend                                                                  15
# variance                                                               15
#
#                                                     val  Date  day  month  \
# field
# b2_sw_tested_hiv_negative                             4     4    4      4
# b4_a_referred_for_art1_referred                       4     4    4      4
# b_1_received_hts_and_know_results                     5     5    5      5
# b_5_known_hiv_positive_status                         4     4    4      4
# budget                                               15    15   15     15
# c1_sws_screened_for_sexually_transmitted_infect...    4     4    4      4
# c2_sti_referral_1_referred                            4     4    4      4
# counter_1_first_outreach_for_quarter                  7     7    7      7
# d1_number_of_sws_screened_for_tb                      4     4    4      4
# difference                                            7     7    7      7
# f_1_male_condoms_number_given                         6     6    6      6
# hct_screening                                        11    11   11     11
# number_of_services_received_in_quarter                7     7    7      7
# other_condoms_e_g_doh                                 4     4    4      4
# risk_reduction_workshop                               6     6    6      6
# spend                                                15    15   15     15
# variance                                             15    15   15     15
#
#                                                     year  Quarter
# field
# b2_sw_tested_hiv_negative                              4        4
# b4_a_referred_for_art1_referred                        4        4
# b_1_received_hts_and_know_results                      5        5
# b_5_known_hiv_positive_status                          4        4
# budget                                                15       15
# c1_sws_screened_for_sexually_transmitted_infect...     4        4
# c2_sti_referral_1_referred                             4        4
# counter_1_first_outreach_for_quarter                   7        7
# d1_number_of_sws_screened_for_tb                       4        4
# difference                                             7        7
# f_1_male_condoms_number_given                          6        6
# hct_screening                                         11       11
# number_of_services_received_in_quarter                 7        7
# other_condoms_e_g_doh                                  4        4
# risk_reduction_workshop                                6        6
# spend                                                 15       15
# variance                                              15       15
#
# [17 rows x 23 columns]

# %% [markdown]
# <h1> Explore monthly breakdown of good M&E </h1>

# %%
DF.loc[(DF['field'].str.contains("b_1_received_hts_and_know_results")) & (DF['year']==2016)\
      & (DF['Quarter']>0) & (DF['Quarter']<=2)].groupby(['Quarter','subrecipient']).sum()
# Out:
#                       province_lat  province_lng      site_lat      site_lng  \
# Quarter subrecipient
# 1       cpc          -10971.201801  11307.292259 -10865.103913  11599.879025
#         oasis          -785.514870    841.468590   -778.119870    840.257640
# 2       cpc          -13308.400644  13753.009525 -13187.971744  14151.790259
#         nqobile       -2435.096097   2608.552908  -2481.546900   2623.148700
#         oasis         -4451.250930   4768.322120  -4429.336561   4755.971291
#         qac            -542.760992    512.734855   -534.413000    537.688600
#         sweat          -949.137392    557.804856   -949.897200    515.874800
#
#                         val  day  month     year
# Quarter subrecipient
# 1       cpc           417.0  417   2094   840672
#         oasis          30.0   30    180    60480
# 2       cpc           506.0  506   4031  1020096
#         nqobile        93.0   93    824   187488
#         oasis         170.0  170   1322   342720
#         qac            19.0   19    171    38304
#         sweat          28.0   28    206    56448

# %% [markdown]
# <h1> grouped by subrecipient and quarter </h1>

# %%
#DF.loc[(DF['subrecipient'].str.contains("cpc")) & (DF['year']==2016)\
#      & (DF['Quarter']>0) & (DF['Quarter']<=2)].groupby(['Quarter','field']).count().dropna()

# %%
#DF.loc[(DF['field'].str.contains("counter_1_first_outreach_for_quarter")) & (DF['year']==2016) \
#       & (DF['Quarter']>=1) & (DF['Quarter']<=2)].keys

# %%
DF.columns
# Out:
# Index([             u'Real_Date',            u'beneficiary',
#                   u'budget_line',       u'budget_line_full',
#                 u'cost_category',            u'description',
#                         u'field', u'invoice_receipt_number',
#                u'peer_motivator',               u'province',
#                  u'province_lat',           u'province_lng',
#                          u'site',               u'site_lat',
#                      u'site_lng',           u'subrecipient',
#                        u'suburb', u'supplier_employee_name',
#         u'transaction_reference',                    u'val',
#                          u'Date',                    u'day',
#                         u'month',                   u'year',
#                       u'Quarter'],
#       dtype='object')

# %%
#DF.loc[(DF['field'].str.contains("counter_1_first_outreach_for_quarter")) & (DF['year']==2016) \
#       & (DF['Quarter']>=1) & (DF['Quarter']<=2)].suburb

# %% [markdown]
# <h1> Count the number of unique people reached in a quarter </h1>

# %%
DF.loc[(DF['field'].str.contains("counter_1_first_outreach_for_quarter")) & (DF['year']==2016) \
       & (DF['Quarter']>=1) & (DF['Quarter']<=2)]\
.groupby(['subrecipient','Quarter']).beneficiary.nunique()

# %%
unique_people_per_q=DF.loc[(DF['field'].str.contains("counter_1_first_outreach_for_quarter")) & (DF['year']==2016) \
       & (DF['Quarter']>=1) & (DF['Quarter']<=2)]\
.groupby(['subrecipient','month']).beneficiary.nunique()

count_new_quarter=DF.loc[(DF['field'].str.contains("counter_1_first_outreach_for_quarter")) & (DF['year']==2016) \
       & (DF['Quarter']>=1) & (DF['Quarter']<=2)]\
.groupby(['Quarter','subrecipient']).beneficiary.nunique()

unique_people_per_q
# Out:
# subrecipient  month
# cpc           4         885
#               5        1279
#               6        1586
#               7        1238
#               8        2102
#               9        2483
# nqobile       7         805
#               8         946
#               9         980
# oasis         4         218
#               5         518
#               6         470
#               7        1762
#               8        1256
#               9        1291
# qac           4         136
#               5         554
#               6         523
#               7         483
#               8         413
#               9         339
# sweat         4         342
#               5         408
#               6         535
#               7         560
#               8         609
#               9         693
# Name: beneficiary, dtype: int64

# %% [markdown]
# <h1> Count number of PM (peer motivators) per quarter </h1>

# %%
unique_pm_per_q=DF.loc[(DF['field'].str.contains("counter_1_first_outreach_for_quarter")) & (DF['year']==2016) \
        & (DF['Quarter']>=1) & (DF['Quarter']<=2)]\
        .groupby(['subrecipient','month']).peer_motivator.nunique()
unique_pm_per_q
# Out:
# subrecipient  month
# cpc           4        20
#               5        23
#               6        25
#               7        35
#               8        34
#               9        36
# nqobile       7        22
#               8        22
#               9        21
# oasis         4         7
#               5         8
#               6         8
#               7        27
#               8        21
#               9        20
# qac           4         4
#               5        14
#               6        15
#               7        15
#               8        14
#               9        15
# sweat         4         4
#               5         2
#               6         4
#               7        16
#               8        20
#               9        17
# Name: peer_motivator, dtype: int64

# %%
reached_per_pm=unique_people_per_q/unique_pm_per_q
reached_per_pm['cpc']
# Out:
# month
# 4    44.250000
# 5    55.608696
# 6    63.440000
# 7    35.371429
# 8    61.823529
# 9    68.972222
# dtype: float64

# %% [markdown]
# <h1> Plot monthly trend of unique SW reached and PM(peer motivators) trained</h1>

# %%
#setup colors
def plot_data(data,ylabel_str):
    start,stop=0,1
    number_of_colors= len(data.index.levels[0])
    cm_subsection = linspace(start, stop, number_of_colors) 
    colors = [ cm.jet(x) for x in cm_subsection ]

    fig=figure()
    fig.set_size_inches(13, 9)
    sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

    for SR,color in zip(data.index.levels[0],colors):
        plt.plot(data[SR],'.-',color=color,markersize=20, label=SR,)
    ylabel(ylabel_str)
    xlabel('Month (2016)')
    legend(loc='upper right', numpoints=1,fontsize=12)
    ax = gca()
    #ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter('%b\n%Y'))
    #ax.xaxis.set_major_formatter(matplotlib.dates.DateFormatter('%b'))
    #yscale('log')

# %%
plot_data(reached_per_pm,'Unique People Reached per PM')

# %%
plot_data(unique_pm_per_q,'unique_pm_per_month')

# %%
plot_data(unique_people_per_q,'count_new_quarter')

# %% [markdown]
# <h1> Make same plots with plotly </h1>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# %%
unique_people_per_q[SR].index
# Out:
# Int64Index([4, 5, 6, 7, 8, 9], dtype='int64', name=u'month')

# %%
def create_trace(data,width=4,size=10,mode='lines+markers'):
    return [go.Scatter(x=data[key_name].index, y=data[key_name].values,mode=mode,name=key_name,\
                      line = dict(width=width), marker=dict(size=size))\
    for key_name in data.index.levels[0]]

# %%
traces=create_trace(unique_people_per_q)
# Edit the layout #color='#7f7f7f'
layout = dict(title = 'SW Reached',
              font=dict(family='Courier New, monospace', size=18),
              xaxis = dict(title = 'Month 2016'),
              yaxis = dict(title = 'New people per month'),
              )
fig = dict(data=traces, layout=layout)
py.iplot(fig, filename='line-mode')
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~attdobi/0 or inside your plot.ly account where it is named 'line-mode'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~attdobi/0.embed" height="525px" width="100%"></iframe>

# %%
traces=create_trace(unique_pm_per_q)
# Edit the layout #color='#7f7f7f'
layout = dict(title = 'PMs Trained',
              font=dict(family='Courier New, monospace', size=18),
              xaxis = dict(title = 'Month 2016'),
              yaxis = dict(title = 'Number of peer motivators'),
              )
fig = dict(data=traces, layout=layout)
py.iplot(fig, filename='line-mode')
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~attdobi/0 or inside your plot.ly account where it is named 'line-mode'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~attdobi/0.embed" height="525px" width="100%"></iframe>

# %%
traces=create_trace(reached_per_pm)
# Edit the layout #color='#7f7f7f'
layout = dict(title = 'PM performance',
              font=dict(family='Courier New, monospace', size=18),
              xaxis = dict(title = 'Month 2016'),
              yaxis = dict(title = 'Number of people reached/PM'),
              )
fig = dict(data=traces, layout=layout)
py.iplot(fig, filename='line-mode')
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~attdobi/0 or inside your plot.ly account where it is named 'line-mode'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~attdobi/0.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# <h1> Get quarterly spending data </h1>

# %%
plot_spend=DF.loc[(DF['field']=='spend') & (DF['year']<=2016) & (DF['Quarter']<=2)].groupby(['Quarter','subrecipient']).sum()['val']
#plot_spend

# %%
plot_spend
# Out:
# Quarter  subrecipient
# 1        cpc               2.759530e+06
#          htt               9.026696e+05
#          lifeline nc       5.417175e+05
#          ll durban         8.422708e+05
#          ll fs             6.321698e+05
#          ll zululand       6.386447e+05
#          munna ndi nnyi    8.012208e+05
#          nqobile           1.443221e+06
#          oasis             1.778952e+06
#          phru              1.297509e+06
#          psh               7.465358e+05
#          qac               1.400363e+06
#          sweat             4.444029e+06
#          thca              2.387249e+04
#          wrhi              1.736811e+06
# 2        cpc               1.618566e+06
#          htt               3.580400e+05
#          lifeline nc       2.402625e+05
#          ll durban         2.850366e+05
#          ll fs             4.950573e+05
#          ll zululand       2.029758e+05
#          munna ndi nnyi    1.188548e+05
#          nqobile           6.233507e+05
#          oasis             6.631024e+05
#          phru              1.143940e+06
#          psh               2.018028e+05
#          qac               9.266312e+05
#          sweat             2.929222e+06
#          thca              0.000000e+00
#          wrhi              2.478493e+06
# Name: val, dtype: float64

# %%
def plot_q(t):
    q=t
    #setup colors
    start,stop=0,1
    number_of_colors= len(count_new_quarter.index.levels[1])
    cm_subsection = linspace(start, stop, number_of_colors) 
    colors = [ cm.jet(x) for x in cm_subsection ]

    fig=figure()
    fig.set_size_inches(10, 7)
    sns.set_context("notebook", font_scale=2.0, rc={"lines.linewidth": 2.5})
    for SR,color in zip(count_new_quarter.index.levels[1],colors):
        try: 
            scatter(plot_spend[(q,SR)]/1e6,count_new_quarter[(q,SR)],color=color,label=SR,s=200)
        except KeyError:
            print('fail')

    #legend=plt.legend(frameon=True )
    #frame = legend.get_frame()
    #frame.set_facecolor('white')

    plt.ylabel('New People Reached per Quarter')
    plt.xlabel('Money Spent ($ Million)')

# %%
interact(plot_q, t=(1,2,1) )
# Out:
# fail
# <function __main__.plot_q>

# %% [markdown]
# <h1> Bar Chart for people reached normalized to money spent </h1>

# %%
#After cutting the data is indexed as 1 and 2 on level 1
dat=count_new_quarter/plot_spend
#dat

# %%
#Loop through data and build arrays for q1, q2

names=[]
q1=[]
q2=[]
for SR in count_new_quarter.index.levels[1]:
    names.append(SR)
    q1.append(dat[(1,SR)])
    q2.append(dat[(2,SR)])
q1=np.array(q1)    
q2=np.array(q2)

# %%
#new
'''
q1=np.array(dat[1].values)
q2=np.array(dat[2].values)
names=dat[2].index
'''
#this will lead to an error since the first quarter has one less SR reporting
# Out:
# '\nq1=np.array(dat[1].values)\nq2=np.array(dat[2].values)\nnames=dat[2].index\n'

# %%
N = 5

ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, q1*1000, width, color='r', label='Q1')

rects2 = ax.bar(ind + width, q2*1000, width, color='y',label='Q2')

# add some text for labels, title and axes ticks
ax.set_ylabel('People Reached per $1000')
#ax.set_title('Scores by group and gender')
ax.set_xticks(ind + width)
ax.set_xticklabels(names)
plt.legend()

# %%
# Open File to write the D3 Graph
output_file = open('SA.html', 'w')

kwargs1 = {"fontSize": '100'}

chart = multiBarChart(width=800, height=400, x_axis_format=None, **kwargs1)
chart.create_y_axis('yAxis','People Reached per $1000')

xdata = names
#xdata = ['one' , 'two', 'three', 'four']
ydata1 = q1*1000
ydata2 = q2*1000

chart.add_serie(name="Quarter 1", y=ydata1, x=xdata ,**kwargs1)
chart.add_serie(name="Quarter 2", y=ydata2, x=xdata, **kwargs1)
chart.buildhtml()

output_file.write(chart.htmlcontent)

# close Html file
output_file.close()

# %% [markdown]
# <h1> People Reached per $1000 </h1>

# %%
chart
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8" />
#         <link href="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.css" rel="stylesheet" />
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script>
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.js"></script>
#     </head>
#     <body>
#
#     <div id="multibarchart"><svg style="width:800px;height:400px;"></svg></div>
#
#
#     <script>
#
#
#
#         data_multibarchart=[{"values": [{"y": 1.3324731482924699, "x": "cpc"}, {"y": NaN, "x": "nqobile"}, {"y": 0.66218765485241438, "x": "oasis"}, {"y": 0.65840050779960402, "x": "qac"}, {"y": 0.22794631424608316, "x": "sweat"}], "key": "Quarter 1", "yAxis": "1"}, {"values": [{"y": 3.5092800687225769, "x": "cpc"}, {"y": 4.251218591756408, "x": "nqobile"}, {"y": 6.1966293804714319, "x": "oasis"}, {"y": 0.88276757087066893, "x": "qac"}, {"y": 0.60698710998101024, "x": "sweat"}], "key": "Quarter 2", "yAxis": "1"}];
#
#     nv.addGraph(function() {
#         var chart = nv.models.multiBarChart();
#
#         chart.margin({top: 30, right: 60, bottom: 20, left: 60});
#
#         var datum = data_multibarchart;
#
#
#
#
#
#             chart.yAxis
#                 .axisLabel('People Reached per $1000');
#
#
#       chart.showLegend(true);
#
#
#
#
#
#
#         d3.select('#multibarchart svg')
#             .datum(datum)
#             .transition().duration(500)
#             .attr('width', 800)
#             .attr('height', 400)
#             .call(chart);
#
#
#     });
#
#
#
#
#     </script>
#
#     </body>
# </html>

# %% [markdown]
# <h1> number_of_services_received_in_quarter per $1000 </h1>

# %%
services=DF.loc[(DF['field'].str.contains("number_of_services_received_in_quarter")) & (DF['year']==2016) \
                & (DF['Quarter']>0) & (DF['Quarter']<=2)]\
.groupby(['Quarter','subrecipient']).sum().val

#services


services_per_spend=services/plot_spend

names=[]
q1=[]
q2=[]
for SR in services.index.levels[1]:
    names.append(SR)
    q1.append(services_per_spend[(1,SR)])
    q2.append(services_per_spend[(2,SR)])
q1=np.array(q1)    
q2=np.array(q2) 


# Open File to write the D3 Graph
output_file = open('SA_services.html', 'w')

kwargs1 = {"fontSize": '100'}

chart = multiBarChart(name='aa', width=800, height=400, x_axis_format=None, **kwargs1)
chart.create_y_axis('yAxis','number of services per $1000')

xdata = names
#xdata = ['one' , 'two', 'three', 'four']
ydata1 = q1*1000
ydata2 = q2*1000

chart.add_serie(name="Quarter 1", y=ydata1, x=xdata ,**kwargs1)
chart.add_serie(name="Quarter 2", y=ydata2, x=xdata, **kwargs1)

chart.buildhtml()

output_file.write(chart.htmlcontent)

# close Html file
output_file.close()

display(chart)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8" />
#         <link href="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.css" rel="stylesheet" />
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script>
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.js"></script>
#     </head>
#     <body>
#
#     <div id="aa"><svg style="width:800px;height:400px;"></svg></div>
#
#
#     <script>
#
#
#
#         data_aa=[{"values": [{"y": 2.5605807086849586, "x": "cpc"}, {"y": NaN, "x": "nqobile"}, {"y": 0.72851884608550843, "x": "oasis"}, {"y": 2.683589054567149, "x": "qac"}, {"y": 0.4255147879954031, "x": "sweat"}], "key": "Quarter 1", "yAxis": "1"}, {"values": [{"y": 4.2049577724869467, "x": "cpc"}, {"y": 4.7469267218895137, "x": "nqobile"}, {"y": 8.0741673650630439, "x": "oasis"}, {"y": 10.042830091103234, "x": "qac"}, {"y": 0.74149381489243771, "x": "sweat"}], "key": "Quarter 2", "yAxis": "1"}];
#
#     nv.addGraph(function() {
#         var chart = nv.models.multiBarChart();
#
#         chart.margin({top: 30, right: 60, bottom: 20, left: 60});
#
#         var datum = data_aa;
#
#
#
#
#
#             chart.yAxis
#                 .axisLabel('number of services per $1000');
#
#
#       chart.showLegend(true);
#
#
#
#
#
#
#         d3.select('#aa svg')
#             .datum(datum)
#             .transition().duration(500)
#             .attr('width', 800)
#             .attr('height', 400)
#             .call(chart);
#
#
#     });
#
#
#
#
#     </script>
#
#     </body>
# </html>

# %%
def plot_ME(ME_name):
    services=DF.loc[(DF['field'].str.contains(ME_name)) & (DF['year']==2016) \
                & (DF['Quarter']>0) & (DF['Quarter']<=2)]\
    .groupby(['Quarter','subrecipient']).sum().val

    #services


    services_per_spend=services/plot_spend

    names=[]
    q1=[]
    q2=[]
    for SR in services.index.levels[1]:
        names.append(SR)
        q1.append(services_per_spend[(1,SR)])
        q2.append(services_per_spend[(2,SR)])
    q1=np.array(q1)    
    q2=np.array(q2) 


    # Open File to write the D3 Graph
    output_file = open('SA_services.html', 'w')

    kwargs1 = {"fontSize": '100'}

    chart = multiBarChart(name=ME_name, width=800, height=400, x_axis_format=None, **kwargs1)
    chart.create_y_axis('yAxis',ME_name+' per $1000')

    xdata = names
    #xdata = ['one' , 'two', 'three', 'four']
    ydata1 = q1*1000
    ydata2 = q2*1000

    chart.add_serie(name="Quarter 1", y=ydata1, x=xdata ,**kwargs1)
    chart.add_serie(name="Quarter 2", y=ydata2, x=xdata, **kwargs1)

    chart.buildhtml()

    output_file.write(chart.htmlcontent)

    # close Html file
    output_file.close()

    display(chart)

# %% [markdown]
# <h1> b2_sw_tested_hiv_negative </h1>

# %%
plot_ME('b2_sw_tested_hiv_negative')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8" />
#         <link href="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.css" rel="stylesheet" />
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script>
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.js"></script>
#     </head>
#     <body>
#
#     <div id="b2_sw_tested_hiv_negative"><svg style="width:800px;height:400px;"></svg></div>
#
#
#     <script>
#
#
#
#         data_b2_sw_tested_hiv_negative=[{"values": [{"y": 0.090595128385400445, "x": "cpc"}, {"y": NaN, "x": "nqobile"}, {"y": NaN, "x": "oasis"}, {"y": NaN, "x": "qac"}], "key": "Quarter 1", "yAxis": "1"}, {"values": [{"y": 0.19461676437457953, "x": "cpc"}, {"y": 0.14758947563833569, "x": "nqobile"}, {"y": 0.12064501105809554, "x": "oasis"}, {"y": 0.010791779594995953, "x": "qac"}], "key": "Quarter 2", "yAxis": "1"}];
#
#     nv.addGraph(function() {
#         var chart = nv.models.multiBarChart();
#
#         chart.margin({top: 30, right: 60, bottom: 20, left: 60});
#
#         var datum = data_b2_sw_tested_hiv_negative;
#
#
#
#
#
#             chart.yAxis
#                 .axisLabel('b2_sw_tested_hiv_negative per $1000');
#
#
#       chart.showLegend(true);
#
#
#
#
#
#
#         d3.select('#b2_sw_tested_hiv_negative svg')
#             .datum(datum)
#             .transition().duration(500)
#             .attr('width', 800)
#             .attr('height', 400)
#             .call(chart);
#
#
#     });
#
#
#
#
#     </script>
#
#     </body>
# </html>

# %% [markdown]
# <h1> Risk reduction workshop </h1>

# %%
plot_ME('risk_reduction_workshop')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8" />
#         <link href="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.css" rel="stylesheet" />
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script>
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.js"></script>
#     </head>
#     <body>
#
#     <div id="risk_reduction_workshop"><svg style="width:800px;height:400px;"></svg></div>
#
#
#     <script>
#
#
#
#         data_risk_reduction_workshop=[{"values": [{"y": 0.11270033971143817, "x": "cpc"}, {"y": NaN, "x": "nqobile"}, {"y": 0.014053218481587739, "x": "oasis"}, {"y": 0.042131919696503935, "x": "qac"}, {"y": 0.011251052035838262, "x": "sweat"}], "key": "Quarter 1", "yAxis": "1"}, {"values": [{"y": 0.1958524263706086, "x": "cpc"}, {"y": 0.29517895127667138, "x": "nqobile"}, {"y": 0.26541902432781017, "x": "oasis"}, {"y": 0.14892655841094415, "x": "qac"}, {"y": 0.043697609717418061, "x": "sweat"}], "key": "Quarter 2", "yAxis": "1"}];
#
#     nv.addGraph(function() {
#         var chart = nv.models.multiBarChart();
#
#         chart.margin({top: 30, right: 60, bottom: 20, left: 60});
#
#         var datum = data_risk_reduction_workshop;
#
#
#
#
#
#             chart.yAxis
#                 .axisLabel('risk_reduction_workshop per $1000');
#
#
#       chart.showLegend(true);
#
#
#
#
#
#
#         d3.select('#risk_reduction_workshop svg')
#             .datum(datum)
#             .transition().duration(500)
#             .attr('width', 800)
#             .attr('height', 400)
#             .call(chart);
#
#
#     });
#
#
#
#
#     </script>
#
#     </body>
# </html>

# %% [markdown]
# <h1> d1_number_of_sws_screened_for_tb </h1>

# %%
plot_ME('d1_number_of_sws_screened_for_tb')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8" />
#         <link href="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.css" rel="stylesheet" />
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script>
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.js"></script>
#     </head>
#     <body>
#
#     <div id="d1_number_of_sws_screened_for_tb"><svg style="width:800px;height:400px;"></svg></div>
#
#
#     <script>
#
#
#
#         data_d1_number_of_sws_screened_for_tb=[{"values": [{"y": NaN, "x": "cpc"}, {"y": NaN, "x": "nqobile"}, {"y": 0.016863862177905288, "x": "oasis"}, {"y": NaN, "x": "qac"}], "key": "Quarter 1", "yAxis": "1"}, {"values": [{"y": 3.4518217859072244, "x": "cpc"}, {"y": 0.17486144396281075, "x": "nqobile"}, {"y": 2.842698073056376, "x": "oasis"}, {"y": 0.023741915108991096, "x": "qac"}], "key": "Quarter 2", "yAxis": "1"}];
#
#     nv.addGraph(function() {
#         var chart = nv.models.multiBarChart();
#
#         chart.margin({top: 30, right: 60, bottom: 20, left: 60});
#
#         var datum = data_d1_number_of_sws_screened_for_tb;
#
#
#
#
#
#             chart.yAxis
#                 .axisLabel('d1_number_of_sws_screened_for_tb per $1000');
#
#
#       chart.showLegend(true);
#
#
#
#
#
#
#         d3.select('#d1_number_of_sws_screened_for_tb svg')
#             .datum(datum)
#             .transition().duration(500)
#             .attr('width', 800)
#             .attr('height', 400)
#             .call(chart);
#
#
#     });
#
#
#
#
#     </script>
#
#     </body>
# </html>

# %% [markdown]
# <h1> c1_sws_screened_for_sexually_transmitted_infections_sti_2 </h1>

# %%
plot_ME('c1_sws_screened_for_sexually_transmitted_infections_sti_2')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8" />
#         <link href="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.css" rel="stylesheet" />
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script>
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.js"></script>
#     </head>
#     <body>
#
#     <div id="c1_sws_screened_for_sexually_transmitted_infections_sti_2"><svg style="width:800px;height:400px;"></svg></div>
#
#
#     <script>
#
#
#
#         data_c1_sws_screened_for_sexually_transmitted_infections_sti_2=[{"values": [{"y": NaN, "x": "cpc"}, {"y": NaN, "x": "nqobile"}, {"y": 0.016863862177905288, "x": "oasis"}, {"y": NaN, "x": "qac"}], "key": "Quarter 1", "yAxis": "1"}, {"values": [{"y": 3.4790063498198647, "x": "cpc"}, {"y": 0.17486144396281075, "x": "nqobile"}, {"y": 3.3298023052034371, "x": "oasis"}, {"y": 0.023741915108991096, "x": "qac"}], "key": "Quarter 2", "yAxis": "1"}];
#
#     nv.addGraph(function() {
#         var chart = nv.models.multiBarChart();
#
#         chart.margin({top: 30, right: 60, bottom: 20, left: 60});
#
#         var datum = data_c1_sws_screened_for_sexually_transmitted_infections_sti_2;
#
#
#
#
#
#             chart.yAxis
#                 .axisLabel('c1_sws_screened_for_sexually_transmitted_infections_sti_2 per $1000');
#
#
#       chart.showLegend(true);
#
#
#
#
#
#
#         d3.select('#c1_sws_screened_for_sexually_transmitted_infections_sti_2 svg')
#             .datum(datum)
#             .transition().duration(500)
#             .attr('width', 800)
#             .attr('height', 400)
#             .call(chart);
#
#
#     });
#
#
#
#
#     </script>
#
#     </body>
# </html>

# %% [markdown]
# <h1> f_1_male_condoms_number_given </h1>

# %%
plot_ME('f_1_male_condoms_number_given')
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8" />
#         <link href="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.css" rel="stylesheet" />
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js"></script>
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/nvd3/1.7.0/nv.d3.min.js"></script>
#     </head>
#     <body>
#
#     <div id="f_1_male_condoms_number_given"><svg style="width:800px;height:400px;"></svg></div>
#
#
#     <script>
#
#
#
#         data_f_1_male_condoms_number_given=[{"values": [{"y": 72.262660585844372, "x": "cpc"}, {"y": 0.011425605341424797, "x": "qac"}, {"y": 0.97501616942574387, "x": "sweat"}], "key": "Quarter 1", "yAxis": "1"}, {"values": [{"y": 198.39789008242849, "x": "cpc"}, {"y": NaN, "x": "qac"}, {"y": 1.5673103610364554, "x": "sweat"}], "key": "Quarter 2", "yAxis": "1"}];
#
#     nv.addGraph(function() {
#         var chart = nv.models.multiBarChart();
#
#         chart.margin({top: 30, right: 60, bottom: 20, left: 60});
#
#         var datum = data_f_1_male_condoms_number_given;
#
#
#
#
#
#             chart.yAxis
#                 .axisLabel('f_1_male_condoms_number_given per $1000');
#
#
#       chart.showLegend(true);
#
#
#
#
#
#
#         d3.select('#f_1_male_condoms_number_given svg')
#             .datum(datum)
#             .transition().duration(500)
#             .attr('width', 800)
#             .attr('height', 400)
#             .call(chart);
#
#
#     });
#
#
#
#
#     </script>
#
#     </body>
# </html>

# %% [markdown]
# <h1> b_1_received_hts_and_know_results </h1>

# %%
plot_ME('b_1_received_hts_and_know_results')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-37ca5a5fdeb1> in <module>()
# ----> 1 plot_ME('b_1_received_hts_and_know_results')
#
# NameError: name 'plot_ME' is not defined

# %% [markdown]
# <h1> ... next we'd also like to normalize to targets </h1>
